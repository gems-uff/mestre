# %% [markdown]
# Goal of this notebook:
#
# Investigate the impact on the classifier accuracy of removing groups of attributes related to the conflicting chunks.
#
# Attributes groups:
#
# - Authorship: self_conflict_perc, authors involved
# - Complexity: leftCC, rightCC
# - Size: chunkAbsSize, chunkRelSize, chunk_left_abs_size, chunk_left_rel_size, chunk_right_abs_size, chunk_right_rel_size
# - Position: chunkPosition
# - Content: Programming language constructs

# %%
import numpy as np
import pandas as pd
from IPython.core.display import display

pd.set_option('display.max_columns', None)
from sklearn.ensemble import RandomForestClassifier

import warnings
import classifier_utils
import configs
warnings.filterwarnings("ignore", category=UserWarning)

# %%
non_features_columns = ["chunk_id", "line_start", "line_end", "line_separator", "kind_conflict", "url", "project"]
non_features_columns.extend(["project_user", "project_name", "path", "file_name", "sha", "leftsha", "rightsha", "basesha"])

# %%
selected_dataset = pd.read_csv("../../data/SELECTED_LABELLED_DATASET.csv")
projects = list(selected_dataset['project'].unique())

# %%
rf = RandomForestClassifier(random_state=99, n_jobs=5, n_estimators=400, max_features=0.3, min_samples_leaf=1)# Decision Tree

# %%
default_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns)
report_default = default_result.get_report_df(include_overall=True)

# %% [markdown]
# ## Drop all chunk related columns

# %%
import importlib
importlib.reload(classifier_utils)
ablation_group = 'all'
all_columns_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns, ablation=True, ablation_group=ablation_group)

# %%
report_all_columns = all_columns_result.get_report_df(include_overall=True)
report_all_columns
# Out:
#                                               project  observations  \
# 0                                     CCI-MIT__XCoLab          5512
# 1                            apache__directory-server           845
# 2                              Ramblurr__Anki-Android           892
# 3                                    apache__accumulo          4113
# 4                                    jgralab__jgralab          2072
# 5                                     getrailo__railo           815
# 6                                 apache__lucene-solr          1256
# 7                    cgjones__android-frameworks-base           828
# 8                                           zkoss__zk          1087
# 9                                       freenet__fred          1268
# 10                     AOKP__frameworks_base_disabled          1999
# 11              CloudStack-extras__CloudStack-archive          1424
# 12                             eucalyptus__eucalyptus          1020
# 13                                    atlasapi__atlas          1107
# 14                  android__platform_frameworks_base          3557
# 15  RealVNC__android-frameworks-base-with-screensh...          2269
# 16                              alkacon__opencms-core           923
# 17            allwinner-ics__platform_frameworks_base          1780
# 18                                       alexo__wro4j          1663
# 19           IceColdSandwich__android_frameworks_base          1792
# 20                           hibernate__hibernate-orm          1000
# 21                             TeamDev-Ltd__OpenFaces          2979
# 22                                   Unidata__thredds          1154
# 23                               SINTEF-9012__ThingML          1022
# 24                              sebastianbenz__Jnario          8298
# 25                             elastic__elasticsearch          1246
# 26                             eclipse__jetty.project          1537
# 27                        revolsys__com.revolsys.open           991
# 28  adetaylor__android-frameworks-base-with-remote...          1792
# 29                                            Overall         56241
#
#     observations (wt NaN)  precision   recall  f1-score  accuracy  \
# 0                    3757     0.9730  0.97800     0.975   0.97800
# 1                     652     0.9220  0.92300     0.922   0.92300
# 2                     759     0.6810  0.70600     0.691   0.70600
# 3                    3148     0.7880  0.79700     0.792   0.79700
# 4                    1802     0.7090  0.71300     0.709   0.71300
# 5                     572     0.6210  0.63300     0.625   0.63300
# 6                     974     0.5520  0.56100     0.556   0.56100
# 7                     565     0.8390  0.84800     0.843   0.84800
# 8                     881     0.7500  0.75900     0.754   0.75900
# 9                    1012     0.6270  0.63800     0.632   0.63800
# 10                   1370     0.7950  0.80700     0.800   0.80700
# 11                   1106     0.6060  0.62000     0.612   0.62000
# 12                    747     0.5870  0.60100     0.593   0.60100
# 13                    782     0.6020  0.61600     0.604   0.61600
# 14                   2460     0.7880  0.79800     0.792   0.79800
# 15                   1561     0.7810  0.79500     0.787   0.79500
# 16                    840     0.9500  0.96000     0.955   0.96000
# 17                   1187     0.7800  0.79000     0.785   0.79000
# 18                   1368     0.4720  0.48000     0.476   0.48000
# 19                   1193     0.7730  0.79000     0.781   0.79000
# 20                    716     0.4540  0.46600     0.459   0.46600
# 21                   2859     0.9460  0.95200     0.948   0.95200
# 22                    950     0.7900  0.82200     0.802   0.82200
# 23                    977     0.9260  0.94200     0.933   0.94200
# 24                   8173     0.9980  0.99900     0.999   0.99900
# 25                      0        NaN      NaN       NaN       NaN
# 26                      0        NaN      NaN       NaN       NaN
# 27                      1        NaN      NaN       NaN       NaN
# 28                      0        NaN      NaN       NaN       NaN
# 29                  40412     0.7484  0.75976     0.753   0.75976
#
#     baseline (majority)  improvement
# 0                0.5730      0.94800
# 1                0.5120      0.84300
# 2                0.4390      0.47700
# 3                0.6350      0.44400
# 4                0.4910      0.43500
# 5                0.3780      0.41000
# 6                0.2660      0.40100
# 7                0.7470      0.39900
# 8                0.6020      0.39600
# 9                0.4040      0.39300
# 10               0.7110      0.33100
# 11               0.4370      0.32600
# 12               0.4230      0.30900
# 13               0.4450      0.30900
# 14               0.7080      0.30700
# 15               0.7110      0.29000
# 16               0.9440      0.27700
# 17               0.7130      0.27000
# 18               0.3070      0.25000
# 19               0.7260      0.23200
# 20               0.3110      0.22500
# 21               0.9380      0.22200
# 22               0.7770      0.20300
# 23               0.9380      0.06600
# 24               0.9990      0.00000
# 25                  NaN          NaN
# 26                  NaN          NaN
# 27                  NaN          NaN
# 28                  NaN          NaN
# 29               0.6054      0.35052

# %% [markdown]
# ## Drop chunk authorship related columns

# %%
import importlib
importlib.reload(classifier_utils)
ablation_group = 'authorship'
authorship_columns_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns, ablation=True, ablation_group=ablation_group)

# %%
report_authorship_columns = authorship_columns_result.get_report_df(include_overall=True)
report_authorship_columns
# Out:
#                                               project  observations  \
# 0                                     CCI-MIT__XCoLab          5512
# 1                            apache__directory-server           845
# 2                                    jgralab__jgralab          2072
# 3               CloudStack-extras__CloudStack-archive          1424
# 4                                    apache__accumulo          4113
# 5                                    Unidata__thredds          1154
# 6                              Ramblurr__Anki-Android           892
# 7                                     getrailo__railo           815
# 8                                 apache__lucene-solr          1256
# 9                              TeamDev-Ltd__OpenFaces          2979
# 10                                      freenet__fred          1268
# 11                                          zkoss__zk          1087
# 12                   cgjones__android-frameworks-base           828
# 13                                       alexo__wro4j          1663
# 14                     AOKP__frameworks_base_disabled          1999
# 15                           hibernate__hibernate-orm          1000
# 16                  android__platform_frameworks_base          3557
# 17                                    atlasapi__atlas          1107
# 18            allwinner-ics__platform_frameworks_base          1780
# 19                             eucalyptus__eucalyptus          1020
# 20  RealVNC__android-frameworks-base-with-screensh...          2269
# 21                              alkacon__opencms-core           923
# 22           IceColdSandwich__android_frameworks_base          1792
# 23                               SINTEF-9012__ThingML          1022
# 24                              sebastianbenz__Jnario          8298
# 25                             elastic__elasticsearch          1246
# 26                             eclipse__jetty.project          1537
# 27                        revolsys__com.revolsys.open           991
# 28  adetaylor__android-frameworks-base-with-remote...          1792
# 29                                            Overall         56241
#
#     observations (wt NaN)  precision   recall  f1-score  accuracy  \
# 0                    3757    0.97300  0.97600   0.97400   0.97600
# 1                     652    0.93200  0.93600   0.93400   0.93600
# 2                    1802    0.86200  0.86300   0.86100   0.86300
# 3                    1106    0.79300  0.79900   0.79400   0.79900
# 4                    3148    0.85000  0.85500   0.85100   0.85500
# 5                     950    0.89900  0.90700   0.90100   0.90700
# 6                     759    0.71900  0.74000   0.72500   0.74000
# 7                     572    0.69100  0.70800   0.69700   0.70800
# 8                     974    0.63100  0.64000   0.63300   0.64000
# 9                    2859    0.96500  0.96800   0.96600   0.96800
# 10                   1012    0.66700  0.67400   0.66700   0.67400
# 11                    881    0.76300  0.78000   0.76900   0.78000
# 12                    565    0.84500  0.85700   0.84900   0.85700
# 13                   1368    0.57900  0.59000   0.58200   0.59000
# 14                   1370    0.81900  0.82600   0.82000   0.82600
# 15                    716    0.57400  0.58400   0.57300   0.58400
# 16                   2460    0.81000  0.81500   0.81000   0.81500
# 17                    782    0.62900  0.64600   0.63200   0.64600
# 18                   1187    0.79800  0.81000   0.80300   0.81000
# 19                    747    0.60100  0.61800   0.60600   0.61800
# 20                   1561    0.79200  0.80300   0.79600   0.80300
# 21                    840    0.94700  0.96100   0.95400   0.96100
# 22                   1193    0.78000  0.80400   0.79100   0.80400
# 23                    977    0.93200  0.94800   0.93900   0.94800
# 24                   8173    0.99800  0.99900   0.99900   0.99900
# 25                      0        NaN      NaN       NaN       NaN
# 26                      0        NaN      NaN       NaN       NaN
# 27                      1        NaN      NaN       NaN       NaN
# 28                      0        NaN      NaN       NaN       NaN
# 29                  40412    0.79396  0.80428   0.79704   0.80428
#
#     baseline (majority)  improvement
# 0                0.5730      0.94500
# 1                0.5120      0.86800
# 2                0.4910      0.73200
# 3                0.4370      0.64400
# 4                0.6350      0.60200
# 5                0.7770      0.58500
# 6                0.4390      0.53800
# 7                0.3780      0.53100
# 8                0.2660      0.50900
# 9                0.9380      0.48300
# 10               0.4040      0.45300
# 11               0.6020      0.44700
# 12               0.7470      0.43400
# 13               0.3070      0.40800
# 14               0.7110      0.39900
# 15               0.3110      0.39600
# 16               0.7080      0.36900
# 17               0.4450      0.36200
# 18               0.7130      0.34000
# 19               0.4230      0.33900
# 20               0.7110      0.31700
# 21               0.9440      0.29800
# 22               0.7260      0.28400
# 23               0.9380      0.16400
# 24               0.9990     -0.00000
# 25                  NaN          NaN
# 26                  NaN          NaN
# 27                  NaN          NaN
# 28                  NaN          NaN
# 29               0.6054      0.45788

# %% [markdown]
# ## Drop chunk complexity related columns

# %%
import importlib
importlib.reload(classifier_utils)
ablation_group = 'complexity'
complexity_columns_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns, ablation=True, ablation_group=ablation_group)

# %%
report_complexity_columns = complexity_columns_result.get_report_df(include_overall=True)
report_complexity_columns
# Out:
#                                               project  observations  \
# 0                                     CCI-MIT__XCoLab          5512
# 1                            apache__directory-server           845
# 2                                    jgralab__jgralab          2072
# 3               CloudStack-extras__CloudStack-archive          1424
# 4                                    Unidata__thredds          1154
# 5                                    apache__accumulo          4113
# 6                              Ramblurr__Anki-Android           892
# 7                                     getrailo__railo           815
# 8                                 apache__lucene-solr          1256
# 9                              TeamDev-Ltd__OpenFaces          2979
# 10                   cgjones__android-frameworks-base           828
# 11                                          zkoss__zk          1087
# 12                                      freenet__fred          1268
# 13                           hibernate__hibernate-orm          1000
# 14                                    atlasapi__atlas          1107
# 15                     AOKP__frameworks_base_disabled          1999
# 16                                       alexo__wro4j          1663
# 17                  android__platform_frameworks_base          3557
# 18  RealVNC__android-frameworks-base-with-screensh...          2269
# 19            allwinner-ics__platform_frameworks_base          1780
# 20                             eucalyptus__eucalyptus          1020
# 21                              alkacon__opencms-core           923
# 22           IceColdSandwich__android_frameworks_base          1792
# 23                               SINTEF-9012__ThingML          1022
# 24                              sebastianbenz__Jnario          8298
# 25                             elastic__elasticsearch          1246
# 26                             eclipse__jetty.project          1537
# 27                        revolsys__com.revolsys.open           991
# 28  adetaylor__android-frameworks-base-with-remote...          1792
# 29                                            Overall         56241
#
#     observations (wt NaN)  precision  recall  f1-score  accuracy  \
# 0                    3757    0.97200  0.9760   0.97400    0.9760
# 1                     652    0.93500  0.9390   0.93600    0.9390
# 2                    1802    0.86700  0.8680   0.86600    0.8680
# 3                    1106    0.79700  0.8030   0.79800    0.8030
# 4                     950    0.91300  0.9180   0.91400    0.9180
# 5                    3148    0.85800  0.8630   0.85900    0.8630
# 6                     759    0.72100  0.7430   0.72400    0.7430
# 7                     572    0.70100  0.7150   0.70700    0.7150
# 8                     974    0.63600  0.6430   0.63600    0.6430
# 9                    2859    0.96600  0.9690   0.96700    0.9690
# 10                    565    0.85700  0.8640   0.85900    0.8640
# 11                    881    0.76700  0.7830   0.77300    0.7830
# 12                   1012    0.66300  0.6700   0.66400    0.6700
# 13                    716    0.57700  0.5910   0.57800    0.5910
# 14                    782    0.65600  0.6700   0.65800    0.6700
# 15                   1370    0.81100  0.8240   0.81600    0.8240
# 16                   1368    0.56300  0.5750   0.56600    0.5750
# 17                   2460    0.81100  0.8170   0.81300    0.8170
# 18                   1561    0.80200  0.8140   0.80700    0.8140
# 19                   1187    0.79900  0.8120   0.80400    0.8120
# 20                    747    0.59700  0.6170   0.60400    0.6170
# 21                    840    0.94700  0.9620   0.95500    0.9620
# 22                   1193    0.79100  0.8110   0.79900    0.8110
# 23                    977    0.93400  0.9490   0.94100    0.9490
# 24                   8173    0.99800  0.9990   0.99900    0.9990
# 25                      0        NaN     NaN       NaN       NaN
# 26                      0        NaN     NaN       NaN       NaN
# 27                      1        NaN     NaN       NaN       NaN
# 28                      0        NaN     NaN       NaN       NaN
# 29                  40412    0.79756  0.8078   0.80068    0.8078
#
#     baseline (majority)  improvement
# 0                0.5730      0.94400
# 1                0.5120      0.87400
# 2                0.4910      0.74200
# 3                0.4370      0.65000
# 4                0.7770      0.63200
# 5                0.6350      0.62500
# 6                0.4390      0.54200
# 7                0.3780      0.54200
# 8                0.2660      0.51300
# 9                0.9380      0.50000
# 10               0.7470      0.46200
# 11               0.6020      0.45600
# 12               0.4040      0.44600
# 13               0.3110      0.40600
# 14               0.4450      0.40600
# 15               0.7110      0.39100
# 16               0.3070      0.38700
# 17               0.7080      0.37400
# 18               0.7110      0.35500
# 19               0.7130      0.34600
# 20               0.4230      0.33600
# 21               0.9440      0.31900
# 22               0.7260      0.30900
# 23               0.9380      0.18000
# 24               0.9990     -0.00000
# 25                  NaN          NaN
# 26                  NaN          NaN
# 27                  NaN          NaN
# 28                  NaN          NaN
# 29               0.6054      0.46948

# %% [markdown]
# ## Drop chunk size related columns

# %%
import importlib
importlib.reload(classifier_utils)
ablation_group = 'size'
size_columns_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns, ablation=True, ablation_group=ablation_group)

# %%
report_size_columns = size_columns_result.get_report_df(include_overall=True)
report_size_columns
# Out:
#                                               project  observations  \
# 0                                     CCI-MIT__XCoLab          5512
# 1                            apache__directory-server           845
# 2                                    jgralab__jgralab          2072
# 3               CloudStack-extras__CloudStack-archive          1424
# 4                                    apache__accumulo          4113
# 5                                    Unidata__thredds          1154
# 6                              Ramblurr__Anki-Android           892
# 7                                 apache__lucene-solr          1256
# 8                              TeamDev-Ltd__OpenFaces          2979
# 9                                     getrailo__railo           815
# 10                   cgjones__android-frameworks-base           828
# 11                                      freenet__fred          1268
# 12                                          zkoss__zk          1087
# 13                                    atlasapi__atlas          1107
# 14                                       alexo__wro4j          1663
# 15                           hibernate__hibernate-orm          1000
# 16                     AOKP__frameworks_base_disabled          1999
# 17                  android__platform_frameworks_base          3557
# 18                             eucalyptus__eucalyptus          1020
# 19            allwinner-ics__platform_frameworks_base          1780
# 20                              alkacon__opencms-core           923
# 21  RealVNC__android-frameworks-base-with-screensh...          2269
# 22           IceColdSandwich__android_frameworks_base          1792
# 23                               SINTEF-9012__ThingML          1022
# 24                              sebastianbenz__Jnario          8298
# 25                             elastic__elasticsearch          1246
# 26                             eclipse__jetty.project          1537
# 27                        revolsys__com.revolsys.open           991
# 28  adetaylor__android-frameworks-base-with-remote...          1792
# 29                                            Overall         56241
#
#     observations (wt NaN)  precision   recall  f1-score  accuracy  \
# 0                    3757      0.977  0.97800   0.97700   0.97800
# 1                     652      0.945  0.94600   0.94500   0.94600
# 2                    1802      0.861  0.86300   0.86100   0.86300
# 3                    1106      0.799  0.80400   0.80000   0.80400
# 4                    3148      0.848  0.85700   0.85200   0.85700
# 5                     950      0.891  0.90100   0.89500   0.90100
# 6                     759      0.713  0.73500   0.72000   0.73500
# 7                     974      0.620  0.63100   0.62500   0.63100
# 8                    2859      0.964  0.96700   0.96500   0.96700
# 9                     572      0.649  0.66300   0.65500   0.66300
# 10                    565      0.854  0.86200   0.85700   0.86200
# 11                   1012      0.658  0.66600   0.65900   0.66600
# 12                    881      0.757  0.77300   0.76400   0.77300
# 13                    782      0.653  0.66900   0.65700   0.66900
# 14                   1368      0.558  0.56500   0.56100   0.56500
# 15                    716      0.552  0.56700   0.55500   0.56700
# 16                   1370      0.805  0.81700   0.81000   0.81700
# 17                   2460      0.807  0.81300   0.80800   0.81300
# 18                    747      0.605  0.62500   0.61200   0.62500
# 19                   1187      0.791  0.80500   0.79700   0.80500
# 20                    840      0.947  0.96200   0.95400   0.96200
# 21                   1561      0.793  0.80300   0.79700   0.80300
# 22                   1193      0.794  0.80800   0.80000   0.80800
# 23                    977      0.936  0.94700   0.94100   0.94700
# 24                   8173      0.998  0.99900   0.99900   0.99900
# 25                      0        NaN      NaN       NaN       NaN
# 26                      0        NaN      NaN       NaN       NaN
# 27                      1        NaN      NaN       NaN       NaN
# 28                      0        NaN      NaN       NaN       NaN
# 29                  40412      0.791  0.80104   0.79464   0.80104
#
#     baseline (majority)  improvement
# 0                0.5730      0.94900
# 1                0.5120      0.89000
# 2                0.4910      0.73200
# 3                0.4370      0.65200
# 4                0.6350      0.60800
# 5                0.7770      0.55700
# 6                0.4390      0.52800
# 7                0.2660      0.49800
# 8                0.9380      0.46600
# 9                0.3780      0.45800
# 10               0.7470      0.45500
# 11               0.4040      0.43900
# 12               0.6020      0.43000
# 13               0.4450      0.40300
# 14               0.3070      0.37200
# 15               0.3110      0.37100
# 16               0.7110      0.36600
# 17               0.7080      0.35900
# 18               0.4230      0.35000
# 19               0.7130      0.32000
# 20               0.9440      0.31900
# 21               0.7110      0.31900
# 22               0.7260      0.30000
# 23               0.9380      0.14800
# 24               0.9990     -0.00000
# 25                  NaN          NaN
# 26                  NaN          NaN
# 27                  NaN          NaN
# 28                  NaN          NaN
# 29               0.6054      0.45156

# %% [markdown]
# ## Drop chunk position related columns

# %%
import importlib
importlib.reload(classifier_utils)
ablation_group = 'position'
position_columns_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns, ablation=True, ablation_group=ablation_group)

# %%
report_position_columns = position_columns_result.get_report_df(include_overall=True)
report_position_columns
# Out:
#                                               project  observations  \
# 0                                     CCI-MIT__XCoLab          5512
# 1                            apache__directory-server           845
# 2                                    jgralab__jgralab          2072
# 3               CloudStack-extras__CloudStack-archive          1424
# 4                                    Unidata__thredds          1154
# 5                                    apache__accumulo          4113
# 6                                     getrailo__railo           815
# 7                              Ramblurr__Anki-Android           892
# 8                                 apache__lucene-solr          1256
# 9                              TeamDev-Ltd__OpenFaces          2979
# 10                                          zkoss__zk          1087
# 11                                      freenet__fred          1268
# 12                   cgjones__android-frameworks-base           828
# 13                           hibernate__hibernate-orm          1000
# 14                     AOKP__frameworks_base_disabled          1999
# 15                                    atlasapi__atlas          1107
# 16                                       alexo__wro4j          1663
# 17                  android__platform_frameworks_base          3557
# 18            allwinner-ics__platform_frameworks_base          1780
# 19                             eucalyptus__eucalyptus          1020
# 20  RealVNC__android-frameworks-base-with-screensh...          2269
# 21           IceColdSandwich__android_frameworks_base          1792
# 22                              alkacon__opencms-core           923
# 23                               SINTEF-9012__ThingML          1022
# 24                              sebastianbenz__Jnario          8298
# 25                             elastic__elasticsearch          1246
# 26                             eclipse__jetty.project          1537
# 27                        revolsys__com.revolsys.open           991
# 28  adetaylor__android-frameworks-base-with-remote...          1792
# 29                                            Overall         56241
#
#     observations (wt NaN)  precision   recall  f1-score  accuracy  \
# 0                    3757    0.97200  0.97600    0.9730   0.97600
# 1                     652    0.93900  0.94200    0.9400   0.94200
# 2                    1802    0.86600  0.86800    0.8660   0.86800
# 3                    1106    0.79900  0.80500    0.8000   0.80500
# 4                     950    0.91500  0.92000    0.9160   0.92000
# 5                    3148    0.85900  0.86400    0.8600   0.86400
# 6                     572    0.70600  0.71900    0.7100   0.71900
# 7                     759    0.71800  0.74300    0.7260   0.74300
# 8                     974    0.64200  0.65000    0.6440   0.65000
# 9                    2859    0.96600  0.96900    0.9670   0.96900
# 10                    881    0.77200  0.78500    0.7770   0.78500
# 11                   1012    0.67200  0.67900    0.6730   0.67900
# 12                    565    0.84900  0.85800    0.8530   0.85800
# 13                    716    0.58500  0.59800    0.5850   0.59800
# 14                   1370    0.82200  0.83000    0.8240   0.83000
# 15                    782    0.65300  0.66900    0.6560   0.66900
# 16                   1368    0.57200  0.58300    0.5740   0.58300
# 17                   2460    0.81400  0.81900    0.8150   0.81900
# 18                   1187    0.79800  0.81000    0.8020   0.81000
# 19                    747    0.59700  0.61800    0.6040   0.61800
# 20                   1561    0.79900  0.80900    0.8020   0.80900
# 21                   1193    0.79700  0.81400    0.8040   0.81400
# 22                    840    0.94700  0.96200    0.9550   0.96200
# 23                    977    0.93400  0.94800    0.9400   0.94800
# 24                   8173    0.99800  0.99900    0.9990   0.99900
# 25                      0        NaN      NaN       NaN       NaN
# 26                      0        NaN      NaN       NaN       NaN
# 27                      1        NaN      NaN       NaN       NaN
# 28                      0        NaN      NaN       NaN       NaN
# 29                  40412    0.79964  0.80948    0.8026   0.80948
#
#     baseline (majority)  improvement
# 0                0.5730      0.94300
# 1                0.5120      0.88100
# 2                0.4910      0.74000
# 3                0.4370      0.65300
# 4                0.7770      0.64200
# 5                0.6350      0.62800
# 6                0.3780      0.54800
# 7                0.4390      0.54200
# 8                0.2660      0.52300
# 9                0.9380      0.50000
# 10               0.6020      0.46200
# 11               0.4040      0.46100
# 12               0.7470      0.44100
# 13               0.3110      0.41600
# 14               0.7110      0.41200
# 15               0.4450      0.40300
# 16               0.3070      0.39800
# 17               0.7080      0.38100
# 18               0.7130      0.34000
# 19               0.4230      0.33900
# 20               0.7110      0.33900
# 21               0.7260      0.32100
# 22               0.9440      0.31900
# 23               0.9380      0.16400
# 24               0.9990     -0.00000
# 25                  NaN          NaN
# 26                  NaN          NaN
# 27                  NaN          NaN
# 28                  NaN          NaN
# 29               0.6054      0.47184

# %% [markdown]
# ## Drop chunk content related columns

# %%
import importlib
importlib.reload(classifier_utils)
ablation_group = 'content'
content_columns_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns, ablation=True, ablation_group=ablation_group)

# %%
report_content_columns = content_columns_result.get_report_df(include_overall=True)
report_content_columns
# Out:
#                                               project  observations  \
# 0                                     CCI-MIT__XCoLab          5512
# 1                            apache__directory-server           845
# 2                                    jgralab__jgralab          2072
# 3               CloudStack-extras__CloudStack-archive          1424
# 4                                    apache__accumulo          4113
# 5                                    Unidata__thredds          1154
# 6                              Ramblurr__Anki-Android           892
# 7                                     getrailo__railo           815
# 8                                 apache__lucene-solr          1256
# 9                                       freenet__fred          1268
# 10                             TeamDev-Ltd__OpenFaces          2979
# 11                                          zkoss__zk          1087
# 12                   cgjones__android-frameworks-base           828
# 13                     AOKP__frameworks_base_disabled          1999
# 14                           hibernate__hibernate-orm          1000
# 15                                       alexo__wro4j          1663
# 16                  android__platform_frameworks_base          3557
# 17                                    atlasapi__atlas          1107
# 18                              alkacon__opencms-core           923
# 19                             eucalyptus__eucalyptus          1020
# 20  RealVNC__android-frameworks-base-with-screensh...          2269
# 21            allwinner-ics__platform_frameworks_base          1780
# 22           IceColdSandwich__android_frameworks_base          1792
# 23                               SINTEF-9012__ThingML          1022
# 24                              sebastianbenz__Jnario          8298
# 25                             elastic__elasticsearch          1246
# 26                             eclipse__jetty.project          1537
# 27                        revolsys__com.revolsys.open           991
# 28  adetaylor__android-frameworks-base-with-remote...          1792
# 29                                            Overall         56241
#
#     observations (wt NaN)  precision  recall  f1-score  accuracy  \
# 0                    3757    0.97100  0.9740     0.973    0.9740
# 1                     652    0.91800  0.9220     0.920    0.9220
# 2                    1802    0.85400  0.8570     0.854    0.8570
# 3                    1106    0.80600  0.8120     0.807    0.8120
# 4                    3148    0.85100  0.8580     0.853    0.8580
# 5                     950    0.90000  0.9060     0.901    0.9060
# 6                     759    0.72500  0.7460     0.727    0.7460
# 7                     572    0.68500  0.6990     0.691    0.6990
# 8                     974    0.63300  0.6420     0.636    0.6420
# 9                    1012    0.66200  0.6740     0.666    0.6740
# 10                   2859    0.96300  0.9660     0.964    0.9660
# 11                    881    0.76400  0.7790     0.770    0.7790
# 12                    565    0.84200  0.8530     0.846    0.8530
# 13                   1370    0.81900  0.8280     0.821    0.8280
# 14                    716    0.56600  0.5800     0.565    0.5800
# 15                   1368    0.56600  0.5770     0.567    0.5770
# 16                   2460    0.80800  0.8150     0.811    0.8150
# 17                    782    0.62900  0.6470     0.631    0.6470
# 18                    840    0.94900  0.9630     0.956    0.9630
# 19                    747    0.59900  0.6170     0.605    0.6170
# 20                   1561    0.79600  0.8070     0.800    0.8070
# 21                   1187    0.79300  0.8060     0.798    0.8060
# 22                   1193    0.79000  0.8090     0.798    0.8090
# 23                    977    0.93500  0.9490     0.941    0.9490
# 24                   8173    0.99800  0.9990     0.999    0.9990
# 25                      0        NaN     NaN       NaN       NaN
# 26                      0        NaN     NaN       NaN       NaN
# 27                      1        NaN     NaN       NaN       NaN
# 28                      0        NaN     NaN       NaN       NaN
# 29                  40412    0.79288  0.8034     0.796    0.8034
#
#     baseline (majority)  improvement
# 0                0.5730      0.94000
# 1                0.5120      0.84000
# 2                0.4910      0.71900
# 3                0.4370      0.66600
# 4                0.6350      0.61100
# 5                0.7770      0.58000
# 6                0.4390      0.54700
# 7                0.3780      0.51700
# 8                0.2660      0.51200
# 9                0.4040      0.45300
# 10               0.9380      0.44900
# 11               0.6020      0.44400
# 12               0.7470      0.42000
# 13               0.7110      0.40400
# 14               0.3110      0.38900
# 15               0.3070      0.38900
# 16               0.7080      0.36900
# 17               0.4450      0.36400
# 18               0.9440      0.34000
# 19               0.4230      0.33600
# 20               0.7110      0.33300
# 21               0.7130      0.32600
# 22               0.7260      0.30300
# 23               0.9380      0.18000
# 24               0.9990     -0.00000
# 25                  NaN          NaN
# 26                  NaN          NaN
# 27                  NaN          NaN
# 28                  NaN          NaN
# 29               0.6054      0.45724

# %%
df_inner_rf = pd.merge(report_default, report_all_columns, on='project', how='inner', suffixes=('_default', '_all'))
df_inner_rf_authorship = report_authorship_columns.add_suffix("_author").rename(columns={"project_author": "project"})
df_inner_rf = pd.merge(df_inner_rf, df_inner_rf_authorship, on='project', how='inner')
df_inner_rf_complexity = report_complexity_columns.add_suffix("_complexity").rename(columns={"project_complexity": "project"})
df_inner_rf = pd.merge(df_inner_rf, df_inner_rf_complexity, on='project', how='inner')
df_inner_rf_size = report_size_columns.add_suffix("_size").rename(columns={"project_size": "project"})
df_inner_rf = pd.merge(df_inner_rf, df_inner_rf_size, on='project', how='inner')
df_inner_rf_position = report_position_columns.add_suffix("_position").rename(columns={"project_position": "project"})
df_inner_rf = pd.merge(df_inner_rf, df_inner_rf_position, on='project', how='inner')
df_inner_rf_content = report_content_columns.add_suffix("_content").rename(columns={"project_content": "project"})
df_inner_rf = pd.merge(df_inner_rf, df_inner_rf_content, on='project', how='inner')

accuracy_rf = df_inner_rf.filter(regex=("project|accuracy.*")).copy()
accuracy_rf
# Out:
#                                               project  accuracy_default  \
# 0                                     CCI-MIT__XCoLab           0.97600
# 1                            apache__directory-server           0.93900
# 2                                    jgralab__jgralab           0.86900
# 3               CloudStack-extras__CloudStack-archive           0.80300
# 4                                    Unidata__thredds           0.91900
# 5                                    apache__accumulo           0.86400
# 6                              Ramblurr__Anki-Android           0.74000
# 7                                     getrailo__railo           0.70100
# 8                                 apache__lucene-solr           0.64400
# 9                              TeamDev-Ltd__OpenFaces           0.96900
# 10                                          zkoss__zk           0.78300
# 11                   cgjones__android-frameworks-base           0.86200
# 12                                      freenet__fred           0.67400
# 13                           hibernate__hibernate-orm           0.60200
# 14                                       alexo__wro4j           0.58400
# 15                                    atlasapi__atlas           0.66600
# 16                     AOKP__frameworks_base_disabled           0.82400
# 17                  android__platform_frameworks_base           0.81800
# 18            allwinner-ics__platform_frameworks_base           0.81300
# 19  RealVNC__android-frameworks-base-with-screensh...           0.81000
# 20                             eucalyptus__eucalyptus           0.62000
# 21                              alkacon__opencms-core           0.96200
# 22           IceColdSandwich__android_frameworks_base           0.81100
# 23                               SINTEF-9012__ThingML           0.94900
# 24                              sebastianbenz__Jnario           0.99900
# 25                             elastic__elasticsearch               NaN
# 26                             eclipse__jetty.project               NaN
# 27                        revolsys__com.revolsys.open               NaN
# 28  adetaylor__android-frameworks-base-with-remote...               NaN
# 29                                            Overall           0.80804
#
#     accuracy_all  accuracy_author  accuracy_complexity  accuracy_size  \
# 0        0.97800          0.97600               0.9760        0.97800
# 1        0.92300          0.93600               0.9390        0.94600
# 2        0.71300          0.86300               0.8680        0.86300
# 3        0.62000          0.79900               0.8030        0.80400
# 4        0.82200          0.90700               0.9180        0.90100
# 5        0.79700          0.85500               0.8630        0.85700
# 6        0.70600          0.74000               0.7430        0.73500
# 7        0.63300          0.70800               0.7150        0.66300
# 8        0.56100          0.64000               0.6430        0.63100
# 9        0.95200          0.96800               0.9690        0.96700
# 10       0.75900          0.78000               0.7830        0.77300
# 11       0.84800          0.85700               0.8640        0.86200
# 12       0.63800          0.67400               0.6700        0.66600
# 13       0.46600          0.58400               0.5910        0.56700
# 14       0.48000          0.59000               0.5750        0.56500
# 15       0.61600          0.64600               0.6700        0.66900
# 16       0.80700          0.82600               0.8240        0.81700
# 17       0.79800          0.81500               0.8170        0.81300
# 18       0.79000          0.81000               0.8120        0.80500
# 19       0.79500          0.80300               0.8140        0.80300
# 20       0.60100          0.61800               0.6170        0.62500
# 21       0.96000          0.96100               0.9620        0.96200
# 22       0.79000          0.80400               0.8110        0.80800
# 23       0.94200          0.94800               0.9490        0.94700
# 24       0.99900          0.99900               0.9990        0.99900
# 25           NaN              NaN                  NaN            NaN
# 26           NaN              NaN                  NaN            NaN
# 27           NaN              NaN                  NaN            NaN
# 28           NaN              NaN                  NaN            NaN
# 29       0.75976          0.80428               0.8078        0.80104
#
#     accuracy_position  accuracy_content
# 0             0.97600            0.9740
# 1             0.94200            0.9220
# 2             0.86800            0.8570
# 3             0.80500            0.8120
# 4             0.92000            0.9060
# 5             0.86400            0.8580
# 6             0.74300            0.7460
# 7             0.71900            0.6990
# 8             0.65000            0.6420
# 9             0.96900            0.9660
# 10            0.78500            0.7790
# 11            0.85800            0.8530
# 12            0.67900            0.6740
# 13            0.59800            0.5800
# 14            0.58300            0.5770
# 15            0.66900            0.6470
# 16            0.83000            0.8280
# 17            0.81900            0.8150
# 18            0.81000            0.8060
# 19            0.80900            0.8070
# 20            0.61800            0.6170
# 21            0.96200            0.9630
# 22            0.81400            0.8090
# 23            0.94800            0.9490
# 24            0.99900            0.9990
# 25                NaN               NaN
# 26                NaN               NaN
# 27                NaN               NaN
# 28                NaN               NaN
# 29            0.80948            0.8034

# %%
accuracy_rf_improv = accuracy_rf[accuracy_rf['project']=='Overall'].copy()
accuracy_rf_improv['improv._all'] = accuracy_rf_improv.apply(lambda x: classifier_utils.get_normalized_improvement(x['accuracy_all'], x['accuracy_default']), axis=1)
accuracy_rf_improv['improv._author'] = accuracy_rf_improv.apply(lambda x: classifier_utils.get_normalized_improvement(x['accuracy_author'], x['accuracy_default']), axis=1)
accuracy_rf_improv['improv._complexity'] = accuracy_rf_improv.apply(lambda x: classifier_utils.get_normalized_improvement(x['accuracy_complexity'], x['accuracy_default']), axis=1)
accuracy_rf_improv['improv._size'] = accuracy_rf_improv.apply(lambda x: classifier_utils.get_normalized_improvement(x['accuracy_size'], x['accuracy_default']), axis=1)
accuracy_rf_improv['improv._position'] = accuracy_rf_improv.apply(lambda x: classifier_utils.get_normalized_improvement(x['accuracy_position'], x['accuracy_default']), axis=1)
accuracy_rf_improv['improv._content'] = accuracy_rf_improv.apply(lambda x: classifier_utils.get_normalized_improvement(x['accuracy_content'], x['accuracy_default']), axis=1)
accuracy_rf_improv.transpose()
# Out:
#                               29
# project                  Overall
# accuracy_default         0.80804
# accuracy_all             0.75976
# accuracy_author          0.80428
# accuracy_complexity       0.8078
# accuracy_size            0.80104
# accuracy_position        0.80948
# accuracy_content          0.8034
# improv._all           -0.0597495
# improv._author       -0.00465323
# improv._complexity  -0.000297015
# improv._size         -0.00866294
# improv._position      0.00750156
# improv._content      -0.00574229
