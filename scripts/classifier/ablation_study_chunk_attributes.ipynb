# %% [markdown]
# Goal of this notebook:
#
# Investigate the impact on the classifier accuracy of removing groups of attributes related to the conflicting chunks.
#
# Attributes groups:
#
# - Authorship: self_conflict_perc, authors involved
# - Complexity: leftCC, rightCC
# - Size: chunkAbsSize, chunkRelSize, chunk_left_abs_size, chunk_left_rel_size, chunk_right_abs_size, chunk_right_rel_size
# - Position: chunkPosition
# - Content: Programming language constructs

# %%
import numpy as np
import pandas as pd
from IPython.core.display import display

pd.set_option('display.max_columns', None)
from sklearn.ensemble import RandomForestClassifier

import warnings
import classifier_utils
import configs
warnings.filterwarnings("ignore", category=UserWarning)

# %%
non_features_columns = ["chunk_id", "line_start", "line_end", "line_separator", "kind_conflict", "url", "project"]
non_features_columns.extend(["project_user", "project_name", "path", "file_name", "sha", "leftsha", "rightsha", "basesha"])

# %%
selected_dataset = pd.read_csv("../../data/SELECTED_LABELLED_DATASET.csv")
projects = list(selected_dataset['project'].unique())

# %%
rf = RandomForestClassifier(random_state=99, n_jobs=5, n_estimators=400, max_features=0.3, min_samples_leaf=1)# Decision Tree

# %%
default_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns)
report_default = default_result.get_report_df(include_overall=True)

# %% [markdown]
# ## Drop all chunk related columns

# %%
import importlib
importlib.reload(classifier_utils)
ablation_group = 'all'
all_columns_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns, ablation=True, ablation_group=ablation_group)

# %%
report_all_columns = all_columns_result.get_report_df(include_overall=True)
report_all_columns
# Out:
#                                   project  observations  \
# 0                         CCI-MIT__XCoLab          5512
# 1                apache__directory-server           845
# 2                  Ramblurr__Anki-Android           892
# 3                        apache__accumulo          4113
# 4                        jgralab__jgralab          2072
# 5                         getrailo__railo           815
# 6                     apache__lucene-solr          1256
# 7                               zkoss__zk          1087
# 8                           freenet__fred          1268
# 9   CloudStack-extras__CloudStack-archive          1424
# 10                 eucalyptus__eucalyptus          1020
# 11                        atlasapi__atlas          1107
# 12      android__platform_frameworks_base          3557
# 13                  alkacon__opencms-core           923
# 14                           alexo__wro4j          1663
# 15               hibernate__hibernate-orm          1000
# 16                 TeamDev-Ltd__OpenFaces          2979
# 17                       Unidata__thredds          1154
# 18                   SINTEF-9012__ThingML          1022
# 19                  sebastianbenz__Jnario          8298
# 20                 elastic__elasticsearch          1246
# 21                 eclipse__jetty.project          1537
# 22            revolsys__com.revolsys.open           991
# 23                                Overall         45781
#
#     observations (wt NaN)  precision  recall  f1-score  accuracy  \
# 0                    3757     0.9730  0.9780   0.97500    0.9780
# 1                     652     0.9220  0.9230   0.92200    0.9230
# 2                     759     0.6810  0.7060   0.69100    0.7060
# 3                    3148     0.7880  0.7970   0.79200    0.7970
# 4                    1802     0.7090  0.7130   0.70900    0.7130
# 5                     572     0.6210  0.6330   0.62500    0.6330
# 6                     974     0.5520  0.5610   0.55600    0.5610
# 7                     881     0.7500  0.7590   0.75400    0.7590
# 8                    1012     0.6270  0.6380   0.63200    0.6380
# 9                    1106     0.6060  0.6200   0.61200    0.6200
# 10                    747     0.5870  0.6010   0.59300    0.6010
# 11                    782     0.6020  0.6160   0.60400    0.6160
# 12                   2460     0.7880  0.7980   0.79200    0.7980
# 13                    840     0.9500  0.9600   0.95500    0.9600
# 14                   1368     0.4720  0.4800   0.47600    0.4800
# 15                    716     0.4540  0.4660   0.45900    0.4660
# 16                   2859     0.9460  0.9520   0.94800    0.9520
# 17                    950     0.7900  0.8220   0.80200    0.8220
# 18                    977     0.9260  0.9420   0.93300    0.9420
# 19                   8173     0.9980  0.9990   0.99900    0.9990
# 20                      0        NaN     NaN       NaN       NaN
# 21                      0        NaN     NaN       NaN       NaN
# 22                      1        NaN     NaN       NaN       NaN
# 23                  34536     0.7371  0.7482   0.74145    0.7482
#
#     baseline (majority)  improvement
# 0               0.57300      0.94800
# 1               0.51200      0.84300
# 2               0.43900      0.47700
# 3               0.63500      0.44400
# 4               0.49100      0.43500
# 5               0.37800      0.41000
# 6               0.26600      0.40100
# 7               0.60200      0.39600
# 8               0.40400      0.39300
# 9               0.43700      0.32600
# 10              0.42300      0.30900
# 11              0.44500      0.30900
# 12              0.70800      0.30700
# 13              0.94400      0.27700
# 14              0.30700      0.25000
# 15              0.31100      0.22500
# 16              0.93800      0.22200
# 17              0.77700      0.20300
# 18              0.93800      0.06600
# 19              0.99900      0.00000
# 20                  NaN          NaN
# 21                  NaN          NaN
# 22                  NaN          NaN
# 23              0.57635      0.36205

# %% [markdown]
# ## Drop chunk authorship related columns

# %%
import importlib
importlib.reload(classifier_utils)
ablation_group = 'authorship'
authorship_columns_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns, ablation=True, ablation_group=ablation_group)

# %%
report_authorship_columns = authorship_columns_result.get_report_df(include_overall=True)
report_authorship_columns
# Out:
#                                   project  observations  \
# 0                         CCI-MIT__XCoLab          5512
# 1                apache__directory-server           845
# 2                        jgralab__jgralab          2072
# 3   CloudStack-extras__CloudStack-archive          1424
# 4                        apache__accumulo          4113
# 5                        Unidata__thredds          1154
# 6                         getrailo__railo           815
# 7                  Ramblurr__Anki-Android           892
# 8                     apache__lucene-solr          1256
# 9                  TeamDev-Ltd__OpenFaces          2979
# 10                          freenet__fred          1268
# 11                              zkoss__zk          1087
# 12                           alexo__wro4j          1663
# 13               hibernate__hibernate-orm          1000
# 14      android__platform_frameworks_base          3557
# 15                        atlasapi__atlas          1107
# 16                 eucalyptus__eucalyptus          1020
# 17                  alkacon__opencms-core           923
# 18                   SINTEF-9012__ThingML          1022
# 19                  sebastianbenz__Jnario          8298
# 20                 elastic__elasticsearch          1246
# 21                 eclipse__jetty.project          1537
# 22            revolsys__com.revolsys.open           991
# 23                                Overall         45781
#
#     observations (wt NaN)  precision   recall  f1-score  accuracy  \
# 0                    3757    0.97200  0.97600   0.97400   0.97600
# 1                     652    0.92900  0.93300   0.93100   0.93300
# 2                    1802    0.85900  0.86100   0.85900   0.86100
# 3                    1106    0.79200  0.79800   0.79400   0.79800
# 4                    3148    0.85200  0.85700   0.85300   0.85700
# 5                     950    0.89700  0.90500   0.89900   0.90500
# 6                     572    0.69400  0.71000   0.70000   0.71000
# 7                     759    0.70900  0.73400   0.71600   0.73400
# 8                     974    0.62900  0.63900   0.63200   0.63900
# 9                    2859    0.96700  0.97000   0.96800   0.97000
# 10                   1012    0.66600  0.67300   0.66700   0.67300
# 11                    881    0.76200  0.77800   0.76800   0.77800
# 12                   1368    0.57600  0.58700   0.57800   0.58700
# 13                    716    0.57400  0.58500   0.57400   0.58500
# 14                   2460    0.80700  0.81300   0.80800   0.81300
# 15                    782    0.62200  0.63900   0.62500   0.63900
# 16                    747    0.59600  0.61300   0.60100   0.61300
# 17                    840    0.94700  0.96200   0.95500   0.96200
# 18                    977    0.93300  0.94900   0.94000   0.94900
# 19                   8173    0.99800  0.99900   0.99900   0.99900
# 20                      0        NaN      NaN       NaN       NaN
# 21                      0        NaN      NaN       NaN       NaN
# 22                      1        NaN      NaN       NaN       NaN
# 23                  34536    0.78905  0.79905   0.79205   0.79905
#
#     baseline (majority)  improvement
# 0               0.57300       0.9440
# 1               0.51200       0.8620
# 2               0.49100       0.7270
# 3               0.43700       0.6420
# 4               0.63500       0.6070
# 5               0.77700       0.5750
# 6               0.37800       0.5340
# 7               0.43900       0.5260
# 8               0.26600       0.5080
# 9               0.93800       0.5060
# 10              0.40400       0.4510
# 11              0.60200       0.4420
# 12              0.30700       0.4040
# 13              0.31100       0.3980
# 14              0.70800       0.3600
# 15              0.44500       0.3500
# 16              0.42300       0.3290
# 17              0.94400       0.3190
# 18              0.93800       0.1800
# 19              0.99900      -0.0000
# 20                  NaN          NaN
# 21                  NaN          NaN
# 22                  NaN          NaN
# 23              0.57635       0.4832

# %% [markdown]
# ## Drop chunk complexity related columns

# %%
import importlib
importlib.reload(classifier_utils)
ablation_group = 'complexity'
complexity_columns_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns, ablation=True, ablation_group=ablation_group)

# %%
report_complexity_columns = complexity_columns_result.get_report_df(include_overall=True)
report_complexity_columns
# Out:
#                                   project  observations  \
# 0                         CCI-MIT__XCoLab          5512
# 1                apache__directory-server           845
# 2                        jgralab__jgralab          2072
# 3   CloudStack-extras__CloudStack-archive          1424
# 4                        Unidata__thredds          1154
# 5                        apache__accumulo          4113
# 6                         getrailo__railo           815
# 7                  Ramblurr__Anki-Android           892
# 8                     apache__lucene-solr          1256
# 9                  TeamDev-Ltd__OpenFaces          2979
# 10                              zkoss__zk          1087
# 11                          freenet__fred          1268
# 12               hibernate__hibernate-orm          1000
# 13                        atlasapi__atlas          1107
# 14                           alexo__wro4j          1663
# 15      android__platform_frameworks_base          3557
# 16                 eucalyptus__eucalyptus          1020
# 17                  alkacon__opencms-core           923
# 18                   SINTEF-9012__ThingML          1022
# 19                  sebastianbenz__Jnario          8298
# 20                 elastic__elasticsearch          1246
# 21                 eclipse__jetty.project          1537
# 22            revolsys__com.revolsys.open           991
# 23                                Overall         45781
#
#     observations (wt NaN)  precision   recall  f1-score  accuracy  \
# 0                    3757     0.9720  0.97600    0.9740   0.97600
# 1                     652     0.9350  0.93900    0.9360   0.93900
# 2                    1802     0.8670  0.86900    0.8670   0.86900
# 3                    1106     0.7980  0.80500    0.7990   0.80500
# 4                     950     0.9130  0.91900    0.9140   0.91900
# 5                    3148     0.8570  0.86200    0.8580   0.86200
# 6                     572     0.6940  0.71000    0.7000   0.71000
# 7                     759     0.7130  0.73500    0.7180   0.73500
# 8                     974     0.6410  0.64800    0.6410   0.64800
# 9                    2859     0.9660  0.96900    0.9670   0.96900
# 10                    881     0.7710  0.78500    0.7760   0.78500
# 11                   1012     0.6670  0.67500    0.6690   0.67500
# 12                    716     0.5910  0.60500    0.5910   0.60500
# 13                    782     0.6550  0.66900    0.6570   0.66900
# 14                   1368     0.5660  0.57700    0.5690   0.57700
# 15                   2460     0.8100  0.81600    0.8120   0.81600
# 16                    747     0.6010  0.62000    0.6070   0.62000
# 17                    840     0.9470  0.96200    0.9550   0.96200
# 18                    977     0.9340  0.94900    0.9410   0.94900
# 19                   8173     0.9980  0.99900    0.9990   0.99900
# 20                      0        NaN      NaN       NaN       NaN
# 21                      0        NaN      NaN       NaN       NaN
# 22                      1        NaN      NaN       NaN       NaN
# 23                  34536     0.7948  0.80445    0.7975   0.80445
#
#     baseline (majority)  improvement
# 0               0.57300       0.9430
# 1               0.51200       0.8740
# 2               0.49100       0.7430
# 3               0.43700       0.6530
# 4               0.77700       0.6370
# 5               0.63500       0.6220
# 6               0.37800       0.5340
# 7               0.43900       0.5280
# 8               0.26600       0.5200
# 9               0.93800       0.4940
# 10              0.60200       0.4620
# 11              0.40400       0.4540
# 12              0.31100       0.4260
# 13              0.44500       0.4030
# 14              0.30700       0.3900
# 15              0.70800       0.3710
# 16              0.42300       0.3410
# 17              0.94400       0.3190
# 18              0.93800       0.1800
# 19              0.99900      -0.0000
# 20                  NaN          NaN
# 21                  NaN          NaN
# 22                  NaN          NaN
# 23              0.57635       0.4947

# %% [markdown]
# ## Drop chunk size related columns

# %%
import importlib
importlib.reload(classifier_utils)
ablation_group = 'size'
size_columns_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns, ablation=True, ablation_group=ablation_group)

# %%
report_size_columns = size_columns_result.get_report_df(include_overall=True)
report_size_columns
# Out:
#                                   project  observations  \
# 0                         CCI-MIT__XCoLab          5512
# 1                apache__directory-server           845
# 2                        jgralab__jgralab          2072
# 3   CloudStack-extras__CloudStack-archive          1424
# 4                        apache__accumulo          4113
# 5                        Unidata__thredds          1154
# 6                  Ramblurr__Anki-Android           892
# 7                     apache__lucene-solr          1256
# 8                  TeamDev-Ltd__OpenFaces          2979
# 9                         getrailo__railo           815
# 10                          freenet__fred          1268
# 11                              zkoss__zk          1087
# 12                        atlasapi__atlas          1107
# 13                           alexo__wro4j          1663
# 14      android__platform_frameworks_base          3557
# 15               hibernate__hibernate-orm          1000
# 16                 eucalyptus__eucalyptus          1020
# 17                  alkacon__opencms-core           923
# 18                   SINTEF-9012__ThingML          1022
# 19                  sebastianbenz__Jnario          8298
# 20                 elastic__elasticsearch          1246
# 21                 eclipse__jetty.project          1537
# 22            revolsys__com.revolsys.open           991
# 23                                Overall         45781
#
#     observations (wt NaN)  precision  recall  f1-score  accuracy  \
# 0                    3757     0.9770  0.9780   0.97700    0.9780
# 1                     652     0.9430  0.9450   0.94400    0.9450
# 2                    1802     0.8590  0.8620   0.85900    0.8620
# 3                    1106     0.7910  0.7970   0.79300    0.7970
# 4                    3148     0.8490  0.8590   0.85300    0.8590
# 5                     950     0.8890  0.8990   0.89300    0.8990
# 6                     759     0.7180  0.7420   0.72600    0.7420
# 7                     974     0.6230  0.6340   0.62800    0.6340
# 8                    2859     0.9640  0.9680   0.96600    0.9680
# 9                     572     0.6510  0.6640   0.65700    0.6640
# 10                   1012     0.6570  0.6640   0.65800    0.6640
# 11                    881     0.7570  0.7730   0.76400    0.7730
# 12                    782     0.6450  0.6650   0.65100    0.6650
# 13                   1368     0.5570  0.5640   0.56000    0.5640
# 14                   2460     0.8080  0.8150   0.81000    0.8150
# 15                    716     0.5460  0.5600   0.55100    0.5600
# 16                    747     0.5990  0.6200   0.60600    0.6200
# 17                    840     0.9460  0.9600   0.95200    0.9600
# 18                    977     0.9350  0.9460   0.94000    0.9460
# 19                   8173     0.9980  0.9990   0.99900    0.9990
# 20                      0        NaN     NaN       NaN       NaN
# 21                      0        NaN     NaN       NaN       NaN
# 22                      1        NaN     NaN       NaN       NaN
# 23                  34536     0.7856  0.7957   0.78935    0.7957
#
#     baseline (majority)  improvement
# 0               0.57300       0.9500
# 1               0.51200       0.8870
# 2               0.49100       0.7280
# 3               0.43700       0.6390
# 4               0.63500       0.6140
# 5               0.77700       0.5470
# 6               0.43900       0.5400
# 7               0.26600       0.5020
# 8               0.93800       0.4770
# 9               0.37800       0.4610
# 10              0.40400       0.4360
# 11              0.60200       0.4300
# 12              0.44500       0.3960
# 13              0.30700       0.3710
# 14              0.70800       0.3660
# 15              0.31100       0.3610
# 16              0.42300       0.3410
# 17              0.94400       0.2770
# 18              0.93800       0.1310
# 19              0.99900      -0.0000
# 20                  NaN          NaN
# 21                  NaN          NaN
# 22                  NaN          NaN
# 23              0.57635       0.4727

# %% [markdown]
# ## Drop chunk position related columns

# %%
import importlib
importlib.reload(classifier_utils)
ablation_group = 'position'
position_columns_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns, ablation=True, ablation_group=ablation_group)

# %%
report_position_columns = position_columns_result.get_report_df(include_overall=True)
report_position_columns
# Out:
#                                   project  observations  \
# 0                         CCI-MIT__XCoLab          5512
# 1                apache__directory-server           845
# 2                        jgralab__jgralab          2072
# 3   CloudStack-extras__CloudStack-archive          1424
# 4                        Unidata__thredds          1154
# 5                        apache__accumulo          4113
# 6                  Ramblurr__Anki-Android           892
# 7                         getrailo__railo           815
# 8                     apache__lucene-solr          1256
# 9                  TeamDev-Ltd__OpenFaces          2979
# 10                              zkoss__zk          1087
# 11                          freenet__fred          1268
# 12               hibernate__hibernate-orm          1000
# 13                           alexo__wro4j          1663
# 14                        atlasapi__atlas          1107
# 15      android__platform_frameworks_base          3557
# 16                 eucalyptus__eucalyptus          1020
# 17                  alkacon__opencms-core           923
# 18                   SINTEF-9012__ThingML          1022
# 19                  sebastianbenz__Jnario          8298
# 20                 elastic__elasticsearch          1246
# 21                 eclipse__jetty.project          1537
# 22            revolsys__com.revolsys.open           991
# 23                                Overall         45781
#
#     observations (wt NaN)  precision   recall  f1-score  accuracy  \
# 0                    3757     0.9720  0.97600    0.9740   0.97600
# 1                     652     0.9330  0.93700    0.9350   0.93700
# 2                    1802     0.8620  0.86500    0.8620   0.86500
# 3                    1106     0.7990  0.80500    0.8000   0.80500
# 4                     950     0.9170  0.92200    0.9180   0.92200
# 5                    3148     0.8570  0.86200    0.8590   0.86200
# 6                     759     0.7250  0.75000    0.7310   0.75000
# 7                     572     0.6950  0.71000    0.7010   0.71000
# 8                     974     0.6360  0.64200    0.6370   0.64200
# 9                    2859     0.9660  0.96900    0.9670   0.96900
# 10                    881     0.7640  0.78100    0.7710   0.78100
# 11                   1012     0.6620  0.67000    0.6640   0.67000
# 12                    716     0.5840  0.59100    0.5800   0.59100
# 13                   1368     0.5660  0.57700    0.5680   0.57700
# 14                    782     0.6430  0.65900    0.6460   0.65900
# 15                   2460     0.8150  0.82000    0.8150   0.82000
# 16                    747     0.6040  0.62400    0.6110   0.62400
# 17                    840     0.9470  0.96200    0.9550   0.96200
# 18                    977     0.9370  0.95000    0.9430   0.95000
# 19                   8173     0.9980  0.99900    0.9990   0.99900
# 20                      0        NaN      NaN       NaN       NaN
# 21                      0        NaN      NaN       NaN       NaN
# 22                      1        NaN      NaN       NaN       NaN
# 23                  34536     0.7941  0.80355    0.7968   0.80355
#
#     baseline (majority)  improvement
# 0               0.57300      0.94300
# 1               0.51200      0.87100
# 2               0.49100      0.73400
# 3               0.43700      0.65300
# 4               0.77700      0.65100
# 5               0.63500      0.62300
# 6               0.43900      0.55400
# 7               0.37800      0.53400
# 8               0.26600      0.51200
# 9               0.93800      0.50000
# 10              0.60200      0.45000
# 11              0.40400      0.44600
# 12              0.31100      0.40600
# 13              0.30700      0.38900
# 14              0.44500      0.38500
# 15              0.70800      0.38400
# 16              0.42300      0.34800
# 17              0.94400      0.31900
# 18              0.93800      0.19700
# 19              0.99900     -0.00000
# 20                  NaN          NaN
# 21                  NaN          NaN
# 22                  NaN          NaN
# 23              0.57635      0.49495

# %% [markdown]
# ## Drop chunk content related columns

# %%
import importlib
importlib.reload(classifier_utils)
ablation_group = 'content'
content_columns_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns, ablation=True, ablation_group=ablation_group)

# %%
report_content_columns = content_columns_result.get_report_df(include_overall=True)
report_content_columns
# Out:
#                                   project  observations  \
# 0                         CCI-MIT__XCoLab          5512
# 1                apache__directory-server           845
# 2                        jgralab__jgralab          2072
# 3   CloudStack-extras__CloudStack-archive          1424
# 4                        apache__accumulo          4113
# 5                        Unidata__thredds          1154
# 6                  Ramblurr__Anki-Android           892
# 7                         getrailo__railo           815
# 8                     apache__lucene-solr          1256
# 9                           freenet__fred          1268
# 10                              zkoss__zk          1087
# 11                 TeamDev-Ltd__OpenFaces          2979
# 12                           alexo__wro4j          1663
# 13               hibernate__hibernate-orm          1000
# 14      android__platform_frameworks_base          3557
# 15                        atlasapi__atlas          1107
# 16                 eucalyptus__eucalyptus          1020
# 17                  alkacon__opencms-core           923
# 18                   SINTEF-9012__ThingML          1022
# 19                  sebastianbenz__Jnario          8298
# 20                 elastic__elasticsearch          1246
# 21                 eclipse__jetty.project          1537
# 22            revolsys__com.revolsys.open           991
# 23                                Overall         45781
#
#     observations (wt NaN)  precision   recall  f1-score  accuracy  \
# 0                    3757     0.9700  0.97400    0.9720   0.97400
# 1                     652     0.9180  0.92200    0.9200   0.92200
# 2                    1802     0.8550  0.85700    0.8550   0.85700
# 3                    1106     0.8060  0.81100    0.8070   0.81100
# 4                    3148     0.8490  0.85800    0.8530   0.85800
# 5                     950     0.9020  0.90800    0.9040   0.90800
# 6                     759     0.7220  0.74700    0.7290   0.74700
# 7                     572     0.6870  0.70100    0.6930   0.70100
# 8                     974     0.6280  0.63300    0.6290   0.63300
# 9                    1012     0.6630  0.67500    0.6660   0.67500
# 10                    881     0.7630  0.77900    0.7690   0.77900
# 11                   2859     0.9630  0.96600    0.9640   0.96600
# 12                   1368     0.5730  0.58400    0.5750   0.58400
# 13                    716     0.5640  0.57700    0.5640   0.57700
# 14                   2460     0.8110  0.81800    0.8130   0.81800
# 15                    782     0.6270  0.64300    0.6280   0.64300
# 16                    747     0.5890  0.60800    0.5950   0.60800
# 17                    840     0.9470  0.96200    0.9540   0.96200
# 18                    977     0.9350  0.94900    0.9410   0.94900
# 19                   8173     0.9980  0.99900    0.9990   0.99900
# 20                      0        NaN      NaN       NaN       NaN
# 21                      0        NaN      NaN       NaN       NaN
# 22                      1        NaN      NaN       NaN       NaN
# 23                  34536     0.7885  0.79855    0.7915   0.79855
#
#     baseline (majority)  improvement
# 0               0.57300      0.93900
# 1               0.51200      0.84000
# 2               0.49100      0.72000
# 3               0.43700      0.66500
# 4               0.63500      0.61200
# 5               0.77700      0.59000
# 6               0.43900      0.54900
# 7               0.37800      0.52000
# 8               0.26600      0.50100
# 9               0.40400      0.45400
# 10              0.60200      0.44400
# 11              0.93800      0.44300
# 12              0.30700      0.40000
# 13              0.31100      0.38500
# 14              0.70800      0.37700
# 15              0.44500      0.35700
# 16              0.42300      0.32000
# 17              0.94400      0.31900
# 18              0.93800      0.18000
# 19              0.99900     -0.00000
# 20                  NaN          NaN
# 21                  NaN          NaN
# 22                  NaN          NaN
# 23              0.57635      0.48075

# %%
df_inner_rf = pd.merge(report_default, report_all_columns, on='project', how='inner', suffixes=('_default', '_all'))
df_inner_rf_authorship = report_authorship_columns.add_suffix("_author").rename(columns={"project_author": "project"})
df_inner_rf = pd.merge(df_inner_rf, df_inner_rf_authorship, on='project', how='inner')
df_inner_rf_complexity = report_complexity_columns.add_suffix("_complexity").rename(columns={"project_complexity": "project"})
df_inner_rf = pd.merge(df_inner_rf, df_inner_rf_complexity, on='project', how='inner')
df_inner_rf_size = report_size_columns.add_suffix("_size").rename(columns={"project_size": "project"})
df_inner_rf = pd.merge(df_inner_rf, df_inner_rf_size, on='project', how='inner')
df_inner_rf_position = report_position_columns.add_suffix("_position").rename(columns={"project_position": "project"})
df_inner_rf = pd.merge(df_inner_rf, df_inner_rf_position, on='project', how='inner')
df_inner_rf_content = report_content_columns.add_suffix("_content").rename(columns={"project_content": "project"})
df_inner_rf = pd.merge(df_inner_rf, df_inner_rf_content, on='project', how='inner')

accuracy_rf = df_inner_rf.filter(regex=("project|accuracy.*")).copy()
accuracy_rf
# Out:
#                                   project  accuracy_default  accuracy_all  \
# 0                         CCI-MIT__XCoLab           0.97600        0.9780
# 1                apache__directory-server           0.93700        0.9230
# 2                        jgralab__jgralab           0.86600        0.7130
# 3   CloudStack-extras__CloudStack-archive           0.80600        0.6200
# 4                        apache__accumulo           0.86300        0.7970
# 5                        Unidata__thredds           0.91600        0.8220
# 6                  Ramblurr__Anki-Android           0.74200        0.7060
# 7                         getrailo__railo           0.71200        0.6330
# 8                     apache__lucene-solr           0.64600        0.5610
# 9                  TeamDev-Ltd__OpenFaces           0.96900        0.9520
# 10                          freenet__fred           0.67900        0.6380
# 11                              zkoss__zk           0.78300        0.7590
# 12               hibernate__hibernate-orm           0.60100        0.4660
# 13                        atlasapi__atlas           0.67300        0.6160
# 14                           alexo__wro4j           0.58400        0.4800
# 15      android__platform_frameworks_base           0.81700        0.7980
# 16                 eucalyptus__eucalyptus           0.61700        0.6010
# 17                  alkacon__opencms-core           0.96200        0.9600
# 18                   SINTEF-9012__ThingML           0.94900        0.9420
# 19                  sebastianbenz__Jnario           0.99900        0.9990
# 20                 elastic__elasticsearch               NaN           NaN
# 21                 eclipse__jetty.project               NaN           NaN
# 22            revolsys__com.revolsys.open               NaN           NaN
# 23                                Overall           0.80485        0.7482
#
#     accuracy_author  accuracy_complexity  accuracy_size  accuracy_position  \
# 0           0.97600              0.97600         0.9780            0.97600
# 1           0.93300              0.93900         0.9450            0.93700
# 2           0.86100              0.86900         0.8620            0.86500
# 3           0.79800              0.80500         0.7970            0.80500
# 4           0.85700              0.86200         0.8590            0.86200
# 5           0.90500              0.91900         0.8990            0.92200
# 6           0.73400              0.73500         0.7420            0.75000
# 7           0.71000              0.71000         0.6640            0.71000
# 8           0.63900              0.64800         0.6340            0.64200
# 9           0.97000              0.96900         0.9680            0.96900
# 10          0.67300              0.67500         0.6640            0.67000
# 11          0.77800              0.78500         0.7730            0.78100
# 12          0.58500              0.60500         0.5600            0.59100
# 13          0.63900              0.66900         0.6650            0.65900
# 14          0.58700              0.57700         0.5640            0.57700
# 15          0.81300              0.81600         0.8150            0.82000
# 16          0.61300              0.62000         0.6200            0.62400
# 17          0.96200              0.96200         0.9600            0.96200
# 18          0.94900              0.94900         0.9460            0.95000
# 19          0.99900              0.99900         0.9990            0.99900
# 20              NaN                  NaN            NaN                NaN
# 21              NaN                  NaN            NaN                NaN
# 22              NaN                  NaN            NaN                NaN
# 23          0.79905              0.80445         0.7957            0.80355
#
#     accuracy_content
# 0            0.97400
# 1            0.92200
# 2            0.85700
# 3            0.81100
# 4            0.85800
# 5            0.90800
# 6            0.74700
# 7            0.70100
# 8            0.63300
# 9            0.96600
# 10           0.67500
# 11           0.77900
# 12           0.57700
# 13           0.64300
# 14           0.58400
# 15           0.81800
# 16           0.60800
# 17           0.96200
# 18           0.94900
# 19           0.99900
# 20               NaN
# 21               NaN
# 22               NaN
# 23           0.79855

# %%
accuracy_rf_improv = accuracy_rf[accuracy_rf['project']=='Overall'].copy()
accuracy_rf_improv['improv._all'] = accuracy_rf_improv.apply(lambda x: classifier_utils.get_normalized_improvement(x['accuracy_all'], x['accuracy_default']), axis=1)
accuracy_rf_improv['improv._author'] = accuracy_rf_improv.apply(lambda x: classifier_utils.get_normalized_improvement(x['accuracy_author'], x['accuracy_default']), axis=1)
accuracy_rf_improv['improv._complexity'] = accuracy_rf_improv.apply(lambda x: classifier_utils.get_normalized_improvement(x['accuracy_complexity'], x['accuracy_default']), axis=1)
accuracy_rf_improv['improv._size'] = accuracy_rf_improv.apply(lambda x: classifier_utils.get_normalized_improvement(x['accuracy_size'], x['accuracy_default']), axis=1)
accuracy_rf_improv['improv._position'] = accuracy_rf_improv.apply(lambda x: classifier_utils.get_normalized_improvement(x['accuracy_position'], x['accuracy_default']), axis=1)
accuracy_rf_improv['improv._content'] = accuracy_rf_improv.apply(lambda x: classifier_utils.get_normalized_improvement(x['accuracy_content'], x['accuracy_default']), axis=1)
accuracy_rf_improv.transpose()
# Out:
#                               23
# project                  Overall
# accuracy_default         0.80485
# accuracy_all              0.7482
# accuracy_author          0.79905
# accuracy_complexity      0.80445
# accuracy_size             0.7957
# accuracy_position        0.80355
# accuracy_content         0.79855
# improv._all           -0.0703858
# improv._author       -0.00720631
# improv._complexity  -0.000496987
# improv._size          -0.0113686
# improv._position     -0.00161521
# improv._content      -0.00782755
