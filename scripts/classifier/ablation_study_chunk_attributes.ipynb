# %% [markdown]
# Goal of this notebook:
#
# Investigate the impact on the classifier accuracy of removing groups of attributes related to the conflicting chunks.
#
# Attributes groups:
#
# - Authorship: self_conflict_perc, authors involved
# - Complexity: leftCC, rightCC
# - Size: chunkAbsSize, chunkRelSize, chunk_left_abs_size, chunk_left_rel_size, chunk_right_abs_size, chunk_right_rel_size
# - Position: chunkPosition
# - Content: Programming language constructs

# %%
import numpy as np
import pandas as pd
from IPython.core.display import display

pd.set_option('display.max_columns', None)
from sklearn.ensemble import RandomForestClassifier

import warnings
import classifier_utils
import configs
warnings.filterwarnings("ignore", category=UserWarning)

# %%
non_features_columns = ["chunk_id", "line_start", "line_end", "line_separator", "kind_conflict", "url", "project"]
non_features_columns.extend(["project_user", "project_name", "path", "file_name", "sha", "leftsha", "rightsha", "basesha"])

# %%
selected_dataset = pd.read_csv("../../data/SELECTED_LABELLED_DATASET.csv")
projects = list(selected_dataset['project'].unique())

# %%
rf = RandomForestClassifier(random_state=99, n_jobs=5, n_estimators=400, max_features=0.3, min_samples_leaf=1)# Decision Tree

# %%
default_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns)
report_default = default_result.get_report_df(include_overall=True)

# %% [markdown]
# ## Drop all chunk related columns

# %%
import importlib
importlib.reload(classifier_utils)
ablation_group = 'all'
all_columns_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns, ablation=True, ablation_group=ablation_group)

# %%
report_all_columns = all_columns_result.get_report_df(include_overall=True)
report_all_columns
# Out:
#                                   project  observations  \
# 0                         CCI-MIT__XCoLab          5512
# 1                apache__directory-server           845
# 2                  Ramblurr__Anki-Android           892
# 3                        apache__accumulo          4113
# 4                        jgralab__jgralab          2072
# 5                         getrailo__railo           815
# 6                     apache__lucene-solr          1256
# 7                               zkoss__zk          1087
# 8                           freenet__fred          1268
# 9   CloudStack-extras__CloudStack-archive          1424
# 10                 eucalyptus__eucalyptus          1020
# 11                        atlasapi__atlas          1107
# 12      android__platform_frameworks_base          3557
# 13                  alkacon__opencms-core           923
# 14                           alexo__wro4j          1663
# 15               hibernate__hibernate-orm          1000
# 16                 TeamDev-Ltd__OpenFaces          2979
# 17                       Unidata__thredds          1154
# 18                   SINTEF-9012__ThingML          1022
# 19                  sebastianbenz__Jnario          8298
# 20                                Overall         42007
#
#     observations (wt NaN)  precision  recall  f1-score  accuracy  \
# 0                    3757     0.9730  0.9780   0.97500    0.9780
# 1                     652     0.9220  0.9230   0.92200    0.9230
# 2                     759     0.6810  0.7060   0.69100    0.7060
# 3                    3148     0.7880  0.7970   0.79200    0.7970
# 4                    1802     0.7090  0.7130   0.70900    0.7130
# 5                     572     0.6210  0.6330   0.62500    0.6330
# 6                     974     0.5520  0.5610   0.55600    0.5610
# 7                     881     0.7500  0.7590   0.75400    0.7590
# 8                    1012     0.6270  0.6380   0.63200    0.6380
# 9                    1106     0.6060  0.6200   0.61200    0.6200
# 10                    747     0.5870  0.6010   0.59300    0.6010
# 11                    782     0.6020  0.6160   0.60400    0.6160
# 12                   2460     0.7880  0.7980   0.79200    0.7980
# 13                    840     0.9500  0.9600   0.95500    0.9600
# 14                   1368     0.4720  0.4800   0.47600    0.4800
# 15                    716     0.4540  0.4660   0.45900    0.4660
# 16                   2859     0.9460  0.9520   0.94800    0.9520
# 17                    950     0.7900  0.8220   0.80200    0.8220
# 18                    977     0.9260  0.9420   0.93300    0.9420
# 19                   8173     0.9980  0.9990   0.99900    0.9990
# 20                  34535     0.7371  0.7482   0.74145    0.7482
#
#     baseline (majority)  improvement
# 0               0.57300      0.94800
# 1               0.51200      0.84300
# 2               0.43900      0.47700
# 3               0.63500      0.44400
# 4               0.49100      0.43500
# 5               0.37800      0.41000
# 6               0.26600      0.40100
# 7               0.60200      0.39600
# 8               0.40400      0.39300
# 9               0.43700      0.32600
# 10              0.42300      0.30900
# 11              0.44500      0.30900
# 12              0.70800      0.30700
# 13              0.94400      0.27700
# 14              0.30700      0.25000
# 15              0.31100      0.22500
# 16              0.93800      0.22200
# 17              0.77700      0.20300
# 18              0.93800      0.06600
# 19              0.99900      0.00000
# 20              0.57635      0.36205

# %% [markdown]
# ## Drop chunk authorship related columns

# %%
import importlib
importlib.reload(classifier_utils)
ablation_group = 'authorship'
authorship_columns_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns, ablation=True, ablation_group=ablation_group)

# %%
report_authorship_columns = authorship_columns_result.get_report_df(include_overall=True)
report_authorship_columns
# Out:
#                                   project  observations  \
# 0                         CCI-MIT__XCoLab          5512
# 1                apache__directory-server           845
# 2                        jgralab__jgralab          2072
# 3   CloudStack-extras__CloudStack-archive          1424
# 4                        apache__accumulo          4113
# 5                        Unidata__thredds          1154
# 6                         getrailo__railo           815
# 7                  Ramblurr__Anki-Android           892
# 8                     apache__lucene-solr          1256
# 9                  TeamDev-Ltd__OpenFaces          2979
# 10                              zkoss__zk          1087
# 11                          freenet__fred          1268
# 12                           alexo__wro4j          1663
# 13               hibernate__hibernate-orm          1000
# 14                        atlasapi__atlas          1107
# 15      android__platform_frameworks_base          3557
# 16                 eucalyptus__eucalyptus          1020
# 17                  alkacon__opencms-core           923
# 18                   SINTEF-9012__ThingML          1022
# 19                  sebastianbenz__Jnario          8298
# 20                                Overall         42007
#
#     observations (wt NaN)  precision   recall  f1-score  accuracy  \
# 0                    3757    0.97200  0.97600   0.97300   0.97600
# 1                     652    0.93100  0.93400   0.93200   0.93400
# 2                    1802    0.85900  0.86100   0.85900   0.86100
# 3                    1106    0.79600  0.80200   0.79700   0.80200
# 4                    3148    0.85200  0.85700   0.85400   0.85700
# 5                     950    0.90200  0.90900   0.90300   0.90900
# 6                     572    0.69600  0.71200   0.70200   0.71200
# 7                     759    0.71400  0.73900   0.72000   0.73900
# 8                     974    0.62900  0.63600   0.63000   0.63600
# 9                    2859    0.96600  0.96900   0.96700   0.96900
# 10                    881    0.76800  0.78300   0.77300   0.78300
# 11                   1012    0.66500  0.67200   0.66600   0.67200
# 12                   1368    0.57100  0.58300   0.57400   0.58300
# 13                    716    0.57200  0.58200   0.57100   0.58200
# 14                    782    0.63800  0.65300   0.64000   0.65300
# 15                   2460    0.80600  0.81400   0.80800   0.81400
# 16                    747    0.60500  0.62400   0.61100   0.62400
# 17                    840    0.94800  0.96200   0.95500   0.96200
# 18                    977    0.93500  0.95000   0.94100   0.95000
# 19                   8173    0.99800  0.99900   0.99900   0.99900
# 20                  34535    0.79115  0.80085   0.79375   0.80085
#
#     baseline (majority)  improvement
# 0               0.57300       0.9430
# 1               0.51200       0.8650
# 2               0.49100       0.7270
# 3               0.43700       0.6480
# 4               0.63500       0.6090
# 5               0.77700       0.5940
# 6               0.37800       0.5370
# 7               0.43900       0.5350
# 8               0.26600       0.5030
# 9               0.93800       0.4940
# 10              0.60200       0.4560
# 11              0.40400       0.4490
# 12              0.30700       0.3990
# 13              0.31100       0.3940
# 14              0.44500       0.3760
# 15              0.70800       0.3630
# 16              0.42300       0.3480
# 17              0.94400       0.3190
# 18              0.93800       0.1970
# 19              0.99900      -0.0000
# 20              0.57635       0.4878

# %% [markdown]
# ## Drop chunk complexity related columns

# %%
import importlib
importlib.reload(classifier_utils)
ablation_group = 'complexity'
complexity_columns_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns, ablation=True, ablation_group=ablation_group)

# %%
report_complexity_columns = complexity_columns_result.get_report_df(include_overall=True)
report_complexity_columns
# Out:
#                                   project  observations  \
# 0                         CCI-MIT__XCoLab          5512
# 1                apache__directory-server           845
# 2                        jgralab__jgralab          2072
# 3   CloudStack-extras__CloudStack-archive          1424
# 4                        Unidata__thredds          1154
# 5                        apache__accumulo          4113
# 6                  Ramblurr__Anki-Android           892
# 7                         getrailo__railo           815
# 8                     apache__lucene-solr          1256
# 9                  TeamDev-Ltd__OpenFaces          2979
# 10                              zkoss__zk          1087
# 11                          freenet__fred          1268
# 12               hibernate__hibernate-orm          1000
# 13                        atlasapi__atlas          1107
# 14                           alexo__wro4j          1663
# 15      android__platform_frameworks_base          3557
# 16                 eucalyptus__eucalyptus          1020
# 17                  alkacon__opencms-core           923
# 18                   SINTEF-9012__ThingML          1022
# 19                  sebastianbenz__Jnario          8298
# 20                                Overall         42007
#
#     observations (wt NaN)  precision   recall  f1-score  accuracy  \
# 0                    3757      0.972  0.97600   0.97400   0.97600
# 1                     652      0.936  0.94000   0.93800   0.94000
# 2                    1802      0.867  0.86900   0.86700   0.86900
# 3                    1106      0.799  0.80400   0.80000   0.80400
# 4                     950      0.916  0.92000   0.91600   0.92000
# 5                    3148      0.855  0.86100   0.85700   0.86100
# 6                     759      0.719  0.74000   0.72300   0.74000
# 7                     572      0.691  0.70600   0.69700   0.70600
# 8                     974      0.637  0.64400   0.63800   0.64400
# 9                    2859      0.965  0.96900   0.96600   0.96900
# 10                    881      0.775  0.79000   0.78100   0.79000
# 11                   1012      0.660  0.66900   0.66300   0.66900
# 12                    716      0.591  0.60800   0.59300   0.60800
# 13                    782      0.657  0.67100   0.65900   0.67100
# 14                   1368      0.567  0.57700   0.56800   0.57700
# 15                   2460      0.815  0.82000   0.81600   0.82000
# 16                    747      0.600  0.62100   0.60700   0.62100
# 17                    840      0.947  0.96200   0.95500   0.96200
# 18                    977      0.933  0.94700   0.94000   0.94700
# 19                   8173      0.998  0.99900   0.99900   0.99900
# 20                  34535      0.795  0.80465   0.79785   0.80465
#
#     baseline (majority)  improvement
# 0               0.57300       0.9430
# 1               0.51200       0.8770
# 2               0.49100       0.7430
# 3               0.43700       0.6520
# 4               0.77700       0.6420
# 5               0.63500       0.6180
# 6               0.43900       0.5380
# 7               0.37800       0.5280
# 8               0.26600       0.5150
# 9               0.93800       0.4890
# 10              0.60200       0.4730
# 11              0.40400       0.4440
# 12              0.31100       0.4300
# 13              0.44500       0.4080
# 14              0.30700       0.3900
# 15              0.70800       0.3840
# 16              0.42300       0.3430
# 17              0.94400       0.3190
# 18              0.93800       0.1480
# 19              0.99900      -0.0000
# 20              0.57635       0.4942

# %% [markdown]
# ## Drop chunk size related columns

# %%
import importlib
importlib.reload(classifier_utils)
ablation_group = 'size'
size_columns_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns, ablation=True, ablation_group=ablation_group)

# %%
report_size_columns = size_columns_result.get_report_df(include_overall=True)
report_size_columns
# Out:
#                                   project  observations  \
# 0                         CCI-MIT__XCoLab          5512
# 1                apache__directory-server           845
# 2                        jgralab__jgralab          2072
# 3   CloudStack-extras__CloudStack-archive          1424
# 4                        apache__accumulo          4113
# 5                        Unidata__thredds          1154
# 6                  Ramblurr__Anki-Android           892
# 7                     apache__lucene-solr          1256
# 8                  TeamDev-Ltd__OpenFaces          2979
# 9                         getrailo__railo           815
# 10                          freenet__fred          1268
# 11                              zkoss__zk          1087
# 12                        atlasapi__atlas          1107
# 13                           alexo__wro4j          1663
# 14               hibernate__hibernate-orm          1000
# 15      android__platform_frameworks_base          3557
# 16                 eucalyptus__eucalyptus          1020
# 17                  alkacon__opencms-core           923
# 18                   SINTEF-9012__ThingML          1022
# 19                  sebastianbenz__Jnario          8298
# 20                                Overall         42007
#
#     observations (wt NaN)  precision   recall  f1-score  accuracy  \
# 0                    3757    0.97700  0.97800    0.9770   0.97800
# 1                     652    0.94500  0.94600    0.9450   0.94600
# 2                    1802    0.86600  0.86800    0.8660   0.86800
# 3                    1106    0.79600  0.80100    0.7970   0.80100
# 4                    3148    0.84800  0.85800    0.8530   0.85800
# 5                     950    0.89300  0.90200    0.8970   0.90200
# 6                     759    0.71200  0.73500    0.7200   0.73500
# 7                     974    0.62200  0.63100    0.6260   0.63100
# 8                    2859    0.96400  0.96700    0.9660   0.96700
# 9                     572    0.64400  0.65900    0.6510   0.65900
# 10                   1012    0.65300  0.66100    0.6550   0.66100
# 11                    881    0.75200  0.76800    0.7590   0.76800
# 12                    782    0.65400  0.67100    0.6590   0.67100
# 13                   1368    0.56300  0.56900    0.5650   0.56900
# 14                    716    0.55000  0.56400    0.5540   0.56400
# 15                   2460    0.80800  0.81500    0.8100   0.81500
# 16                    747    0.60500  0.62500    0.6120   0.62500
# 17                    840    0.94700  0.96100    0.9540   0.96100
# 18                    977    0.93600  0.94700    0.9410   0.94700
# 19                   8173    0.99800  0.99900    0.9990   0.99900
# 20                  34535    0.78665  0.79625    0.7903   0.79625
#
#     baseline (majority)  improvement
# 0               0.57300       0.9490
# 1               0.51200       0.8900
# 2               0.49100       0.7420
# 3               0.43700       0.6470
# 4               0.63500       0.6110
# 5               0.77700       0.5610
# 6               0.43900       0.5280
# 7               0.26600       0.4980
# 8               0.93800       0.4720
# 9               0.37800       0.4520
# 10              0.40400       0.4310
# 11              0.60200       0.4190
# 12              0.44500       0.4080
# 13              0.30700       0.3790
# 14              0.31100       0.3670
# 15              0.70800       0.3660
# 16              0.42300       0.3500
# 17              0.94400       0.2980
# 18              0.93800       0.1480
# 19              0.99900      -0.0000
# 20              0.57635       0.4758

# %% [markdown]
# ## Drop chunk position related columns

# %%
import importlib
importlib.reload(classifier_utils)
ablation_group = 'position'
position_columns_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns, ablation=True, ablation_group=ablation_group)

# %%
report_position_columns = position_columns_result.get_report_df(include_overall=True)
report_position_columns
# Out:
#                                   project  observations  \
# 0                         CCI-MIT__XCoLab          5512
# 1                apache__directory-server           845
# 2                        jgralab__jgralab          2072
# 3   CloudStack-extras__CloudStack-archive          1424
# 4                        Unidata__thredds          1154
# 5                        apache__accumulo          4113
# 6                         getrailo__railo           815
# 7                  Ramblurr__Anki-Android           892
# 8                     apache__lucene-solr          1256
# 9                  TeamDev-Ltd__OpenFaces          2979
# 10                              zkoss__zk          1087
# 11                          freenet__fred          1268
# 12               hibernate__hibernate-orm          1000
# 13                           alexo__wro4j          1663
# 14                        atlasapi__atlas          1107
# 15      android__platform_frameworks_base          3557
# 16                 eucalyptus__eucalyptus          1020
# 17                  alkacon__opencms-core           923
# 18                   SINTEF-9012__ThingML          1022
# 19                  sebastianbenz__Jnario          8298
# 20                                Overall         42007
#
#     observations (wt NaN)  precision  recall  f1-score  accuracy  \
# 0                    3757    0.97200   0.975   0.97300     0.975
# 1                     652    0.93700   0.940   0.93900     0.940
# 2                    1802    0.86300   0.865   0.86300     0.865
# 3                    1106    0.80000   0.806   0.80000     0.806
# 4                     950    0.91300   0.919   0.91400     0.919
# 5                    3148    0.85700   0.864   0.86000     0.864
# 6                     572    0.70900   0.722   0.71300     0.722
# 7                     759    0.71500   0.740   0.72200     0.740
# 8                     974    0.63300   0.641   0.63500     0.641
# 9                    2859    0.96600   0.969   0.96700     0.969
# 10                    881    0.77400   0.790   0.78000     0.790
# 11                   1012    0.67600   0.684   0.67800     0.684
# 12                    716    0.57700   0.591   0.57800     0.591
# 13                   1368    0.56900   0.580   0.57200     0.580
# 14                    782    0.64600   0.661   0.64900     0.661
# 15                   2460    0.81300   0.820   0.81500     0.820
# 16                    747    0.60300   0.624   0.61000     0.624
# 17                    840    0.94700   0.962   0.95500     0.962
# 18                    977    0.93500   0.948   0.94100     0.948
# 19                   8173    0.99800   0.999   0.99900     0.999
# 20                  34535    0.79515   0.805   0.79815     0.805
#
#     baseline (majority)  improvement
# 0               0.57300       0.9410
# 1               0.51200       0.8770
# 2               0.49100       0.7350
# 3               0.43700       0.6550
# 4               0.77700       0.6370
# 5               0.63500       0.6270
# 6               0.37800       0.5530
# 7               0.43900       0.5380
# 8               0.26600       0.5100
# 9               0.93800       0.4940
# 10              0.60200       0.4730
# 11              0.40400       0.4690
# 12              0.31100       0.4060
# 13              0.30700       0.3930
# 14              0.44500       0.3890
# 15              0.70800       0.3820
# 16              0.42300       0.3480
# 17              0.94400       0.3190
# 18              0.93800       0.1640
# 19              0.99900      -0.0000
# 20              0.57635       0.4955

# %% [markdown]
# ## Drop chunk content related columns

# %%
import importlib
importlib.reload(classifier_utils)
ablation_group = 'content'
content_columns_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns, ablation=True, ablation_group=ablation_group)

# %%
report_content_columns = content_columns_result.get_report_df(include_overall=True)
report_content_columns
# Out:
#                                   project  observations  \
# 0                         CCI-MIT__XCoLab          5512
# 1                apache__directory-server           845
# 2                        jgralab__jgralab          2072
# 3   CloudStack-extras__CloudStack-archive          1424
# 4                        apache__accumulo          4113
# 5                        Unidata__thredds          1154
# 6                  Ramblurr__Anki-Android           892
# 7                         getrailo__railo           815
# 8                     apache__lucene-solr          1256
# 9                           freenet__fred          1268
# 10                 TeamDev-Ltd__OpenFaces          2979
# 11                              zkoss__zk          1087
# 12                           alexo__wro4j          1663
# 13      android__platform_frameworks_base          3557
# 14               hibernate__hibernate-orm          1000
# 15                        atlasapi__atlas          1107
# 16                 eucalyptus__eucalyptus          1020
# 17                  alkacon__opencms-core           923
# 18                   SINTEF-9012__ThingML          1022
# 19                  sebastianbenz__Jnario          8298
# 20                                Overall         42007
#
#     observations (wt NaN)  precision   recall  f1-score  accuracy  \
# 0                    3757    0.97000  0.97300    0.9710   0.97300
# 1                     652    0.92000  0.92300    0.9210   0.92300
# 2                    1802    0.85500  0.85700    0.8550   0.85700
# 3                    1106    0.80200  0.80700    0.8020   0.80700
# 4                    3148    0.85000  0.85800    0.8530   0.85800
# 5                     950    0.90100  0.90700    0.9020   0.90700
# 6                     759    0.71800  0.74300    0.7250   0.74300
# 7                     572    0.69200  0.70800    0.6990   0.70800
# 8                     974    0.63300  0.63800    0.6340   0.63800
# 9                    1012    0.66000  0.67100    0.6640   0.67100
# 10                   2859    0.96200  0.96500    0.9640   0.96500
# 11                    881    0.75800  0.77400    0.7650   0.77400
# 12                   1368    0.56600  0.57700    0.5670   0.57700
# 13                   2460    0.81500  0.82000    0.8160   0.82000
# 14                    716    0.55500  0.56800    0.5540   0.56800
# 15                    782    0.62900  0.64700    0.6310   0.64700
# 16                    747    0.59400  0.61300    0.6000   0.61300
# 17                    840    0.94700  0.96100    0.9540   0.96100
# 18                    977    0.93400  0.94800    0.9400   0.94800
# 19                   8173    0.99800  0.99900    0.9990   0.99900
# 20                  34535    0.78795  0.79785    0.7908   0.79785
#
#     baseline (majority)  improvement
# 0               0.57300      0.93800
# 1               0.51200      0.84300
# 2               0.49100      0.72000
# 3               0.43700      0.65800
# 4               0.63500      0.61200
# 5               0.77700      0.58500
# 6               0.43900      0.54200
# 7               0.37800      0.53100
# 8               0.26600      0.50600
# 9               0.40400      0.44800
# 10              0.93800      0.43800
# 11              0.60200      0.43300
# 12              0.30700      0.38900
# 13              0.70800      0.38400
# 14              0.31100      0.37300
# 15              0.44500      0.36400
# 16              0.42300      0.32900
# 17              0.94400      0.29800
# 18              0.93800      0.16400
# 19              0.99900     -0.00000
# 20              0.57635      0.47775

# %%
df_inner_rf = pd.merge(report_default, report_all_columns, on='project', how='inner', suffixes=('_default', '_all'))
df_inner_rf_authorship = report_authorship_columns.add_suffix("_author").rename(columns={"project_author": "project"})
df_inner_rf = pd.merge(df_inner_rf, df_inner_rf_authorship, on='project', how='inner')
df_inner_rf_complexity = report_complexity_columns.add_suffix("_complexity").rename(columns={"project_complexity": "project"})
df_inner_rf = pd.merge(df_inner_rf, df_inner_rf_complexity, on='project', how='inner')
df_inner_rf_size = report_size_columns.add_suffix("_size").rename(columns={"project_size": "project"})
df_inner_rf = pd.merge(df_inner_rf, df_inner_rf_size, on='project', how='inner')
df_inner_rf_position = report_position_columns.add_suffix("_position").rename(columns={"project_position": "project"})
df_inner_rf = pd.merge(df_inner_rf, df_inner_rf_position, on='project', how='inner')
df_inner_rf_content = report_content_columns.add_suffix("_content").rename(columns={"project_content": "project"})
df_inner_rf = pd.merge(df_inner_rf, df_inner_rf_content, on='project', how='inner')

accuracy_rf = df_inner_rf.filter(regex=("project|accuracy.*")).copy()
accuracy_rf
# Out:
#                                   project  accuracy_default  accuracy_all  \
# 0                         CCI-MIT__XCoLab           0.97600        0.9780
# 1                apache__directory-server           0.94200        0.9230
# 2                        jgralab__jgralab           0.87000        0.7130
# 3   CloudStack-extras__CloudStack-archive           0.80400        0.6200
# 4                        Unidata__thredds           0.92100        0.8220
# 5                        apache__accumulo           0.86300        0.7970
# 6                  Ramblurr__Anki-Android           0.73600        0.7060
# 7                     apache__lucene-solr           0.65000        0.5610
# 8                         getrailo__railo           0.70300        0.6330
# 9                  TeamDev-Ltd__OpenFaces           0.97000        0.9520
# 10                              zkoss__zk           0.78800        0.7590
# 11                          freenet__fred           0.67800        0.6380
# 12               hibernate__hibernate-orm           0.59800        0.4660
# 13                           alexo__wro4j           0.59000        0.4800
# 14                        atlasapi__atlas           0.66600        0.6160
# 15      android__platform_frameworks_base           0.81700        0.7980
# 16                 eucalyptus__eucalyptus           0.62500        0.6010
# 17                  alkacon__opencms-core           0.96200        0.9600
# 18                   SINTEF-9012__ThingML           0.94900        0.9420
# 19                  sebastianbenz__Jnario           0.99900        0.9990
# 20                                Overall           0.80535        0.7482
#
#     accuracy_author  accuracy_complexity  accuracy_size  accuracy_position  \
# 0           0.97600              0.97600        0.97800              0.975
# 1           0.93400              0.94000        0.94600              0.940
# 2           0.86100              0.86900        0.86800              0.865
# 3           0.80200              0.80400        0.80100              0.806
# 4           0.90900              0.92000        0.90200              0.919
# 5           0.85700              0.86100        0.85800              0.864
# 6           0.73900              0.74000        0.73500              0.740
# 7           0.63600              0.64400        0.63100              0.641
# 8           0.71200              0.70600        0.65900              0.722
# 9           0.96900              0.96900        0.96700              0.969
# 10          0.78300              0.79000        0.76800              0.790
# 11          0.67200              0.66900        0.66100              0.684
# 12          0.58200              0.60800        0.56400              0.591
# 13          0.58300              0.57700        0.56900              0.580
# 14          0.65300              0.67100        0.67100              0.661
# 15          0.81400              0.82000        0.81500              0.820
# 16          0.62400              0.62100        0.62500              0.624
# 17          0.96200              0.96200        0.96100              0.962
# 18          0.95000              0.94700        0.94700              0.948
# 19          0.99900              0.99900        0.99900              0.999
# 20          0.80085              0.80465        0.79625              0.805
#
#     accuracy_content
# 0            0.97300
# 1            0.92300
# 2            0.85700
# 3            0.80700
# 4            0.90700
# 5            0.85800
# 6            0.74300
# 7            0.63800
# 8            0.70800
# 9            0.96500
# 10           0.77400
# 11           0.67100
# 12           0.56800
# 13           0.57700
# 14           0.64700
# 15           0.82000
# 16           0.61300
# 17           0.96100
# 18           0.94800
# 19           0.99900
# 20           0.79785

# %%
accuracy_rf_improv = accuracy_rf[accuracy_rf['project']=='Overall'].copy()
accuracy_rf_improv['improv._all'] = accuracy_rf_improv.apply(lambda x: classifier_utils.get_normalized_improvement(x['accuracy_all'], x['accuracy_default']), axis=1)
accuracy_rf_improv['improv._author'] = accuracy_rf_improv.apply(lambda x: classifier_utils.get_normalized_improvement(x['accuracy_author'], x['accuracy_default']), axis=1)
accuracy_rf_improv['improv._complexity'] = accuracy_rf_improv.apply(lambda x: classifier_utils.get_normalized_improvement(x['accuracy_complexity'], x['accuracy_default']), axis=1)
accuracy_rf_improv['improv._size'] = accuracy_rf_improv.apply(lambda x: classifier_utils.get_normalized_improvement(x['accuracy_size'], x['accuracy_default']), axis=1)
accuracy_rf_improv['improv._position'] = accuracy_rf_improv.apply(lambda x: classifier_utils.get_normalized_improvement(x['accuracy_position'], x['accuracy_default']), axis=1)
accuracy_rf_improv['improv._content'] = accuracy_rf_improv.apply(lambda x: classifier_utils.get_normalized_improvement(x['accuracy_content'], x['accuracy_default']), axis=1)
accuracy_rf_improv.transpose()
# Out:
#                            20
# project               Overall
# accuracy_default      0.80535
# accuracy_all           0.7482
# accuracy_author       0.80085
# accuracy_complexity   0.80465
# accuracy_size         0.79625
# accuracy_position       0.805
# accuracy_content      0.79785
# improv._all         -0.070963
# improv._author      -0.005588
# improv._complexity  -0.000869
# improv._size        -0.011299
# improv._position    -0.000435
# improv._content     -0.009313
