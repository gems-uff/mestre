# %% [markdown]
# Goal of this notebook:
#
# Investigate the impact on the classifier accuracy of adding each group of attributes related to the conflicting chunks.
#
# Attributes groups:
#
# - Authorship: self_conflict_perc, authors involved
# - Complexity: leftCC, rightCC
# - Size: chunkAbsSize, chunkRelSize, chunk_left_abs_size, chunk_left_rel_size, chunk_right_abs_size, chunk_right_rel_size
# - Position: chunkPosition
# - Content: Programming language constructs

# %%
import numpy as np
import pandas as pd
from IPython.core.display import display

pd.set_option('display.max_columns', None)
from sklearn.ensemble import RandomForestClassifier
import warnings
import classifier_utils
import configs
warnings.filterwarnings("ignore", category=UserWarning)

# %%
non_features_columns = ["chunk_id", "line_start", "line_end", "line_separator", "kind_conflict", "url", "project"]
non_features_columns.extend(["project_user", "project_name", "path", "file_name", "sha", "leftsha", "rightsha", "basesha"])

# %%
selected_dataset = pd.read_csv("../../data/SELECTED_LABELLED_DATASET.csv")
projects = list(selected_dataset['project'].unique())

# %%
rf = RandomForestClassifier(random_state=99, n_jobs=5, n_estimators=400, max_features=0.3, min_samples_leaf=1)# Decision Tree

# %%
default_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns)
report_default = default_result.get_report_df(include_overall=True)

# %% [markdown]
# ## Use no chunk related columns

# %%
import importlib
importlib.reload(classifier_utils)
ablation_group = 'all'
none_columns_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns, ablation=True, ablation_group=ablation_group, ablation_mode='remove')

# %%
report_none_columns = none_columns_result.get_report_df(include_overall=True)
report_none_columns
# Out:
#                                   project  observations  \
# 0                         CCI-MIT__XCoLab          5512
# 1                apache__directory-server           845
# 2                  Ramblurr__Anki-Android           892
# 3                        apache__accumulo          4113
# 4                        jgralab__jgralab          2072
# 5                         getrailo__railo           815
# 6                     apache__lucene-solr          1256
# 7                               zkoss__zk          1087
# 8                           freenet__fred          1268
# 9   CloudStack-extras__CloudStack-archive          1424
# 10                 eucalyptus__eucalyptus          1020
# 11                        atlasapi__atlas          1107
# 12      android__platform_frameworks_base          3557
# 13                  alkacon__opencms-core           923
# 14                           alexo__wro4j          1663
# 15               hibernate__hibernate-orm          1000
# 16                 TeamDev-Ltd__OpenFaces          2979
# 17                       Unidata__thredds          1154
# 18                   SINTEF-9012__ThingML          1022
# 19                  sebastianbenz__Jnario          8298
# 20                                Overall         42007
#
#     observations (wt NaN)  precision  recall  f1-score  accuracy  \
# 0                    3757     0.9730  0.9780   0.97500    0.9780
# 1                     652     0.9220  0.9230   0.92200    0.9230
# 2                     759     0.6810  0.7060   0.69100    0.7060
# 3                    3148     0.7880  0.7970   0.79200    0.7970
# 4                    1802     0.7090  0.7130   0.70900    0.7130
# 5                     572     0.6210  0.6330   0.62500    0.6330
# 6                     974     0.5520  0.5610   0.55600    0.5610
# 7                     881     0.7500  0.7590   0.75400    0.7590
# 8                    1012     0.6270  0.6380   0.63200    0.6380
# 9                    1106     0.6060  0.6200   0.61200    0.6200
# 10                    747     0.5870  0.6010   0.59300    0.6010
# 11                    782     0.6020  0.6160   0.60400    0.6160
# 12                   2460     0.7880  0.7980   0.79200    0.7980
# 13                    840     0.9500  0.9600   0.95500    0.9600
# 14                   1368     0.4720  0.4800   0.47600    0.4800
# 15                    716     0.4540  0.4660   0.45900    0.4660
# 16                   2859     0.9460  0.9520   0.94800    0.9520
# 17                    950     0.7900  0.8220   0.80200    0.8220
# 18                    977     0.9260  0.9420   0.93300    0.9420
# 19                   8173     0.9980  0.9990   0.99900    0.9990
# 20                  34535     0.7371  0.7482   0.74145    0.7482
#
#     baseline (majority)  improvement
# 0               0.57300      0.94800
# 1               0.51200      0.84300
# 2               0.43900      0.47700
# 3               0.63500      0.44400
# 4               0.49100      0.43500
# 5               0.37800      0.41000
# 6               0.26600      0.40100
# 7               0.60200      0.39600
# 8               0.40400      0.39300
# 9               0.43700      0.32600
# 10              0.42300      0.30900
# 11              0.44500      0.30900
# 12              0.70800      0.30700
# 13              0.94400      0.27700
# 14              0.30700      0.25000
# 15              0.31100      0.22500
# 16              0.93800      0.22200
# 17              0.77700      0.20300
# 18              0.93800      0.06600
# 19              0.99900      0.00000
# 20              0.57635      0.36205

# %% [markdown]
# ## Use chunk authorship related columns

# %%
import importlib
importlib.reload(classifier_utils)
ablation_group = 'authorship'
authorship_columns_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns, ablation=True, ablation_group=ablation_group, ablation_mode='add')

# %%
report_authorship_columns = authorship_columns_result.get_report_df(include_overall=True)
report_authorship_columns
# Out:
#                                   project  observations  \
# 0                         CCI-MIT__XCoLab          5512
# 1                apache__directory-server           845
# 2   CloudStack-extras__CloudStack-archive          1424
# 3                  Ramblurr__Anki-Android           892
# 4                        apache__accumulo          4113
# 5                        jgralab__jgralab          2072
# 6                     apache__lucene-solr          1256
# 7                         getrailo__railo           815
# 8                           freenet__fred          1268
# 9                               zkoss__zk          1087
# 10                        atlasapi__atlas          1107
# 11      android__platform_frameworks_base          3557
# 12                 eucalyptus__eucalyptus          1020
# 13               hibernate__hibernate-orm          1000
# 14                       Unidata__thredds          1154
# 15                           alexo__wro4j          1663
# 16                  alkacon__opencms-core           923
# 17                 TeamDev-Ltd__OpenFaces          2979
# 18                   SINTEF-9012__ThingML          1022
# 19                  sebastianbenz__Jnario          8298
# 20                                Overall         42007
#
#     observations (wt NaN)  precision  recall  f1-score  accuracy  \
# 0                    3757     0.9740  0.9760     0.975    0.9760
# 1                     652     0.9270  0.9280     0.927    0.9280
# 2                    1106     0.7560  0.7610     0.758    0.7610
# 3                     759     0.6970  0.7190     0.706    0.7190
# 4                    3148     0.8070  0.8140     0.810    0.8140
# 5                    1802     0.7390  0.7390     0.738    0.7390
# 6                     974     0.5890  0.5950     0.592    0.5950
# 7                     572     0.6340  0.6450     0.638    0.6450
# 8                    1012     0.6490  0.6570     0.652    0.6570
# 9                     881     0.7590  0.7700     0.764    0.7700
# 10                    782     0.6270  0.6450     0.631    0.6450
# 11                   2460     0.7960  0.8010     0.798    0.8010
# 12                    747     0.5870  0.6010     0.592    0.6010
# 13                    716     0.4960  0.5110     0.502    0.5110
# 14                    950     0.8280  0.8390     0.833    0.8390
# 15                   1368     0.4870  0.4930     0.490    0.4930
# 16                    840     0.9430  0.9560     0.949    0.9560
# 17                   2859     0.9450  0.9490     0.947    0.9490
# 18                    977     0.9360  0.9460     0.939    0.9460
# 19                   8173     0.9980  0.9990     0.999    0.9990
# 20                  34535     0.7587  0.7672     0.762    0.7672
#
#     baseline (majority)  improvement
# 0               0.57300      0.94500
# 1               0.51200      0.85200
# 2               0.43700      0.57600
# 3               0.43900      0.50000
# 4               0.63500      0.49000
# 5               0.49100      0.48600
# 6               0.26600      0.44900
# 7               0.37800      0.43000
# 8               0.40400      0.42500
# 9               0.60200      0.42200
# 10              0.44500      0.35900
# 11              0.70800      0.32000
# 12              0.42300      0.30900
# 13              0.31100      0.29000
# 14              0.77700      0.27800
# 15              0.30700      0.26800
# 16              0.94400      0.21300
# 17              0.93800      0.17000
# 18              0.93800      0.13100
# 19              0.99900      0.00000
# 20              0.57635      0.39565

# %% [markdown]
# ## Use chunk complexity related columns

# %%
import importlib
importlib.reload(classifier_utils)
ablation_group = 'complexity'
complexity_columns_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns, ablation=True, ablation_group=ablation_group, ablation_mode='add')

# %%
report_complexity_columns = complexity_columns_result.get_report_df(include_overall=True)
report_complexity_columns
# Out:
#                                   project  observations  \
# 0                         CCI-MIT__XCoLab          5512
# 1                apache__directory-server           845
# 2                        jgralab__jgralab          2072
# 3                  Ramblurr__Anki-Android           892
# 4                        apache__accumulo          4113
# 5                         getrailo__railo           815
# 6   CloudStack-extras__CloudStack-archive          1424
# 7                     apache__lucene-solr          1256
# 8                               zkoss__zk          1087
# 9                           freenet__fred          1268
# 10                 eucalyptus__eucalyptus          1020
# 11                           alexo__wro4j          1663
# 12      android__platform_frameworks_base          3557
# 13                        atlasapi__atlas          1107
# 14                 TeamDev-Ltd__OpenFaces          2979
# 15                  alkacon__opencms-core           923
# 16                       Unidata__thredds          1154
# 17               hibernate__hibernate-orm          1000
# 18                   SINTEF-9012__ThingML          1022
# 19                  sebastianbenz__Jnario          8298
# 20                                Overall         42007
#
#     observations (wt NaN)  precision   recall  f1-score  accuracy  \
# 0                    3757     0.9710  0.97500     0.973   0.97500
# 1                     652     0.9140  0.91600     0.914   0.91600
# 2                    1802     0.7980  0.80200     0.799   0.80200
# 3                     759     0.6860  0.70800     0.695   0.70800
# 4                    3148     0.7960  0.80500     0.800   0.80500
# 5                     572     0.6400  0.64700     0.642   0.64700
# 6                    1106     0.6710  0.67700     0.674   0.67700
# 7                     974     0.5690  0.57800     0.573   0.57800
# 8                     881     0.7500  0.76500     0.757   0.76500
# 9                    1012     0.6260  0.63300     0.628   0.63300
# 10                    747     0.5930  0.60800     0.599   0.60800
# 11                   1368     0.5140  0.52200     0.517   0.52200
# 12                   2460     0.7900  0.79800     0.793   0.79800
# 13                    782     0.5870  0.60500     0.592   0.60500
# 14                   2859     0.9480  0.95300     0.950   0.95300
# 15                    840     0.9490  0.95700     0.953   0.95700
# 16                    950     0.8010  0.82700     0.811   0.82700
# 17                    716     0.4460  0.46400     0.452   0.46400
# 18                    977     0.9350  0.94400     0.939   0.94400
# 19                   8173     0.9980  0.99900     0.999   0.99900
# 20                  34535     0.7491  0.75915     0.753   0.75915
#
#     baseline (majority)  improvement
# 0               0.57300      0.94100
# 1               0.51200      0.82700
# 2               0.49100      0.61200
# 3               0.43900      0.47900
# 4               0.63500      0.46600
# 5               0.37800      0.43300
# 6               0.43700      0.42700
# 7               0.26600      0.42500
# 8               0.60200      0.41000
# 9               0.40400      0.38500
# 10              0.42300      0.32000
# 11              0.30700      0.31000
# 12              0.70800      0.30700
# 13              0.44500      0.28800
# 14              0.93800      0.24400
# 15              0.94400      0.23400
# 16              0.77700      0.22600
# 17              0.31100      0.22100
# 18              0.93800      0.09800
# 19              0.99900     -0.00000
# 20              0.57635      0.38265

# %% [markdown]
# ## Use chunk size related columns

# %%
import importlib
importlib.reload(classifier_utils)
ablation_group = 'size'
size_columns_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns, ablation=True, ablation_group=ablation_group, ablation_mode='add')

# %%
report_size_columns = size_columns_result.get_report_df(include_overall=True)
report_size_columns
# Out:
#                                   project  observations  \
# 0                         CCI-MIT__XCoLab          5512
# 1                apache__directory-server           845
# 2                        jgralab__jgralab          2072
# 3   CloudStack-extras__CloudStack-archive          1424
# 4                        apache__accumulo          4113
# 5                        Unidata__thredds          1154
# 6                  Ramblurr__Anki-Android           892
# 7                         getrailo__railo           815
# 8                     apache__lucene-solr          1256
# 9                           freenet__fred          1268
# 10                 TeamDev-Ltd__OpenFaces          2979
# 11                              zkoss__zk          1087
# 12                           alexo__wro4j          1663
# 13      android__platform_frameworks_base          3557
# 14                        atlasapi__atlas          1107
# 15               hibernate__hibernate-orm          1000
# 16                  alkacon__opencms-core           923
# 17                 eucalyptus__eucalyptus          1020
# 18                   SINTEF-9012__ThingML          1022
# 19                  sebastianbenz__Jnario          8298
# 20                                Overall         42007
#
#     observations (wt NaN)  precision  recall  f1-score  accuracy  \
# 0                    3757     0.9700  0.9740   0.97200    0.9740
# 1                     652     0.9110  0.9140   0.91200    0.9140
# 2                    1802     0.8350  0.8370   0.83500    0.8370
# 3                    1106     0.7740  0.7800   0.77500    0.7800
# 4                    3148     0.8400  0.8480   0.84300    0.8480
# 5                     950     0.8840  0.8980   0.88900    0.8980
# 6                     759     0.7000  0.7250   0.70900    0.7250
# 7                     572     0.6740  0.6940   0.68300    0.6940
# 8                     974     0.6110  0.6220   0.61600    0.6220
# 9                    1012     0.6600  0.6710   0.66400    0.6710
# 10                   2859     0.9630  0.9660   0.96400    0.9660
# 11                    881     0.7620  0.7740   0.76700    0.7740
# 12                   1368     0.5640  0.5740   0.56500    0.5740
# 13                   2460     0.8090  0.8130   0.80900    0.8130
# 14                    782     0.6200  0.6370   0.62200    0.6370
# 15                    716     0.5220  0.5380   0.52600    0.5380
# 16                    840     0.9460  0.9610   0.95300    0.9610
# 17                    747     0.5760  0.5930   0.58200    0.5930
# 18                    977     0.9310  0.9460   0.93800    0.9460
# 19                   8173     0.9980  0.9990   0.99900    0.9990
# 20                  34535     0.7775  0.7882   0.78115    0.7882
#
#     baseline (majority)  improvement
# 0               0.57300       0.9400
# 1               0.51200       0.8240
# 2               0.49100       0.6800
# 3               0.43700       0.6100
# 4               0.63500       0.5820
# 5               0.77700       0.5420
# 6               0.43900       0.5090
# 7               0.37800       0.5080
# 8               0.26600       0.4850
# 9               0.40400       0.4480
# 10              0.93800       0.4430
# 11              0.60200       0.4330
# 12              0.30700       0.3850
# 13              0.70800       0.3620
# 14              0.44500       0.3460
# 15              0.31100       0.3290
# 16              0.94400       0.2980
# 17              0.42300       0.2950
# 18              0.93800       0.1310
# 19              0.99900      -0.0000
# 20              0.57635       0.4575

# %% [markdown]
# ## Use chunk position related columns

# %%
import importlib
importlib.reload(classifier_utils)
ablation_group = 'position'
position_columns_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns, ablation=True, ablation_group=ablation_group, ablation_mode='add')

# %%
report_position_columns = position_columns_result.get_report_df(include_overall=True)
report_position_columns
# Out:
#                                   project  observations  \
# 0                         CCI-MIT__XCoLab          5512
# 1                apache__directory-server           845
# 2                        jgralab__jgralab          2072
# 3                        apache__accumulo          4113
# 4                  Ramblurr__Anki-Android           892
# 5   CloudStack-extras__CloudStack-archive          1424
# 6                               zkoss__zk          1087
# 7                     apache__lucene-solr          1256
# 8                  TeamDev-Ltd__OpenFaces          2979
# 9                         getrailo__railo           815
# 10                          freenet__fred          1268
# 11                        atlasapi__atlas          1107
# 12                 eucalyptus__eucalyptus          1020
# 13      android__platform_frameworks_base          3557
# 14                  alkacon__opencms-core           923
# 15                           alexo__wro4j          1663
# 16               hibernate__hibernate-orm          1000
# 17                       Unidata__thredds          1154
# 18                   SINTEF-9012__ThingML          1022
# 19                  sebastianbenz__Jnario          8298
# 20                                Overall         42007
#
#     observations (wt NaN)  precision   recall  f1-score  accuracy  \
# 0                    3757    0.97100  0.97500     0.973   0.97500
# 1                     652    0.92200  0.92300     0.923   0.92300
# 2                    1802    0.76000  0.76400     0.761   0.76400
# 3                    3148    0.82500  0.82700     0.826   0.82700
# 4                     759    0.69000  0.71100     0.699   0.71100
# 5                    1106    0.67700  0.68700     0.681   0.68700
# 6                     881    0.76100  0.77300     0.766   0.77300
# 7                     974    0.55900  0.56800     0.563   0.56800
# 8                    2859    0.96200  0.96400     0.962   0.96400
# 9                     572    0.61300  0.62600     0.618   0.62600
# 10                   1012    0.61500  0.62400     0.618   0.62400
# 11                    782    0.60700  0.62000     0.610   0.62000
# 12                    747    0.59200  0.60500     0.597   0.60500
# 13                   2460    0.78400  0.79100     0.787   0.79100
# 14                    840    0.95000  0.96000     0.955   0.96000
# 15                   1368    0.49300  0.49900     0.495   0.49900
# 16                    716    0.44300  0.46100     0.450   0.46100
# 17                    950    0.79400  0.82400     0.802   0.82400
# 18                    977    0.92900  0.94400     0.935   0.94400
# 19                   8173    0.99800  0.99900     0.999   0.99900
# 20                  34535    0.74725  0.75725     0.751   0.75725
#
#     baseline (majority)  improvement
# 0               0.57300      0.94200
# 1               0.51200      0.84300
# 2               0.49100      0.53700
# 3               0.63500      0.52600
# 4               0.43900      0.48600
# 5               0.43700      0.44500
# 6               0.60200      0.43000
# 7               0.26600      0.41100
# 8               0.93800      0.40900
# 9               0.37800      0.39900
# 10              0.40400      0.36800
# 11              0.44500      0.31600
# 12              0.42300      0.31600
# 13              0.70800      0.28700
# 14              0.94400      0.27700
# 15              0.30700      0.27600
# 16              0.31100      0.21700
# 17              0.77700      0.21200
# 18              0.93800      0.09800
# 19              0.99900      0.00000
# 20              0.57635      0.38975

# %% [markdown]
# ## Use chunk content related columns

# %%
import importlib
importlib.reload(classifier_utils)
ablation_group = 'content'
content_columns_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns, ablation=True, ablation_group=ablation_group, ablation_mode='add')

# %%
report_content_columns = content_columns_result.get_report_df(include_overall=True)
report_content_columns
# Out:
#                                   project  observations  \
# 0                         CCI-MIT__XCoLab          5512
# 1                apache__directory-server           845
# 2                        apache__accumulo          4113
# 3   CloudStack-extras__CloudStack-archive          1424
# 4                        jgralab__jgralab          2072
# 5                  Ramblurr__Anki-Android           892
# 6                  TeamDev-Ltd__OpenFaces          2979
# 7                     apache__lucene-solr          1256
# 8                        Unidata__thredds          1154
# 9                               zkoss__zk          1087
# 10                        getrailo__railo           815
# 11                          freenet__fred          1268
# 12                  alkacon__opencms-core           923
# 13                        atlasapi__atlas          1107
# 14                           alexo__wro4j          1663
# 15      android__platform_frameworks_base          3557
# 16               hibernate__hibernate-orm          1000
# 17                 eucalyptus__eucalyptus          1020
# 18                   SINTEF-9012__ThingML          1022
# 19                  sebastianbenz__Jnario          8298
# 20                                Overall         42007
#
#     observations (wt NaN)  precision   recall  f1-score  accuracy  \
# 0                    3757    0.97800  0.98000   0.97900   0.98000
# 1                     652    0.93700  0.93900   0.93800   0.93900
# 2                    3148    0.83500  0.84100   0.83800   0.84100
# 3                    1106    0.74400  0.75500   0.74800   0.75500
# 4                    1802    0.76300  0.76500   0.76300   0.76500
# 5                     759    0.71000  0.72900   0.71600   0.72900
# 6                    2859    0.96500  0.96800   0.96600   0.96800
# 7                     974    0.60800  0.61500   0.61100   0.61500
# 8                     950    0.86400  0.87900   0.86700   0.87900
# 9                     881    0.75600  0.77300   0.76400   0.77300
# 10                    572    0.62200  0.63600   0.62800   0.63600
# 11                   1012    0.64500  0.65200   0.64600   0.65200
# 12                    840    0.95300  0.96700   0.96000   0.96700
# 13                    782    0.63000  0.64600   0.63400   0.64600
# 14                   1368    0.54600  0.55200   0.54800   0.55200
# 15                   2460    0.79700  0.80700   0.80100   0.80700
# 16                    716    0.51700  0.53500   0.52200   0.53500
# 17                    747    0.59400  0.60900   0.59800   0.60900
# 18                    977    0.93500  0.94800   0.94100   0.94800
# 19                   8173    0.99800  0.99900   0.99900   0.99900
# 20                  34535    0.76985  0.77975   0.77335   0.77975
#
#     baseline (majority)  improvement
# 0               0.57300      0.95300
# 1               0.51200      0.87400
# 2               0.63500      0.56600
# 3               0.43700      0.56500
# 4               0.49100      0.53800
# 5               0.43900      0.51600
# 6               0.93800      0.47700
# 7               0.26600      0.47600
# 8               0.77700      0.45800
# 9               0.60200      0.43000
# 10              0.37800      0.41600
# 11              0.40400      0.41600
# 12              0.94400      0.40400
# 13              0.44500      0.36200
# 14              0.30700      0.35300
# 15              0.70800      0.33900
# 16              0.31100      0.32500
# 17              0.42300      0.32300
# 18              0.93800      0.16400
# 19              0.99900      0.00000
# 20              0.57635      0.44775

# %%
df_inner_rf = pd.merge(report_default, report_none_columns, on='project', how='inner', suffixes=('_all', '_none'))
df_inner_rf_authorship = report_authorship_columns.add_suffix("_author").rename(columns={"project_author": "project"})
df_inner_rf = pd.merge(df_inner_rf, df_inner_rf_authorship, on='project', how='inner')
df_inner_rf_complexity = report_complexity_columns.add_suffix("_complexity").rename(columns={"project_complexity": "project"})
df_inner_rf = pd.merge(df_inner_rf, df_inner_rf_complexity, on='project', how='inner')
df_inner_rf_size = report_size_columns.add_suffix("_size").rename(columns={"project_size": "project"})
df_inner_rf = pd.merge(df_inner_rf, df_inner_rf_size, on='project', how='inner')
df_inner_rf_position = report_position_columns.add_suffix("_position").rename(columns={"project_position": "project"})
df_inner_rf = pd.merge(df_inner_rf, df_inner_rf_position, on='project', how='inner')
df_inner_rf_content = report_content_columns.add_suffix("_content").rename(columns={"project_content": "project"})
df_inner_rf = pd.merge(df_inner_rf, df_inner_rf_content, on='project', how='inner')

accuracy_rf = df_inner_rf.filter(regex=("project|accuracy.*")).copy()
accuracy_rf
# Out:
#                                   project  accuracy_all  accuracy_none  \
# 0                         CCI-MIT__XCoLab       0.97600         0.9780
# 1                apache__directory-server       0.94200         0.9230
# 2                        jgralab__jgralab       0.87000         0.7130
# 3   CloudStack-extras__CloudStack-archive       0.80400         0.6200
# 4                        Unidata__thredds       0.92100         0.8220
# 5                        apache__accumulo       0.86300         0.7970
# 6                  Ramblurr__Anki-Android       0.73600         0.7060
# 7                     apache__lucene-solr       0.65000         0.5610
# 8                         getrailo__railo       0.70300         0.6330
# 9                  TeamDev-Ltd__OpenFaces       0.97000         0.9520
# 10                              zkoss__zk       0.78800         0.7590
# 11                          freenet__fred       0.67800         0.6380
# 12               hibernate__hibernate-orm       0.59800         0.4660
# 13                           alexo__wro4j       0.59000         0.4800
# 14                        atlasapi__atlas       0.66600         0.6160
# 15      android__platform_frameworks_base       0.81700         0.7980
# 16                 eucalyptus__eucalyptus       0.62500         0.6010
# 17                  alkacon__opencms-core       0.96200         0.9600
# 18                   SINTEF-9012__ThingML       0.94900         0.9420
# 19                  sebastianbenz__Jnario       0.99900         0.9990
# 20                                Overall       0.80535         0.7482
#
#     accuracy_author  accuracy_complexity  accuracy_size  accuracy_position  \
# 0            0.9760              0.97500         0.9740            0.97500
# 1            0.9280              0.91600         0.9140            0.92300
# 2            0.7390              0.80200         0.8370            0.76400
# 3            0.7610              0.67700         0.7800            0.68700
# 4            0.8390              0.82700         0.8980            0.82400
# 5            0.8140              0.80500         0.8480            0.82700
# 6            0.7190              0.70800         0.7250            0.71100
# 7            0.5950              0.57800         0.6220            0.56800
# 8            0.6450              0.64700         0.6940            0.62600
# 9            0.9490              0.95300         0.9660            0.96400
# 10           0.7700              0.76500         0.7740            0.77300
# 11           0.6570              0.63300         0.6710            0.62400
# 12           0.5110              0.46400         0.5380            0.46100
# 13           0.4930              0.52200         0.5740            0.49900
# 14           0.6450              0.60500         0.6370            0.62000
# 15           0.8010              0.79800         0.8130            0.79100
# 16           0.6010              0.60800         0.5930            0.60500
# 17           0.9560              0.95700         0.9610            0.96000
# 18           0.9460              0.94400         0.9460            0.94400
# 19           0.9990              0.99900         0.9990            0.99900
# 20           0.7672              0.75915         0.7882            0.75725
#
#     accuracy_content
# 0            0.98000
# 1            0.93900
# 2            0.76500
# 3            0.75500
# 4            0.87900
# 5            0.84100
# 6            0.72900
# 7            0.61500
# 8            0.63600
# 9            0.96800
# 10           0.77300
# 11           0.65200
# 12           0.53500
# 13           0.55200
# 14           0.64600
# 15           0.80700
# 16           0.60900
# 17           0.96700
# 18           0.94800
# 19           0.99900
# 20           0.77975

# %%
accuracy_rf_improv = accuracy_rf[accuracy_rf['project']=='Overall'].copy()
accuracy_rf_improv['improv._all'] = accuracy_rf_improv.apply(lambda x: classifier_utils.get_normalized_improvement(x['accuracy_all'], x['accuracy_none']), axis=1)
accuracy_rf_improv['improv._author'] = accuracy_rf_improv.apply(lambda x: classifier_utils.get_normalized_improvement(x['accuracy_author'], x['accuracy_none']), axis=1)
accuracy_rf_improv['improv._complexity'] = accuracy_rf_improv.apply(lambda x: classifier_utils.get_normalized_improvement(x['accuracy_complexity'], x['accuracy_none']), axis=1)
accuracy_rf_improv['improv._size'] = accuracy_rf_improv.apply(lambda x: classifier_utils.get_normalized_improvement(x['accuracy_size'], x['accuracy_none']), axis=1)
accuracy_rf_improv['improv._position'] = accuracy_rf_improv.apply(lambda x: classifier_utils.get_normalized_improvement(x['accuracy_position'], x['accuracy_none']), axis=1)
accuracy_rf_improv['improv._content'] = accuracy_rf_improv.apply(lambda x: classifier_utils.get_normalized_improvement(x['accuracy_content'], x['accuracy_none']), axis=1)
accuracy_rf_improv.transpose()
# Out:
#                            20
# project               Overall
# accuracy_all          0.80535
# accuracy_none          0.7482
# accuracy_author        0.7672
# accuracy_complexity   0.75915
# accuracy_size          0.7882
# accuracy_position     0.75725
# accuracy_content      0.77975
# improv._all          0.226966
# improv._author       0.075457
# improv._complexity   0.043487
# improv._size         0.158856
# improv._position     0.035941
# improv._content      0.125298
