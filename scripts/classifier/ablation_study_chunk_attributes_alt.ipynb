# %% [markdown]
# Goal of this notebook:
#
# Investigate the impact on the classifier accuracy of adding each group of attributes related to the conflicting chunks.
#
# Attributes groups:
#
# - Authorship: self_conflict_perc, authors involved
# - Complexity: leftCC, rightCC
# - Size: chunkAbsSize, chunkRelSize, chunk_left_abs_size, chunk_left_rel_size, chunk_right_abs_size, chunk_right_rel_size
# - Position: chunkPosition
# - Content: Programming language constructs

# %%
import numpy as np
import pandas as pd
from IPython.core.display import display

pd.set_option('display.max_columns', None)
from sklearn.ensemble import RandomForestClassifier
import warnings
import classifier_utils
import configs
warnings.filterwarnings("ignore", category=UserWarning)

# %%
non_features_columns = ["chunk_id", "line_start", "line_end", "line_separator", "kind_conflict", "url", "project"]
non_features_columns.extend(["project_user", "project_name", "path", "file_name", "sha", "leftsha", "rightsha", "basesha"])

# %%
selected_dataset = pd.read_csv("../../data/SELECTED_LABELLED_DATASET.csv")
projects = list(selected_dataset['project'].unique())

# %%
rf = RandomForestClassifier(random_state=99, n_jobs=5, n_estimators=400, max_features=0.3, min_samples_leaf=1)# Decision Tree

# %%
default_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns)
report_default = default_result.get_report_df(include_overall=True)

# %% [markdown]
# ## Use no chunk related columns

# %%
import importlib
importlib.reload(classifier_utils)
ablation_group = 'all'
none_columns_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns, ablation=True, ablation_group=ablation_group, ablation_mode='remove')

# %%
report_none_columns = none_columns_result.get_report_df(include_overall=True)
report_none_columns
# Out:
#                                               project  observations  \
# 0                                     CCI-MIT__XCoLab          5512
# 1                            apache__directory-server           845
# 2                              Ramblurr__Anki-Android           892
# 3                                    apache__accumulo          4113
# 4                                    jgralab__jgralab          2072
# 5                                     getrailo__railo           815
# 6                                 apache__lucene-solr          1256
# 7                    cgjones__android-frameworks-base           828
# 8                                           zkoss__zk          1087
# 9                                       freenet__fred          1268
# 10                     AOKP__frameworks_base_disabled          1999
# 11              CloudStack-extras__CloudStack-archive          1424
# 12                             eucalyptus__eucalyptus          1020
# 13                                    atlasapi__atlas          1107
# 14                  android__platform_frameworks_base          3557
# 15  RealVNC__android-frameworks-base-with-screensh...          2269
# 16                              alkacon__opencms-core           923
# 17            allwinner-ics__platform_frameworks_base          1780
# 18                                       alexo__wro4j          1663
# 19           IceColdSandwich__android_frameworks_base          1792
# 20                           hibernate__hibernate-orm          1000
# 21                             TeamDev-Ltd__OpenFaces          2979
# 22                                   Unidata__thredds          1154
# 23                               SINTEF-9012__ThingML          1022
# 24                              sebastianbenz__Jnario          8298
# 25                             elastic__elasticsearch          1246
# 26                             eclipse__jetty.project          1537
# 27                        revolsys__com.revolsys.open           991
# 28  adetaylor__android-frameworks-base-with-remote...          1792
# 29                                            Overall         56241
#
#     observations (wt NaN)  precision   recall  f1-score  accuracy  \
# 0                    3757     0.9730  0.97800     0.975   0.97800
# 1                     652     0.9220  0.92300     0.922   0.92300
# 2                     759     0.6810  0.70600     0.691   0.70600
# 3                    3148     0.7880  0.79700     0.792   0.79700
# 4                    1802     0.7090  0.71300     0.709   0.71300
# 5                     572     0.6210  0.63300     0.625   0.63300
# 6                     974     0.5520  0.56100     0.556   0.56100
# 7                     565     0.8390  0.84800     0.843   0.84800
# 8                     881     0.7500  0.75900     0.754   0.75900
# 9                    1012     0.6270  0.63800     0.632   0.63800
# 10                   1370     0.7950  0.80700     0.800   0.80700
# 11                   1106     0.6060  0.62000     0.612   0.62000
# 12                    747     0.5870  0.60100     0.593   0.60100
# 13                    782     0.6020  0.61600     0.604   0.61600
# 14                   2460     0.7880  0.79800     0.792   0.79800
# 15                   1561     0.7810  0.79500     0.787   0.79500
# 16                    840     0.9500  0.96000     0.955   0.96000
# 17                   1187     0.7800  0.79000     0.785   0.79000
# 18                   1368     0.4720  0.48000     0.476   0.48000
# 19                   1193     0.7730  0.79000     0.781   0.79000
# 20                    716     0.4540  0.46600     0.459   0.46600
# 21                   2859     0.9460  0.95200     0.948   0.95200
# 22                    950     0.7900  0.82200     0.802   0.82200
# 23                    977     0.9260  0.94200     0.933   0.94200
# 24                   8173     0.9980  0.99900     0.999   0.99900
# 25                      0        NaN      NaN       NaN       NaN
# 26                      0        NaN      NaN       NaN       NaN
# 27                      1        NaN      NaN       NaN       NaN
# 28                      0        NaN      NaN       NaN       NaN
# 29                  40412     0.7484  0.75976     0.753   0.75976
#
#     baseline (majority)  improvement
# 0                0.5730      0.94800
# 1                0.5120      0.84300
# 2                0.4390      0.47700
# 3                0.6350      0.44400
# 4                0.4910      0.43500
# 5                0.3780      0.41000
# 6                0.2660      0.40100
# 7                0.7470      0.39900
# 8                0.6020      0.39600
# 9                0.4040      0.39300
# 10               0.7110      0.33100
# 11               0.4370      0.32600
# 12               0.4230      0.30900
# 13               0.4450      0.30900
# 14               0.7080      0.30700
# 15               0.7110      0.29000
# 16               0.9440      0.27700
# 17               0.7130      0.27000
# 18               0.3070      0.25000
# 19               0.7260      0.23200
# 20               0.3110      0.22500
# 21               0.9380      0.22200
# 22               0.7770      0.20300
# 23               0.9380      0.06600
# 24               0.9990      0.00000
# 25                  NaN          NaN
# 26                  NaN          NaN
# 27                  NaN          NaN
# 28                  NaN          NaN
# 29               0.6054      0.35052

# %% [markdown]
# ## Use chunk authorship related columns

# %%
import importlib
importlib.reload(classifier_utils)
ablation_group = 'authorship'
authorship_columns_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns, ablation=True, ablation_group=ablation_group, ablation_mode='add')

# %%
report_authorship_columns = authorship_columns_result.get_report_df(include_overall=True)
report_authorship_columns
# Out:
#                                               project  observations  \
# 0                                     CCI-MIT__XCoLab          5512
# 1                            apache__directory-server           845
# 2               CloudStack-extras__CloudStack-archive          1424
# 3                              Ramblurr__Anki-Android           892
# 4                                    apache__accumulo          4113
# 5                                    jgralab__jgralab          2072
# 6                                 apache__lucene-solr          1256
# 7                    cgjones__android-frameworks-base           828
# 8                                     getrailo__railo           815
# 9                                           zkoss__zk          1087
# 10                                      freenet__fred          1268
# 11                                    atlasapi__atlas          1107
# 12                     AOKP__frameworks_base_disabled          1999
# 13                  android__platform_frameworks_base          3557
# 14                             eucalyptus__eucalyptus          1020
# 15  RealVNC__android-frameworks-base-with-screensh...          2269
# 16                           hibernate__hibernate-orm          1000
# 17            allwinner-ics__platform_frameworks_base          1780
# 18                                   Unidata__thredds          1154
# 19                                       alexo__wro4j          1663
# 20           IceColdSandwich__android_frameworks_base          1792
# 21                              alkacon__opencms-core           923
# 22                             TeamDev-Ltd__OpenFaces          2979
# 23                               SINTEF-9012__ThingML          1022
# 24                              sebastianbenz__Jnario          8298
# 25                             elastic__elasticsearch          1246
# 26                             eclipse__jetty.project          1537
# 27                        revolsys__com.revolsys.open           991
# 28  adetaylor__android-frameworks-base-with-remote...          1792
# 29                                            Overall         56241
#
#     observations (wt NaN)  precision   recall  f1-score  accuracy  \
# 0                    3757     0.9730  0.97600   0.97400   0.97600
# 1                     652     0.9270  0.92800   0.92700   0.92800
# 2                    1106     0.7590  0.76400   0.76000   0.76400
# 3                     759     0.6930  0.71800   0.70300   0.71800
# 4                    3148     0.8070  0.81400   0.81100   0.81400
# 5                    1802     0.7400  0.74000   0.73900   0.74000
# 6                     974     0.5810  0.58900   0.58500   0.58900
# 7                     565     0.8500  0.85800   0.85300   0.85800
# 8                     572     0.6360  0.64700   0.63900   0.64700
# 9                     881     0.7620  0.77300   0.76700   0.77300
# 10                   1012     0.6520  0.66000   0.65500   0.66000
# 11                    782     0.6370  0.65300   0.64100   0.65300
# 12                   1370     0.8020  0.81100   0.80600   0.81100
# 13                   2460     0.7960  0.80100   0.79800   0.80100
# 14                    747     0.5890  0.60200   0.59400   0.60200
# 15                   1561     0.7900  0.79900   0.79400   0.79900
# 16                    716     0.4950  0.51300   0.50200   0.51300
# 17                   1187     0.7870  0.79600   0.79100   0.79600
# 18                    950     0.8260  0.83800   0.83100   0.83800
# 19                   1368     0.4810  0.48800   0.48400   0.48800
# 20                   1193     0.7760  0.79300   0.78400   0.79300
# 21                    840     0.9420  0.95600   0.94900   0.95600
# 22                   2859     0.9450  0.94900   0.94700   0.94900
# 23                    977     0.9360  0.94600   0.93900   0.94600
# 24                   8173     0.9980  0.99900   0.99900   0.99900
# 25                      0        NaN      NaN       NaN       NaN
# 26                      0        NaN      NaN       NaN       NaN
# 27                      1        NaN      NaN       NaN       NaN
# 28                      0        NaN      NaN       NaN       NaN
# 29                  40412     0.7672  0.77644   0.77088   0.77644
#
#     baseline (majority)  improvement
# 0                0.5730      0.94300
# 1                0.5120      0.85200
# 2                0.4370      0.58100
# 3                0.4390      0.49800
# 4                0.6350      0.49100
# 5                0.4910      0.48900
# 6                0.2660      0.44100
# 7                0.7470      0.44100
# 8                0.3780      0.43300
# 9                0.6020      0.43000
# 10               0.4040      0.43000
# 11               0.4450      0.37600
# 12               0.7110      0.34600
# 13               0.7080      0.32000
# 14               0.4230      0.31100
# 15               0.7110      0.30600
# 16               0.3110      0.29200
# 17               0.7130      0.29000
# 18               0.7770      0.27400
# 19               0.3070      0.26100
# 20               0.7260      0.24500
# 21               0.9440      0.21300
# 22               0.9380      0.17000
# 23               0.9380      0.13100
# 24               0.9990      0.00000
# 25                  NaN          NaN
# 26                  NaN          NaN
# 27                  NaN          NaN
# 28                  NaN          NaN
# 29               0.6054      0.38256

# %% [markdown]
# ## Use chunk complexity related columns

# %%
import importlib
importlib.reload(classifier_utils)
ablation_group = 'complexity'
complexity_columns_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns, ablation=True, ablation_group=ablation_group, ablation_mode='add')

# %%
report_complexity_columns = complexity_columns_result.get_report_df(include_overall=True)
report_complexity_columns
# Out:
#                                               project  observations  \
# 0                                     CCI-MIT__XCoLab          5512
# 1                            apache__directory-server           845
# 2                                    jgralab__jgralab          2072
# 3                              Ramblurr__Anki-Android           892
# 4                                    apache__accumulo          4113
# 5                    cgjones__android-frameworks-base           828
# 6                                     getrailo__railo           815
# 7               CloudStack-extras__CloudStack-archive          1424
# 8                                 apache__lucene-solr          1256
# 9                                           zkoss__zk          1087
# 10                                      freenet__fred          1268
# 11                     AOKP__frameworks_base_disabled          1999
# 12                             eucalyptus__eucalyptus          1020
# 13                                       alexo__wro4j          1663
# 14                  android__platform_frameworks_base          3557
# 15            allwinner-ics__platform_frameworks_base          1780
# 16                                    atlasapi__atlas          1107
# 17  RealVNC__android-frameworks-base-with-screensh...          2269
# 18           IceColdSandwich__android_frameworks_base          1792
# 19                             TeamDev-Ltd__OpenFaces          2979
# 20                              alkacon__opencms-core           923
# 21                                   Unidata__thredds          1154
# 22                           hibernate__hibernate-orm          1000
# 23                               SINTEF-9012__ThingML          1022
# 24                              sebastianbenz__Jnario          8298
# 25                             elastic__elasticsearch          1246
# 26                             eclipse__jetty.project          1537
# 27                        revolsys__com.revolsys.open           991
# 28  adetaylor__android-frameworks-base-with-remote...          1792
# 29                                            Overall         56241
#
#     observations (wt NaN)  precision  recall  f1-score  accuracy  \
# 0                    3757    0.97100  0.9750   0.97300    0.9750
# 1                     652    0.91400  0.9160   0.91400    0.9160
# 2                    1802    0.79800  0.8020   0.79900    0.8020
# 3                     759    0.68600  0.7080   0.69500    0.7080
# 4                    3148    0.79600  0.8050   0.80000    0.8050
# 5                     565    0.85600  0.8640   0.85900    0.8640
# 6                     572    0.64000  0.6470   0.64200    0.6470
# 7                    1106    0.67100  0.6770   0.67400    0.6770
# 8                     974    0.56900  0.5780   0.57300    0.5780
# 9                     881    0.75000  0.7650   0.75700    0.7650
# 10                   1012    0.62600  0.6330   0.62800    0.6330
# 11                   1370    0.79900  0.8090   0.80300    0.8090
# 12                    747    0.59300  0.6080   0.59900    0.6080
# 13                   1368    0.51400  0.5220   0.51700    0.5220
# 14                   2460    0.79000  0.7980   0.79300    0.7980
# 15                   1187    0.78700  0.7980   0.79200    0.7980
# 16                    782    0.58700  0.6050   0.59200    0.6050
# 17                   1561    0.78300  0.7930   0.78700    0.7930
# 18                   1193    0.77500  0.7930   0.78300    0.7930
# 19                   2859    0.94800  0.9530   0.95000    0.9530
# 20                    840    0.94900  0.9570   0.95300    0.9570
# 21                    950    0.80100  0.8270   0.81100    0.8270
# 22                    716    0.44600  0.4640   0.45200    0.4640
# 23                    977    0.93500  0.9440   0.93900    0.9440
# 24                   8173    0.99800  0.9990   0.99900    0.9990
# 25                      0        NaN     NaN       NaN       NaN
# 26                      0        NaN     NaN       NaN       NaN
# 27                      1        NaN     NaN       NaN       NaN
# 28                      0        NaN     NaN       NaN       NaN
# 29                  40412    0.75928  0.7696   0.76336    0.7696
#
#     baseline (majority)  improvement
# 0                0.5730      0.94100
# 1                0.5120      0.82700
# 2                0.4910      0.61200
# 3                0.4390      0.47900
# 4                0.6350      0.46600
# 5                0.7470      0.46200
# 6                0.3780      0.43300
# 7                0.4370      0.42700
# 8                0.2660      0.42500
# 9                0.6020      0.41000
# 10               0.4040      0.38500
# 11               0.7110      0.34100
# 12               0.4230      0.32000
# 13               0.3070      0.31000
# 14               0.7080      0.30700
# 15               0.7130      0.29600
# 16               0.4450      0.28800
# 17               0.7110      0.28400
# 18               0.7260      0.24500
# 19               0.9380      0.24400
# 20               0.9440      0.23400
# 21               0.7770      0.22600
# 22               0.3110      0.22100
# 23               0.9380      0.09800
# 24               0.9990     -0.00000
# 25                  NaN          NaN
# 26                  NaN          NaN
# 27                  NaN          NaN
# 28                  NaN          NaN
# 29               0.6054      0.37124

# %% [markdown]
# ## Use chunk size related columns

# %%
import importlib
importlib.reload(classifier_utils)
ablation_group = 'size'
size_columns_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns, ablation=True, ablation_group=ablation_group, ablation_mode='add')

# %%
report_size_columns = size_columns_result.get_report_df(include_overall=True)
report_size_columns
# Out:
#                                               project  observations  \
# 0                                     CCI-MIT__XCoLab          5512
# 1                            apache__directory-server           845
# 2                                    jgralab__jgralab          2072
# 3               CloudStack-extras__CloudStack-archive          1424
# 4                                    apache__accumulo          4113
# 5                                    Unidata__thredds          1154
# 6                              Ramblurr__Anki-Android           892
# 7                                     getrailo__railo           815
# 8                                 apache__lucene-solr          1256
# 9                                       freenet__fred          1268
# 10                             TeamDev-Ltd__OpenFaces          2979
# 11                                          zkoss__zk          1087
# 12                   cgjones__android-frameworks-base           828
# 13                                       alexo__wro4j          1663
# 14                     AOKP__frameworks_base_disabled          1999
# 15                  android__platform_frameworks_base          3557
# 16                                    atlasapi__atlas          1107
# 17                           hibernate__hibernate-orm          1000
# 18  RealVNC__android-frameworks-base-with-screensh...          2269
# 19            allwinner-ics__platform_frameworks_base          1780
# 20                              alkacon__opencms-core           923
# 21                             eucalyptus__eucalyptus          1020
# 22           IceColdSandwich__android_frameworks_base          1792
# 23                               SINTEF-9012__ThingML          1022
# 24                              sebastianbenz__Jnario          8298
# 25                             elastic__elasticsearch          1246
# 26                             eclipse__jetty.project          1537
# 27                        revolsys__com.revolsys.open           991
# 28  adetaylor__android-frameworks-base-with-remote...          1792
# 29                                            Overall         56241
#
#     observations (wt NaN)  precision   recall  f1-score  accuracy  \
# 0                    3757    0.97000  0.97400   0.97200   0.97400
# 1                     652    0.91100  0.91400   0.91200   0.91400
# 2                    1802    0.83500  0.83700   0.83500   0.83700
# 3                    1106    0.77400  0.78000   0.77500   0.78000
# 4                    3148    0.84000  0.84800   0.84300   0.84800
# 5                     950    0.88400  0.89800   0.88900   0.89800
# 6                     759    0.70000  0.72500   0.70900   0.72500
# 7                     572    0.67400  0.69400   0.68300   0.69400
# 8                     974    0.61100  0.62200   0.61600   0.62200
# 9                    1012    0.66000  0.67100   0.66400   0.67100
# 10                   2859    0.96300  0.96600   0.96400   0.96600
# 11                    881    0.76200  0.77400   0.76700   0.77400
# 12                    565    0.84300  0.85100   0.84600   0.85100
# 13                   1368    0.56400  0.57400   0.56500   0.57400
# 14                   1370    0.81100  0.82000   0.81300   0.82000
# 15                   2460    0.80900  0.81300   0.80900   0.81300
# 16                    782    0.62000  0.63700   0.62200   0.63700
# 17                    716    0.52200  0.53800   0.52600   0.53800
# 18                   1561    0.79000  0.80300   0.79500   0.80300
# 19                   1187    0.78800  0.80100   0.79300   0.80100
# 20                    840    0.94600  0.96100   0.95300   0.96100
# 21                    747    0.57600  0.59300   0.58200   0.59300
# 22                   1193    0.78600  0.80400   0.79300   0.80400
# 23                    977    0.93100  0.94600   0.93800   0.94600
# 24                   8173    0.99800  0.99900   0.99900   0.99900
# 25                      0        NaN      NaN       NaN       NaN
# 26                      0        NaN      NaN       NaN       NaN
# 27                      1        NaN      NaN       NaN       NaN
# 28                      0        NaN      NaN       NaN       NaN
# 29                  40412    0.78272  0.79372   0.78652   0.79372
#
#     baseline (majority)  improvement
# 0                0.5730      0.94000
# 1                0.5120      0.82400
# 2                0.4910      0.68000
# 3                0.4370      0.61000
# 4                0.6350      0.58200
# 5                0.7770      0.54200
# 6                0.4390      0.50900
# 7                0.3780      0.50800
# 8                0.2660      0.48500
# 9                0.4040      0.44800
# 10               0.9380      0.44300
# 11               0.6020      0.43300
# 12               0.7470      0.41300
# 13               0.3070      0.38500
# 14               0.7110      0.37900
# 15               0.7080      0.36200
# 16               0.4450      0.34600
# 17               0.3110      0.32900
# 18               0.7110      0.31900
# 19               0.7130      0.30800
# 20               0.9440      0.29800
# 21               0.4230      0.29500
# 22               0.7260      0.28400
# 23               0.9380      0.13100
# 24               0.9990     -0.00000
# 25                  NaN          NaN
# 26                  NaN          NaN
# 27                  NaN          NaN
# 28                  NaN          NaN
# 29               0.6054      0.43412

# %% [markdown]
# ## Use chunk position related columns

# %%
import importlib
importlib.reload(classifier_utils)
ablation_group = 'position'
position_columns_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns, ablation=True, ablation_group=ablation_group, ablation_mode='add')

# %%
report_position_columns = position_columns_result.get_report_df(include_overall=True)
report_position_columns
# Out:
#                                               project  observations  \
# 0                                     CCI-MIT__XCoLab          5512
# 1                            apache__directory-server           845
# 2                                    jgralab__jgralab          2072
# 3                                    apache__accumulo          4113
# 4                              Ramblurr__Anki-Android           892
# 5                    cgjones__android-frameworks-base           828
# 6               CloudStack-extras__CloudStack-archive          1424
# 7                                           zkoss__zk          1087
# 8                                 apache__lucene-solr          1256
# 9                              TeamDev-Ltd__OpenFaces          2979
# 10                                    getrailo__railo           815
# 11                                      freenet__fred          1268
# 12                             eucalyptus__eucalyptus          1020
# 13                                    atlasapi__atlas          1107
# 14                     AOKP__frameworks_base_disabled          1999
# 15                  android__platform_frameworks_base          3557
# 16  RealVNC__android-frameworks-base-with-screensh...          2269
# 17            allwinner-ics__platform_frameworks_base          1780
# 18                              alkacon__opencms-core           923
# 19                                       alexo__wro4j          1663
# 20                           hibernate__hibernate-orm          1000
# 21                                   Unidata__thredds          1154
# 22           IceColdSandwich__android_frameworks_base          1792
# 23                               SINTEF-9012__ThingML          1022
# 24                              sebastianbenz__Jnario          8298
# 25                             elastic__elasticsearch          1246
# 26                             eclipse__jetty.project          1537
# 27                        revolsys__com.revolsys.open           991
# 28  adetaylor__android-frameworks-base-with-remote...          1792
# 29                                            Overall         56241
#
#     observations (wt NaN)  precision   recall  f1-score  accuracy  \
# 0                    3757    0.97100  0.97500   0.97300   0.97500
# 1                     652    0.92200  0.92300   0.92300   0.92300
# 2                    1802    0.76000  0.76400   0.76100   0.76400
# 3                    3148    0.82500  0.82700   0.82600   0.82700
# 4                     759    0.69000  0.71100   0.69900   0.71100
# 5                     565    0.85700  0.86400   0.86000   0.86400
# 6                    1106    0.67700  0.68700   0.68100   0.68700
# 7                     881    0.76100  0.77300   0.76600   0.77300
# 8                     974    0.55900  0.56800   0.56300   0.56800
# 9                    2859    0.96200  0.96400   0.96200   0.96400
# 10                    572    0.61300  0.62600   0.61800   0.62600
# 11                   1012    0.61500  0.62400   0.61800   0.62400
# 12                    747    0.59200  0.60500   0.59700   0.60500
# 13                    782    0.60700  0.62000   0.61000   0.62000
# 14                   1370    0.78300  0.79600   0.78900   0.79600
# 15                   2460    0.78400  0.79100   0.78700   0.79100
# 16                   1561    0.78000  0.79400   0.78600   0.79400
# 17                   1187    0.78100  0.79300   0.78600   0.79300
# 18                    840    0.95000  0.96000   0.95500   0.96000
# 19                   1368    0.49300  0.49900   0.49500   0.49900
# 20                    716    0.44300  0.46100   0.45000   0.46100
# 21                    950    0.79400  0.82400   0.80200   0.82400
# 22                   1193    0.76600  0.78000   0.77300   0.78000
# 23                    977    0.92900  0.94400   0.93500   0.94400
# 24                   8173    0.99800  0.99900   0.99900   0.99900
# 25                      0        NaN      NaN       NaN       NaN
# 26                      0        NaN      NaN       NaN       NaN
# 27                      1        NaN      NaN       NaN       NaN
# 28                      0        NaN      NaN       NaN       NaN
# 29                  40412    0.75648  0.76688   0.76056   0.76688
#
#     baseline (majority)  improvement
# 0                0.5730      0.94200
# 1                0.5120      0.84300
# 2                0.4910      0.53700
# 3                0.6350      0.52600
# 4                0.4390      0.48600
# 5                0.7470      0.46200
# 6                0.4370      0.44500
# 7                0.6020      0.43000
# 8                0.2660      0.41100
# 9                0.9380      0.40900
# 10               0.3780      0.39900
# 11               0.4040      0.36800
# 12               0.4230      0.31600
# 13               0.4450      0.31600
# 14               0.7110      0.29300
# 15               0.7080      0.28700
# 16               0.7110      0.28600
# 17               0.7130      0.27900
# 18               0.9440      0.27700
# 19               0.3070      0.27600
# 20               0.3110      0.21700
# 21               0.7770      0.21200
# 22               0.7260      0.19900
# 23               0.9380      0.09800
# 24               0.9990      0.00000
# 25                  NaN          NaN
# 26                  NaN          NaN
# 27                  NaN          NaN
# 28                  NaN          NaN
# 29               0.6054      0.37256

# %% [markdown]
# ## Use chunk content related columns

# %%
import importlib
importlib.reload(classifier_utils)
ablation_group = 'content'
content_columns_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns, ablation=True, ablation_group=ablation_group, ablation_mode='add')

# %%
report_content_columns = content_columns_result.get_report_df(include_overall=True)
report_content_columns
# Out:
#                                               project  observations  \
# 0                                     CCI-MIT__XCoLab          5512
# 1                            apache__directory-server           845
# 2                                    apache__accumulo          4113
# 3               CloudStack-extras__CloudStack-archive          1424
# 4                                    jgralab__jgralab          2072
# 5                              Ramblurr__Anki-Android           892
# 6                              TeamDev-Ltd__OpenFaces          2979
# 7                                 apache__lucene-solr          1256
# 8                    cgjones__android-frameworks-base           828
# 9                                           zkoss__zk          1087
# 10                                   Unidata__thredds          1154
# 11                                    getrailo__railo           815
# 12                                      freenet__fred          1268
# 13                              alkacon__opencms-core           923
# 14                                    atlasapi__atlas          1107
# 15                                       alexo__wro4j          1663
# 16                     AOKP__frameworks_base_disabled          1999
# 17                  android__platform_frameworks_base          3557
# 18            allwinner-ics__platform_frameworks_base          1780
# 19                             eucalyptus__eucalyptus          1020
# 20                           hibernate__hibernate-orm          1000
# 21  RealVNC__android-frameworks-base-with-screensh...          2269
# 22           IceColdSandwich__android_frameworks_base          1792
# 23                               SINTEF-9012__ThingML          1022
# 24                              sebastianbenz__Jnario          8298
# 25                             elastic__elasticsearch          1246
# 26                             eclipse__jetty.project          1537
# 27                        revolsys__com.revolsys.open           991
# 28  adetaylor__android-frameworks-base-with-remote...          1792
# 29                                            Overall         56241
#
#     observations (wt NaN)  precision   recall  f1-score  accuracy  \
# 0                    3757    0.97800  0.98000   0.97800   0.98000
# 1                     652    0.93400  0.93600   0.93500   0.93600
# 2                    3148    0.83700  0.84500   0.84000   0.84500
# 3                    1106    0.74400  0.75400   0.74700   0.75400
# 4                    1802    0.76300  0.76400   0.76200   0.76400
# 5                     759    0.71000  0.72900   0.71600   0.72900
# 6                    2859    0.96400  0.96700   0.96600   0.96700
# 7                     974    0.59600  0.60500   0.60000   0.60500
# 8                     565    0.85000  0.86000   0.85400   0.86000
# 9                     881    0.76100  0.77600   0.76800   0.77600
# 10                    950    0.85700  0.87300   0.86100   0.87300
# 11                    572    0.62400  0.63800   0.63000   0.63800
# 12                   1012    0.64400  0.65100   0.64600   0.65100
# 13                    840    0.95300  0.96500   0.95900   0.96500
# 14                    782    0.63000  0.64600   0.63400   0.64600
# 15                   1368    0.55000  0.55700   0.55300   0.55700
# 16                   1370    0.80300  0.81300   0.80700   0.81300
# 17                   2460    0.80000  0.80900   0.80300   0.80900
# 18                   1187    0.79500  0.80600   0.80000   0.80600
# 19                    747    0.59300  0.61000   0.59900   0.61000
# 20                    716    0.50600  0.52400   0.51200   0.52400
# 21                   1561    0.78700  0.79800   0.79200   0.79800
# 22                   1193    0.79100  0.80300   0.79600   0.80300
# 23                    977    0.93500  0.94900   0.94100   0.94900
# 24                   8173    0.99800  0.99900   0.99900   0.99900
# 25                      0        NaN      NaN       NaN       NaN
# 26                      0        NaN      NaN       NaN       NaN
# 27                      1        NaN      NaN       NaN       NaN
# 28                      0        NaN      NaN       NaN       NaN
# 29                  40412    0.77612  0.78628   0.77992   0.78628
#
#     baseline (majority)  improvement
# 0                0.5730      0.95200
# 1                0.5120      0.86800
# 2                0.6350      0.57400
# 3                0.4370      0.56300
# 4                0.4910      0.53700
# 5                0.4390      0.51600
# 6                0.9380      0.47200
# 7                0.2660      0.46200
# 8                0.7470      0.44800
# 9                0.6020      0.43900
# 10               0.7770      0.42900
# 11               0.3780      0.41900
# 12               0.4040      0.41500
# 13               0.9440      0.38300
# 14               0.4450      0.36200
# 15               0.3070      0.36100
# 16               0.7110      0.35400
# 17               0.7080      0.34500
# 18               0.7130      0.32600
# 19               0.4230      0.32500
# 20               0.3110      0.30800
# 21               0.7110      0.29900
# 22               0.7260      0.28100
# 23               0.9380      0.18000
# 24               0.9990      0.00000
# 25                  NaN          NaN
# 26                  NaN          NaN
# 27                  NaN          NaN
# 28                  NaN          NaN
# 29               0.6054      0.42472

# %%
df_inner_rf = pd.merge(report_default, report_none_columns, on='project', how='inner', suffixes=('_all', '_none'))
df_inner_rf_authorship = report_authorship_columns.add_suffix("_author").rename(columns={"project_author": "project"})
df_inner_rf = pd.merge(df_inner_rf, df_inner_rf_authorship, on='project', how='inner')
df_inner_rf_complexity = report_complexity_columns.add_suffix("_complexity").rename(columns={"project_complexity": "project"})
df_inner_rf = pd.merge(df_inner_rf, df_inner_rf_complexity, on='project', how='inner')
df_inner_rf_size = report_size_columns.add_suffix("_size").rename(columns={"project_size": "project"})
df_inner_rf = pd.merge(df_inner_rf, df_inner_rf_size, on='project', how='inner')
df_inner_rf_position = report_position_columns.add_suffix("_position").rename(columns={"project_position": "project"})
df_inner_rf = pd.merge(df_inner_rf, df_inner_rf_position, on='project', how='inner')
df_inner_rf_content = report_content_columns.add_suffix("_content").rename(columns={"project_content": "project"})
df_inner_rf = pd.merge(df_inner_rf, df_inner_rf_content, on='project', how='inner')

accuracy_rf = df_inner_rf.filter(regex=("project|accuracy.*")).copy()
accuracy_rf
# Out:
#                                               project  accuracy_all  \
# 0                                     CCI-MIT__XCoLab       0.97600
# 1                            apache__directory-server       0.93900
# 2                                    jgralab__jgralab       0.86900
# 3               CloudStack-extras__CloudStack-archive       0.80300
# 4                                    Unidata__thredds       0.91900
# 5                                    apache__accumulo       0.86400
# 6                              Ramblurr__Anki-Android       0.74000
# 7                                     getrailo__railo       0.70100
# 8                                 apache__lucene-solr       0.64400
# 9                              TeamDev-Ltd__OpenFaces       0.96900
# 10                                          zkoss__zk       0.78300
# 11                   cgjones__android-frameworks-base       0.86200
# 12                                      freenet__fred       0.67400
# 13                           hibernate__hibernate-orm       0.60200
# 14                                       alexo__wro4j       0.58400
# 15                                    atlasapi__atlas       0.66600
# 16                     AOKP__frameworks_base_disabled       0.82400
# 17                  android__platform_frameworks_base       0.81800
# 18            allwinner-ics__platform_frameworks_base       0.81300
# 19  RealVNC__android-frameworks-base-with-screensh...       0.81000
# 20                             eucalyptus__eucalyptus       0.62000
# 21                              alkacon__opencms-core       0.96200
# 22           IceColdSandwich__android_frameworks_base       0.81100
# 23                               SINTEF-9012__ThingML       0.94900
# 24                              sebastianbenz__Jnario       0.99900
# 25                             elastic__elasticsearch           NaN
# 26                             eclipse__jetty.project           NaN
# 27                        revolsys__com.revolsys.open           NaN
# 28  adetaylor__android-frameworks-base-with-remote...           NaN
# 29                                            Overall       0.80804
#
#     accuracy_none  accuracy_author  accuracy_complexity  accuracy_size  \
# 0         0.97800          0.97600               0.9750        0.97400
# 1         0.92300          0.92800               0.9160        0.91400
# 2         0.71300          0.74000               0.8020        0.83700
# 3         0.62000          0.76400               0.6770        0.78000
# 4         0.82200          0.83800               0.8270        0.89800
# 5         0.79700          0.81400               0.8050        0.84800
# 6         0.70600          0.71800               0.7080        0.72500
# 7         0.63300          0.64700               0.6470        0.69400
# 8         0.56100          0.58900               0.5780        0.62200
# 9         0.95200          0.94900               0.9530        0.96600
# 10        0.75900          0.77300               0.7650        0.77400
# 11        0.84800          0.85800               0.8640        0.85100
# 12        0.63800          0.66000               0.6330        0.67100
# 13        0.46600          0.51300               0.4640        0.53800
# 14        0.48000          0.48800               0.5220        0.57400
# 15        0.61600          0.65300               0.6050        0.63700
# 16        0.80700          0.81100               0.8090        0.82000
# 17        0.79800          0.80100               0.7980        0.81300
# 18        0.79000          0.79600               0.7980        0.80100
# 19        0.79500          0.79900               0.7930        0.80300
# 20        0.60100          0.60200               0.6080        0.59300
# 21        0.96000          0.95600               0.9570        0.96100
# 22        0.79000          0.79300               0.7930        0.80400
# 23        0.94200          0.94600               0.9440        0.94600
# 24        0.99900          0.99900               0.9990        0.99900
# 25            NaN              NaN                  NaN            NaN
# 26            NaN              NaN                  NaN            NaN
# 27            NaN              NaN                  NaN            NaN
# 28            NaN              NaN                  NaN            NaN
# 29        0.75976          0.77644               0.7696        0.79372
#
#     accuracy_position  accuracy_content
# 0             0.97500           0.98000
# 1             0.92300           0.93600
# 2             0.76400           0.76400
# 3             0.68700           0.75400
# 4             0.82400           0.87300
# 5             0.82700           0.84500
# 6             0.71100           0.72900
# 7             0.62600           0.63800
# 8             0.56800           0.60500
# 9             0.96400           0.96700
# 10            0.77300           0.77600
# 11            0.86400           0.86000
# 12            0.62400           0.65100
# 13            0.46100           0.52400
# 14            0.49900           0.55700
# 15            0.62000           0.64600
# 16            0.79600           0.81300
# 17            0.79100           0.80900
# 18            0.79300           0.80600
# 19            0.79400           0.79800
# 20            0.60500           0.61000
# 21            0.96000           0.96500
# 22            0.78000           0.80300
# 23            0.94400           0.94900
# 24            0.99900           0.99900
# 25                NaN               NaN
# 26                NaN               NaN
# 27                NaN               NaN
# 28                NaN               NaN
# 29            0.76688           0.78628

# %%
accuracy_rf_improv = accuracy_rf[accuracy_rf['project']=='Overall'].copy()
accuracy_rf_improv['improv._all'] = accuracy_rf_improv.apply(lambda x: classifier_utils.get_normalized_improvement(x['accuracy_all'], x['accuracy_none']), axis=1)
accuracy_rf_improv['improv._author'] = accuracy_rf_improv.apply(lambda x: classifier_utils.get_normalized_improvement(x['accuracy_author'], x['accuracy_none']), axis=1)
accuracy_rf_improv['improv._complexity'] = accuracy_rf_improv.apply(lambda x: classifier_utils.get_normalized_improvement(x['accuracy_complexity'], x['accuracy_none']), axis=1)
accuracy_rf_improv['improv._size'] = accuracy_rf_improv.apply(lambda x: classifier_utils.get_normalized_improvement(x['accuracy_size'], x['accuracy_none']), axis=1)
accuracy_rf_improv['improv._position'] = accuracy_rf_improv.apply(lambda x: classifier_utils.get_normalized_improvement(x['accuracy_position'], x['accuracy_none']), axis=1)
accuracy_rf_improv['improv._content'] = accuracy_rf_improv.apply(lambda x: classifier_utils.get_normalized_improvement(x['accuracy_content'], x['accuracy_none']), axis=1)
accuracy_rf_improv.transpose()
# Out:
#                             29
# project                Overall
# accuracy_all           0.80804
# accuracy_none          0.75976
# accuracy_author        0.77644
# accuracy_complexity     0.7696
# accuracy_size          0.79372
# accuracy_position      0.76688
# accuracy_content       0.78628
# improv._all           0.200966
# improv._author       0.0694306
# improv._complexity    0.040959
# improv._size          0.141359
# improv._position      0.029637
# improv._content        0.11039
