# %% [markdown]
# Goal of this notebook:
#
# Investigate the impact on the classifier accuracy of each group of attributes related to the conflicting chunks.
#
# Attributes groups:
# - Merge attributes
# - File attributes
# - Chunk attributes
#
#
# - Merge + File -> measure Chunk attributes group importance
# - Merge + Chunk -> measure File attributes group importance
# - File + Chunk -> measure Merge attributes group importance

# %%
import numpy as np
import pandas as pd
from IPython.core.display import display

pd.set_option('display.max_columns', None)
from sklearn.ensemble import RandomForestClassifier
import warnings
import classifier_utils
import configs
warnings.filterwarnings("ignore", category=UserWarning)
import time

# %%
print(f'Notebook last run on: {time.ctime()}')
# Out:
# Notebook last run on: Mon Aug  1 10:34:26 2022

# %%
non_features_columns = ["chunk_id", "line_start", "line_end", "line_separator", "kind_conflict", "url", "project"]
non_features_columns.extend(["project_user", "project_name", "path", "file_name", "sha", "leftsha", "rightsha", "basesha"])

# %%
selected_dataset = pd.read_csv("../../data/SELECTED_LABELLED_DATASET.csv")
projects = list(selected_dataset['project'].unique())

# %%
rf = RandomForestClassifier(random_state=99, n_jobs=5, n_estimators=400, max_features=0.3, min_samples_leaf=1)# Decision Tree

# %%
default_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns)
report_default = default_result.get_report_df(include_overall=True)

# %% [markdown]
# ## Merge + file (no chunk attributes)

# %%
import importlib
importlib.reload(classifier_utils)
ablation_group = 'all'
chunk_columns_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns, ablation=True, ablation_group=ablation_group, ablation_mode='remove')

# %%
report_chunk_columns = chunk_columns_result.get_report_df(include_overall=True)
report_chunk_columns
# Out:
#                                   project  observations  \
# 0                         CCI-MIT__XCoLab          5512
# 1                apache__directory-server           845
# 2                  Ramblurr__Anki-Android           892
# 3                        apache__accumulo          4113
# 4                        jgralab__jgralab          2072
# 5                         getrailo__railo           815
# 6                     apache__lucene-solr          1256
# 7                               zkoss__zk          1087
# 8                           freenet__fred          1268
# 9   CloudStack-extras__CloudStack-archive          1424
# 10                 eucalyptus__eucalyptus          1020
# 11                        atlasapi__atlas          1107
# 12      android__platform_frameworks_base          3557
# 13                  alkacon__opencms-core           923
# 14                           alexo__wro4j          1663
# 15               hibernate__hibernate-orm          1000
# 16                 TeamDev-Ltd__OpenFaces          2979
# 17                       Unidata__thredds          1154
# 18                   SINTEF-9012__ThingML          1022
# 19                  sebastianbenz__Jnario          8298
# 20                                Overall         42007
#
#     observations (wt NaN)  precision  recall  f1-score  accuracy  \
# 0                    3757     0.9730  0.9780   0.97500    0.9780
# 1                     652     0.9220  0.9230   0.92200    0.9230
# 2                     759     0.6810  0.7060   0.69100    0.7060
# 3                    3148     0.7880  0.7970   0.79200    0.7970
# 4                    1802     0.7090  0.7130   0.70900    0.7130
# 5                     572     0.6210  0.6330   0.62500    0.6330
# 6                     974     0.5520  0.5610   0.55600    0.5610
# 7                     881     0.7500  0.7590   0.75400    0.7590
# 8                    1012     0.6270  0.6380   0.63200    0.6380
# 9                    1106     0.6060  0.6200   0.61200    0.6200
# 10                    747     0.5870  0.6010   0.59300    0.6010
# 11                    782     0.6020  0.6160   0.60400    0.6160
# 12                   2460     0.7880  0.7980   0.79200    0.7980
# 13                    840     0.9500  0.9600   0.95500    0.9600
# 14                   1368     0.4720  0.4800   0.47600    0.4800
# 15                    716     0.4540  0.4660   0.45900    0.4660
# 16                   2859     0.9460  0.9520   0.94800    0.9520
# 17                    950     0.7900  0.8220   0.80200    0.8220
# 18                    977     0.9260  0.9420   0.93300    0.9420
# 19                   8173     0.9980  0.9990   0.99900    0.9990
# 20                  34535     0.7371  0.7482   0.74145    0.7482
#
#     baseline (majority)  improvement
# 0               0.57300      0.94800
# 1               0.51200      0.84300
# 2               0.43900      0.47700
# 3               0.63500      0.44400
# 4               0.49100      0.43500
# 5               0.37800      0.41000
# 6               0.26600      0.40100
# 7               0.60200      0.39600
# 8               0.40400      0.39300
# 9               0.43700      0.32600
# 10              0.42300      0.30900
# 11              0.44500      0.30900
# 12              0.70800      0.30700
# 13              0.94400      0.27700
# 14              0.30700      0.25000
# 15              0.31100      0.22500
# 16              0.93800      0.22200
# 17              0.77700      0.20300
# 18              0.93800      0.06600
# 19              0.99900      0.00000
# 20              0.57635      0.36205

# %% [markdown]
# ## Merge + Chunk (no file attributes)

# %%
import importlib
importlib.reload(classifier_utils)
ablation_group = 'file'
file_columns_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns, ablation=True, ablation_group=ablation_group, ablation_mode='remove')

# %%
report_file_columns = file_columns_result.get_report_df(include_overall=True)
report_file_columns
# Out:
#                                   project  observations  \
# 0                         CCI-MIT__XCoLab          5512
# 1                apache__directory-server           845
# 2                        jgralab__jgralab          2072
# 3                        Unidata__thredds          1154
# 4   CloudStack-extras__CloudStack-archive          1424
# 5                        apache__accumulo          4113
# 6                         getrailo__railo           815
# 7                     apache__lucene-solr          1256
# 8                  Ramblurr__Anki-Android           892
# 9                  TeamDev-Ltd__OpenFaces          2979
# 10                              zkoss__zk          1087
# 11                          freenet__fred          1268
# 12                           alexo__wro4j          1663
# 13               hibernate__hibernate-orm          1000
# 14                        atlasapi__atlas          1107
# 15      android__platform_frameworks_base          3557
# 16                 eucalyptus__eucalyptus          1020
# 17                  alkacon__opencms-core           923
# 18                   SINTEF-9012__ThingML          1022
# 19                  sebastianbenz__Jnario          8298
# 20                                Overall         42007
#
#     observations (wt NaN)  precision  recall  f1-score  accuracy  \
# 0                    3757     0.9700   0.974    0.9720     0.974
# 1                     652     0.9280   0.931    0.9290     0.931
# 2                    1802     0.8550   0.857    0.8540     0.857
# 3                     950     0.9170   0.923    0.9170     0.923
# 4                    1106     0.7940   0.800    0.7950     0.800
# 5                    3148     0.8580   0.864    0.8600     0.864
# 6                     572     0.6990   0.710    0.7040     0.710
# 7                     974     0.6480   0.653    0.6480     0.653
# 8                     759     0.7070   0.726    0.7100     0.726
# 9                    2859     0.9680   0.970    0.9690     0.970
# 10                    881     0.7760   0.788    0.7780     0.788
# 11                   1012     0.6640   0.672    0.6660     0.672
# 12                   1368     0.5700   0.581    0.5720     0.581
# 13                    716     0.5730   0.582    0.5740     0.582
# 14                    782     0.6440   0.660    0.6480     0.660
# 15                   2460     0.8140   0.819    0.8150     0.819
# 16                    747     0.5990   0.621    0.6070     0.621
# 17                    840     0.9460   0.961    0.9530     0.961
# 18                    977     0.9360   0.949    0.9420     0.949
# 19                   8173     0.9980   0.999    0.9990     0.999
# 20                  34535     0.7932   0.802    0.7956     0.802
#
#     baseline (majority)  improvement
# 0               0.57300       0.9390
# 1               0.51200       0.8580
# 2               0.49100       0.7190
# 3               0.77700       0.6560
# 4               0.43700       0.6450
# 5               0.63500       0.6280
# 6               0.37800       0.5340
# 7               0.26600       0.5270
# 8               0.43900       0.5120
# 9               0.93800       0.5110
# 10              0.60200       0.4670
# 11              0.40400       0.4490
# 12              0.30700       0.3960
# 13              0.31100       0.3940
# 14              0.44500       0.3870
# 15              0.70800       0.3810
# 16              0.42300       0.3430
# 17              0.94400       0.2980
# 18              0.93800       0.1800
# 19              0.99900      -0.0000
# 20              0.57635       0.4912

# %% [markdown]
# ## File + Chunk (no merge attributes)

# %%
import importlib
importlib.reload(classifier_utils)
ablation_group = 'merge'
merge_columns_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns, ablation=True, ablation_group=ablation_group, ablation_mode='remove')

# %%
report_merge_columns = merge_columns_result.get_report_df(include_overall=True)
report_merge_columns
# Out:
#                                   project  observations  \
# 0                         CCI-MIT__XCoLab          5512
# 1                apache__directory-server           845
# 2                        jgralab__jgralab          2072
# 3   CloudStack-extras__CloudStack-archive          1424
# 4                        Unidata__thredds          1154
# 5                  Ramblurr__Anki-Android           892
# 6                        apache__accumulo          4113
# 7                     apache__lucene-solr          1256
# 8                         getrailo__railo           815
# 9                  TeamDev-Ltd__OpenFaces          2979
# 10                           alexo__wro4j          1663
# 11                          freenet__fred          1268
# 12               hibernate__hibernate-orm          1000
# 13                  alkacon__opencms-core           923
# 14                        atlasapi__atlas          1107
# 15                              zkoss__zk          1087
# 16                   SINTEF-9012__ThingML          1022
# 17      android__platform_frameworks_base          3557
# 18                 eucalyptus__eucalyptus          1020
# 19                  sebastianbenz__Jnario          8298
# 20                                Overall         42007
#
#     observations (wt NaN)  precision  recall  f1-score  accuracy  \
# 0                    3757     0.9670  0.9700   0.96800    0.9700
# 1                     652     0.9120  0.9160   0.91300    0.9160
# 2                    1802     0.8480  0.8480   0.84100    0.8480
# 3                    1106     0.7920  0.7990   0.78900    0.7990
# 4                     950     0.9060  0.9120   0.90600    0.9120
# 5                     759     0.6980  0.7090   0.68900    0.7090
# 6                    3148     0.7860  0.8040   0.78600    0.8040
# 7                     974     0.6020  0.5990   0.59700    0.5990
# 8                     572     0.5880  0.6070   0.59000    0.6070
# 9                    2859     0.9550  0.9610   0.95800    0.9610
# 10                   1368     0.5300  0.5420   0.53300    0.5420
# 11                   1012     0.5970  0.6040   0.58500    0.6040
# 12                    716     0.5180  0.5360   0.52300    0.5360
# 13                    840     0.9420  0.9620   0.95200    0.9620
# 14                    782     0.5550  0.5820   0.55800    0.5820
# 15                    881     0.6670  0.6950   0.67300    0.6950
# 16                    977     0.9420  0.9520   0.94700    0.9520
# 17                   2460     0.7340  0.7620   0.71100    0.7620
# 18                    747     0.5210  0.5290   0.50300    0.5290
# 19                   8173     0.9980  0.9990   0.99900    0.9990
# 20                  34535     0.7529  0.7644   0.75105    0.7644
#
#     baseline (majority)  improvement
# 0               0.57300       0.9310
# 1               0.51200       0.8270
# 2               0.49100       0.7010
# 3               0.43700       0.6440
# 4               0.77700       0.6040
# 5               0.43900       0.4810
# 6               0.63500       0.4630
# 7               0.26600       0.4530
# 8               0.37800       0.3680
# 9               0.93800       0.3640
# 10              0.30700       0.3400
# 11              0.40400       0.3350
# 12              0.31100       0.3270
# 13              0.94400       0.3190
# 14              0.44500       0.2470
# 15              0.60200       0.2340
# 16              0.93800       0.2300
# 17              0.70800       0.1850
# 18              0.42300       0.1830
# 19              0.99900      -0.0000
# 20              0.57635       0.4118

# %%
df_inner_rf = pd.merge(report_default, report_chunk_columns, on='project', how='inner', suffixes=('_all', '_chunk'))
df_inner_rf_file = report_file_columns.add_suffix("_file").rename(columns={"project_file": "project"})
df_inner_rf = pd.merge(df_inner_rf, df_inner_rf_file, on='project', how='inner')
df_inner_rf_merge = report_merge_columns.add_suffix("_merge").rename(columns={"project_merge": "project"})
df_inner_rf = pd.merge(df_inner_rf, df_inner_rf_merge, on='project', how='inner')

accuracy_rf = df_inner_rf.filter(regex=("project|accuracy.*")).copy()
accuracy_rf
# Out:
#                                   project  accuracy_all  accuracy_chunk  \
# 0                         CCI-MIT__XCoLab       0.97600          0.9780
# 1                apache__directory-server       0.94200          0.9230
# 2                        jgralab__jgralab       0.87000          0.7130
# 3   CloudStack-extras__CloudStack-archive       0.80400          0.6200
# 4                        Unidata__thredds       0.92100          0.8220
# 5                        apache__accumulo       0.86300          0.7970
# 6                  Ramblurr__Anki-Android       0.73600          0.7060
# 7                     apache__lucene-solr       0.65000          0.5610
# 8                         getrailo__railo       0.70300          0.6330
# 9                  TeamDev-Ltd__OpenFaces       0.97000          0.9520
# 10                              zkoss__zk       0.78800          0.7590
# 11                          freenet__fred       0.67800          0.6380
# 12               hibernate__hibernate-orm       0.59800          0.4660
# 13                           alexo__wro4j       0.59000          0.4800
# 14                        atlasapi__atlas       0.66600          0.6160
# 15      android__platform_frameworks_base       0.81700          0.7980
# 16                 eucalyptus__eucalyptus       0.62500          0.6010
# 17                  alkacon__opencms-core       0.96200          0.9600
# 18                   SINTEF-9012__ThingML       0.94900          0.9420
# 19                  sebastianbenz__Jnario       0.99900          0.9990
# 20                                Overall       0.80535          0.7482
#
#     accuracy_file  accuracy_merge
# 0           0.974          0.9700
# 1           0.931          0.9160
# 2           0.857          0.8480
# 3           0.800          0.7990
# 4           0.923          0.9120
# 5           0.864          0.8040
# 6           0.726          0.7090
# 7           0.653          0.5990
# 8           0.710          0.6070
# 9           0.970          0.9610
# 10          0.788          0.6950
# 11          0.672          0.6040
# 12          0.582          0.5360
# 13          0.581          0.5420
# 14          0.660          0.5820
# 15          0.819          0.7620
# 16          0.621          0.5290
# 17          0.961          0.9620
# 18          0.949          0.9520
# 19          0.999          0.9990
# 20          0.802          0.7644

# %%
accuracy_rf_improv = accuracy_rf[accuracy_rf['project']=='Overall'].copy()
accuracy_rf_improv['improv._chunk'] = accuracy_rf_improv.apply(lambda x: classifier_utils.get_normalized_improvement(x['accuracy_chunk'], x['accuracy_all']), axis=1)
accuracy_rf_improv['improv._file'] = accuracy_rf_improv.apply(lambda x: classifier_utils.get_normalized_improvement(x['accuracy_file'], x['accuracy_all']), axis=1)
accuracy_rf_improv['improv._merge'] = accuracy_rf_improv.apply(lambda x: classifier_utils.get_normalized_improvement(x['accuracy_merge'], x['accuracy_all']), axis=1)
accuracy_rf_improv.transpose()
# Out:
#                       20
# project          Overall
# accuracy_all     0.80535
# accuracy_chunk    0.7482
# accuracy_file      0.802
# accuracy_merge    0.7644
# improv._chunk  -0.070963
# improv._file    -0.00416
# improv._merge  -0.050847

# %% [markdown]
# Investigate the impact of removing 2 scopes

# %% [markdown]
# ## Remove Chunk + merge (use only file attributes)

# %%
import random
import importlib
importlib.reload(classifier_utils)
ablation_group = 'file'
file_only_columns_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns, ablation=True, ablation_group=ablation_group, ablation_mode='file_only')

# %%
report_file_only_columns = file_only_columns_result.get_report_df(include_overall=True)
report_file_only_columns
# Out:
#                                   project  observations  \
# 0                apache__directory-server           845
# 1                  Ramblurr__Anki-Android           892
# 2                        jgralab__jgralab          2072
# 3                         CCI-MIT__XCoLab          5512
# 4   CloudStack-extras__CloudStack-archive          1424
# 5                        Unidata__thredds          1154
# 6                     apache__lucene-solr          1256
# 7                           freenet__fred          1268
# 8                        apache__accumulo          4113
# 9                            alexo__wro4j          1663
# 10                              zkoss__zk          1087
# 11                        getrailo__railo           815
# 12      android__platform_frameworks_base          3557
# 13                 eucalyptus__eucalyptus          1020
# 14                        atlasapi__atlas          1107
# 15               hibernate__hibernate-orm          1000
# 16                   SINTEF-9012__ThingML          1022
# 17                  alkacon__opencms-core           923
# 18                  sebastianbenz__Jnario          8298
# 19                 TeamDev-Ltd__OpenFaces          2979
# 20                                Overall         42007
#
#     observations (wt NaN)  precision   recall  f1-score  accuracy  \
# 0                     652    0.87100  0.87300    0.8720   0.87300
# 1                     759    0.66900  0.69300    0.6790   0.69300
# 2                    1802    0.70000  0.70400    0.6990   0.70400
# 3                    3757    0.76700  0.75200    0.7300   0.75200
# 4                    1106    0.65000  0.65900    0.6530   0.65900
# 5                     950    0.83800  0.85700    0.8440   0.85700
# 6                     974    0.48100  0.49600    0.4870   0.49600
# 7                    1012    0.56300  0.57600    0.5680   0.57600
# 8                    3148    0.69400  0.71500    0.7040   0.71500
# 9                    1368    0.44100  0.44700    0.4430   0.44700
# 10                    881    0.65800  0.67500    0.6660   0.67500
# 11                    572    0.47100  0.49000    0.4770   0.49000
# 12                   2460    0.71800  0.75200    0.7310   0.75200
# 13                    747    0.48800  0.50200    0.4930   0.50200
# 14                    782    0.49600  0.50900    0.5020   0.50900
# 15                    716    0.34700  0.35600    0.3510   0.35600
# 16                    977    0.92600  0.94100    0.9330   0.94100
# 17                    840    0.92900  0.94500    0.9350   0.94500
# 18                   8173    0.99800  0.99900    0.9990   0.99900
# 19                   2859    0.91200  0.93200    0.9200   0.93200
# 20                  34535    0.68085  0.69365    0.6843   0.69365
#
#     baseline (majority)  improvement
# 0               0.51200      0.73900
# 1               0.43900      0.45300
# 2               0.49100      0.41900
# 3               0.57300      0.41800
# 4               0.43700      0.39500
# 5               0.77700      0.35800
# 6               0.26600      0.31300
# 7               0.40400      0.28900
# 8               0.63500      0.22000
# 9               0.30700      0.20100
# 10              0.60200      0.18500
# 11              0.37800      0.18000
# 12              0.70800      0.15000
# 13              0.42300      0.13700
# 14              0.44500      0.11500
# 15              0.31100      0.06500
# 16              0.93800      0.04900
# 17              0.94400      0.02100
# 18              0.99900      0.00000
# 19              0.93800     -0.00600
# 20              0.57635      0.23505

# %% [markdown]
# ## Remove Chunk + File (use only merge attributes)

# %%
import random
import importlib
importlib.reload(classifier_utils)
merge_only_columns_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns, ablation=True, ablation_group='', ablation_mode='merge_only')

# %%
report_merge_only_columns = merge_only_columns_result.get_report_df(include_overall=True)
report_merge_only_columns
# Out:
#                                   project  observations  \
# 0                         CCI-MIT__XCoLab          5512
# 1                apache__directory-server           845
# 2                  Ramblurr__Anki-Android           892
# 3                        apache__accumulo          4113
# 4                     apache__lucene-solr          1256
# 5                         getrailo__railo           815
# 6                           freenet__fred          1268
# 7                   alkacon__opencms-core           923
# 8                               zkoss__zk          1087
# 9                  eucalyptus__eucalyptus          1020
# 10                        atlasapi__atlas          1107
# 11      android__platform_frameworks_base          3557
# 12                 TeamDev-Ltd__OpenFaces          2979
# 13               hibernate__hibernate-orm          1000
# 14                       jgralab__jgralab          2072
# 15                           alexo__wro4j          1663
# 16                   SINTEF-9012__ThingML          1022
# 17  CloudStack-extras__CloudStack-archive          1424
# 18                       Unidata__thredds          1154
# 19                  sebastianbenz__Jnario          8298
# 20                                Overall         42007
#
#     observations (wt NaN)  precision   recall  f1-score  accuracy  \
# 0                    3757     0.9640  0.97100   0.96800   0.97100
# 1                     652     0.8940  0.90600   0.90000   0.90600
# 2                     759     0.6850  0.71100   0.69400   0.71100
# 3                    3148     0.7700  0.79300   0.77800   0.79300
# 4                     974     0.5400  0.55600   0.54400   0.55600
# 5                     572     0.5910  0.61400   0.59800   0.61400
# 6                    1012     0.6060  0.61300   0.60500   0.61300
# 7                     840     0.9430  0.96300   0.95200   0.96300
# 8                     881     0.6970  0.72800   0.70900   0.72800
# 9                     747     0.5680  0.59800   0.58000   0.59800
# 10                    782     0.5790  0.60000   0.58300   0.60000
# 11                   2460     0.7800  0.78800   0.78300   0.78800
# 12                   2859     0.9430  0.95200   0.94700   0.95200
# 13                    716     0.4160  0.45300   0.39900   0.45300
# 14                   1802     0.6280  0.59500   0.53600   0.59500
# 15                   1368     0.4100  0.42300   0.41400   0.42300
# 16                    977     0.9350  0.94700   0.94000   0.94700
# 17                   1106     0.4720  0.50800   0.46600   0.50800
# 18                    950     0.7030  0.78300   0.72600   0.78300
# 19                   8173     0.9980  0.99900   0.99900   0.99900
# 20                  34535     0.7061  0.72505   0.70605   0.72505
#
#     baseline (majority)  improvement
# 0               0.57300      0.93200
# 1               0.51200      0.80800
# 2               0.43900      0.48600
# 3               0.63500      0.43300
# 4               0.26600      0.39600
# 5               0.37800      0.37900
# 6               0.40400      0.35000
# 7               0.94400      0.34000
# 8               0.60200      0.31600
# 9               0.42300      0.30400
# 10              0.44500      0.27900
# 11              0.70800      0.27500
# 12              0.93800      0.22700
# 13              0.31100      0.20500
# 14              0.49100      0.20500
# 15              0.30700      0.16700
# 16              0.93800      0.14800
# 17              0.43700      0.12700
# 18              0.77700      0.02800
# 19              0.99900      0.00000
# 20              0.57635      0.32025

# %% [markdown]
# ## Remove Merge + File (use only chunk attributes)

# %%
import random
import importlib
importlib.reload(classifier_utils)
chunk_only_columns_result = classifier_utils.ProjectsResults(rf, projects, non_features_columns, ablation=True, ablation_group='', ablation_mode='chunk_only')

# %%
report_chunk_only_columns = chunk_only_columns_result.get_report_df(include_overall=True)
report_chunk_only_columns
# Out:
#                                   project  observations  \
# 0                         CCI-MIT__XCoLab          5512
# 1                apache__directory-server           845
# 2                        jgralab__jgralab          2072
# 3   CloudStack-extras__CloudStack-archive          1424
# 4                        Unidata__thredds          1154
# 5                     apache__lucene-solr          1256
# 6                        apache__accumulo          4113
# 7                  Ramblurr__Anki-Android           892
# 8                  TeamDev-Ltd__OpenFaces          2979
# 9                         getrailo__railo           815
# 10               hibernate__hibernate-orm          1000
# 11                  alkacon__opencms-core           923
# 12                          freenet__fred          1268
# 13                           alexo__wro4j          1663
# 14                              zkoss__zk          1087
# 15                        atlasapi__atlas          1107
# 16                   SINTEF-9012__ThingML          1022
# 17      android__platform_frameworks_base          3557
# 18                 eucalyptus__eucalyptus          1020
# 19                  sebastianbenz__Jnario          8298
# 20                                Overall         42007
#
#     observations (wt NaN)  precision  recall  f1-score  accuracy  \
# 0                    3757     0.9650  0.9670   0.96500    0.9670
# 1                     652     0.8900  0.8960   0.89300    0.8960
# 2                    1802     0.8380  0.8370   0.83200    0.8370
# 3                    1106     0.7770  0.7860   0.77600    0.7860
# 4                     950     0.9030  0.9080   0.90300    0.9080
# 5                     974     0.5920  0.5930   0.59100    0.5930
# 6                    3148     0.7760  0.7940   0.77600    0.7940
# 7                     759     0.6570  0.6790   0.65400    0.6790
# 8                    2859     0.9600  0.9630   0.96100    0.9630
# 9                     572     0.5770  0.5960   0.58200    0.5960
# 10                    716     0.5350  0.5490   0.53700    0.5490
# 11                    840     0.9430  0.9630   0.95200    0.9630
# 12                   1012     0.5890  0.5960   0.57800    0.5960
# 13                   1368     0.4860  0.4960   0.48900    0.4960
# 14                    881     0.6800  0.6980   0.68300    0.6980
# 15                    782     0.5450  0.5680   0.54800    0.5680
# 16                    977     0.9380  0.9510   0.94400    0.9510
# 17                   2460     0.7240  0.7560   0.70100    0.7560
# 18                    747     0.5090  0.5170   0.49100    0.5170
# 19                   8173     0.9980  0.9990   0.99900    0.9990
# 20                  34535     0.7441  0.7556   0.74275    0.7556
#
#     baseline (majority)  improvement
# 0               0.57300       0.9220
# 1               0.51200       0.7860
# 2               0.49100       0.6800
# 3               0.43700       0.6200
# 4               0.77700       0.5900
# 5               0.26600       0.4460
# 6               0.63500       0.4370
# 7               0.43900       0.4270
# 8               0.93800       0.3920
# 9               0.37800       0.3510
# 10              0.31100       0.3450
# 11              0.94400       0.3400
# 12              0.40400       0.3220
# 13              0.30700       0.2720
# 14              0.60200       0.2420
# 15              0.44500       0.2210
# 16              0.93800       0.2130
# 17              0.70800       0.1640
# 18              0.42300       0.1620
# 19              0.99900      -0.0000
# 20              0.57635       0.3966

# %%
df_inner_rf = pd.merge(report_default, report_chunk_only_columns, on='project', how='inner', suffixes=('_all', '_chunk'))
df_inner_rf_file_only = report_file_only_columns.add_suffix("_file").rename(columns={"project_file": "project"})
df_inner_rf = pd.merge(df_inner_rf, df_inner_rf_file_only, on='project', how='inner')
df_inner_rf_merge_only = report_merge_only_columns.add_suffix("_merge").rename(columns={"project_merge": "project"})
df_inner_rf = pd.merge(df_inner_rf, df_inner_rf_merge_only, on='project', how='inner')

accuracy_rf = df_inner_rf.filter(regex=("project|accuracy.*")).copy()
accuracy_rf
# Out:
#                                   project  accuracy_all  accuracy_chunk  \
# 0                         CCI-MIT__XCoLab       0.97600          0.9670
# 1                apache__directory-server       0.94200          0.8960
# 2                        jgralab__jgralab       0.87000          0.8370
# 3   CloudStack-extras__CloudStack-archive       0.80400          0.7860
# 4                        Unidata__thredds       0.92100          0.9080
# 5                        apache__accumulo       0.86300          0.7940
# 6                  Ramblurr__Anki-Android       0.73600          0.6790
# 7                     apache__lucene-solr       0.65000          0.5930
# 8                         getrailo__railo       0.70300          0.5960
# 9                  TeamDev-Ltd__OpenFaces       0.97000          0.9630
# 10                              zkoss__zk       0.78800          0.6980
# 11                          freenet__fred       0.67800          0.5960
# 12               hibernate__hibernate-orm       0.59800          0.5490
# 13                           alexo__wro4j       0.59000          0.4960
# 14                        atlasapi__atlas       0.66600          0.5680
# 15      android__platform_frameworks_base       0.81700          0.7560
# 16                 eucalyptus__eucalyptus       0.62500          0.5170
# 17                  alkacon__opencms-core       0.96200          0.9630
# 18                   SINTEF-9012__ThingML       0.94900          0.9510
# 19                  sebastianbenz__Jnario       0.99900          0.9990
# 20                                Overall       0.80535          0.7556
#
#     accuracy_file  accuracy_merge
# 0         0.75200         0.97100
# 1         0.87300         0.90600
# 2         0.70400         0.59500
# 3         0.65900         0.50800
# 4         0.85700         0.78300
# 5         0.71500         0.79300
# 6         0.69300         0.71100
# 7         0.49600         0.55600
# 8         0.49000         0.61400
# 9         0.93200         0.95200
# 10        0.67500         0.72800
# 11        0.57600         0.61300
# 12        0.35600         0.45300
# 13        0.44700         0.42300
# 14        0.50900         0.60000
# 15        0.75200         0.78800
# 16        0.50200         0.59800
# 17        0.94500         0.96300
# 18        0.94100         0.94700
# 19        0.99900         0.99900
# 20        0.69365         0.72505

# %%
accuracy_rf_improv = accuracy_rf[accuracy_rf['project']=='Overall'].copy()
accuracy_rf_improv['improv._chunk'] = accuracy_rf_improv.apply(lambda x: classifier_utils.get_normalized_improvement(x['accuracy_chunk'], x['accuracy_all']), axis=1)
accuracy_rf_improv['improv._file'] = accuracy_rf_improv.apply(lambda x: classifier_utils.get_normalized_improvement(x['accuracy_file'], x['accuracy_all']), axis=1)
accuracy_rf_improv['improv._merge'] = accuracy_rf_improv.apply(lambda x: classifier_utils.get_normalized_improvement(x['accuracy_merge'], x['accuracy_all']), axis=1)
accuracy_rf_improv.transpose()
# Out:
#                       20
# project          Overall
# accuracy_all     0.80535
# accuracy_chunk    0.7556
# accuracy_file    0.69365
# accuracy_merge   0.72505
# improv._chunk  -0.061774
# improv._file   -0.138697
# improv._merge  -0.099708
