# %%
import numpy as np
import pandas as pd
from IPython.core.display import display

pd.set_option('display.max_columns', None)
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFECV
import warnings
import classifier_utils
warnings.filterwarnings("ignore")

# %%
non_features_columns = ["chunk_id", "line_start", "line_end", "line_separator", "kind_conflict", "url", "project"]
non_features_columns.extend(["project_user", "project_name", "path", "file_name", "sha", "leftsha", "rightsha", "basesha"])

# %%
selected_dataset = pd.read_csv("../../data/SELECTED_LABELLED_DATASET.csv")
projects = list(selected_dataset['project'].unique())

# %% [markdown]
# ## Attributes relevance

# %%
import importlib
importlib.reload(classifier_utils)
results = classifier_utils.get_attributes_importance(projects, non_features_columns)

# %% [markdown]
# - Which attributes are more relevant (according to the information gain) across all projects?

# %%
results = results.sort_values('average_information_gain', ascending=False).head(50)
results
# Out:
#                              attribute  average_information_gain  average_rank
# 0                     left_lines_added                  1.361994         11.05
# 35                           Commits 1                  1.222260         14.30
# 1                   left_lines_removed                  1.207105         13.70
# 20                        chunkAbsSize                  1.183627         18.75
# 3                  right_lines_removed                  1.140743         16.15
# 13                      keyword_remove                  1.060914         19.25
# 14                         keyword_use                  1.035883         18.75
# 37                     Changed files 1                  1.031389         19.10
# 2                    right_lines_added                  1.000893         17.25
# 5                          keyword_fix                  0.986123         18.05
# 16                      keyword_change                  0.945341         22.40
# 38                     Changed files 2                  0.924259         21.40
# 28                      Branching time                  0.917475         19.90
# 12                         keyword_add                  0.897746         19.60
# 32                      Different devs                  0.880995         24.05
# 21                        chunkRelSize                  0.851528         27.35
# 6                          keyword_bug                  0.835091         21.55
# 10                    keyword_refactor                  0.807376         27.85
# 29                Merge isolation time                  0.796688         23.00
# 36                           Commits 2                  0.793542         23.90
# 30                              Devs 1                  0.793134         28.95
# 11                      keyword_update                  0.791321         22.80
# 33                           Same devs                  0.778756         29.00
# 26                chunk_right_abs_size                  0.765816         32.15
# 65                   Method invocation                  0.746177         25.40
# 8                      keyword_improve                  0.742164         25.75
# 15                      keyword_delete                  0.735356         28.05
# 31                              Devs 2                  0.729918         29.45
# 24                 chunk_left_abs_size                  0.703911         35.70
# 34                   Devs intersection                  0.700336         36.60
# 27                chunk_right_rel_size                  0.693855         36.50
# 25                 chunk_left_rel_size                  0.669690         35.45
# 40                  self_conflict_perc                  0.654865         38.10
# 7                      keyword_feature                  0.643017         29.75
# 9                     keyword_document                  0.597038         34.50
# 42      has_multiple_devs_on_each_side                  0.505910         42.70
# 4                     conclusion_delay                  0.450807         37.05
# 23                            fileSize                  0.448278         39.50
# 48                            Variable                  0.424312         31.95
# 41  has_branch_merge_message_indicator                  0.398596         45.95
# 50                             Comment                  0.382789         31.00
# 22                       chunkPosition                  0.350235         50.60
# 19                              fileCC                  0.337003         43.10
# 54                        If statement                  0.331180         35.05
# 73                           Attribute                  0.310743         35.95
# 67                              Import                  0.280483         36.70
# 75                    Method signature                  0.251188         36.10
# 17                              leftCC                  0.234069         49.30
# 18                             rightCC                  0.168234         54.00
# 43                  Method declaration                  0.160039         39.40

# %%
results.to_csv('../../data/results/attributes_importance.csv', index=False)

# %% [markdown]
# - Are there any insightful association rules for the top-10 attributes?

# %%
import importlib
importlib.reload(classifier_utils)
top_10_attributes = results.iloc[:10]
top_10_attributes = list(top_10_attributes['attribute'])
target_class_name = 'developerdecision'
threshold = 0.5
min_occurences = 10
df_increase, df_decrease = classifier_utils.process_association_rules(top_10_attributes, projects, target_class_name, threshold, min_occurences)

# %%
print(f"Mined {len(df_increase)} rules with at least {threshold*100:.2f}% increased chance that occur more than {min_occurences} times:")
display(df_increase)
# Out:
# Mined 266 rules with at least 50.00% increased chance that occur more than 10 times:
#                                         Rule       Lift  Confidence  \
# 2            left_lines_removed=17 => Manual  10.607873    0.976023
# 2             chunkAbsSize=12 => Combination   8.497970    0.545455
# 3             chunkAbsSize=11 => Combination   8.101398    0.520000
# 0                      keyword_fix=0 => None   7.288073    0.014981
# 2   right_lines_added=9 => ConcatenationV2V1   7.236271    0.033730
# ..                                       ...        ...         ...
# 29        keyword_fix=8 => ConcatenationV2V1   1.510804    0.007042
# 43     right_lines_removed=14 => Combination   1.506373    0.096689
# 27             keyword_use=10 => Combination   1.503042    0.096475
# 34          Commits 1=9 => ConcatenationV2V1   1.500822    0.006996
# 51       right_lines_added=15 => Combination   1.500200    0.096292
#
#     Occurrences
# 2           692
# 2            12
# 3            13
# 0            12
# 2            17
# ..          ...
# 29           24
# 43          438
# 27           52
# 34           18
# 51          187
#
# [266 rows x 4 columns]

# %%
print(f"Mined {len(df_decrease)} rules with at least {threshold*100:.2f}% decreased chance that occur more than {min_occurences} times:")
display(df_decrease)
# Out:
# Mined 123 rules with at least 50.00% decreased chance that occur more than 10 times:
#                                     Rule      Lift  Confidence  Occurrences
# 1     left_lines_removed=17 => Version 1  0.025370    0.016925           12
# 3     left_lines_removed=-1 => Version 2  0.050272    0.007644           33
# 4   left_lines_removed=-1 => Combination  0.050525    0.003243           14
# 1          keyword_remove=1 => Version 2  0.055210    0.008395           84
# 0                keyword_use=0 => Manual  0.094187    0.008666           74
# ..                                   ...       ...         ...          ...
# 16    keyword_use=1 => ConcatenationV1V2  0.486705    0.008708           18
# 15           keyword_remove=10 => Manual  0.488893    0.044983           13
# 27      right_lines_removed=17 => Manual  0.492448    0.045310          185
# 19              Commits 1=2 => Version 1  0.493321    0.329114          104
# 17           keyword_fix=11 => Version 2  0.496894    0.075556           34
#
# [123 rows x 4 columns]

# %% [markdown]
# ## Developers attribute relevance
#
# Considers the information gain and attribute rank (according to the information gain) for the developer with the highest information gain in each project

# %%
import importlib
importlib.reload(classifier_utils)
developers_relevance = classifier_utils.get_developers_attribute_importance(projects, non_features_columns)

# %% [markdown]
# - Which author is the more relevant for each project?
# - What about overall? How important are the authors?

# %%
developers_relevance
# Out:
#                                   project                            author  \
# 0                  Ramblurr__Anki-Android            martin.andre@gmail.com
# 1                apache__directory-server              elecharny@apache.org
# 2       android__platform_frameworks_base  initial-contribution@android.com
# 3                           freenet__fred         toad@amphibian.dyndns.org
# 4                            alexo__wro4j           alex.objelean@gmail.com
# 5                     apache__lucene-solr             mikemccand@apache.org
# 6                         getrailo__railo              michael@getrailo.org
# 7                         atlasapi__atlas            fred@metabroadcast.com
# 8                hibernate__hibernate-orm               steve@hibernate.org
# 9   CloudStack-extras__CloudStack-archive                   alena@cloud.com
# 10                 TeamDev-Ltd__OpenFaces       dmitry.pikhulya@teamdev.com
# 11                 eucalyptus__eucalyptus                     decker@hawaii
# 12                              zkoss__zk                  tomyeh@zkoss.org
# 13                  alkacon__opencms-core            a.kandzior@alkacon.com
# 14                   SINTEF-9012__ThingML      mouline.ludovic@etu.unice.fr
# 15                       apache__accumulo               ctubbsii@apache.org
# 16                       Unidata__thredds            caron@unidata.ucar.edu
# 17                       jgralab__jgralab               horn@uni-koblenz.de
# 18                  sebastianbenz__Jnario     birgit.engelmann@bmw-carit.de
# 19                        CCI-MIT__XCoLab       janusz.parfieniuk@gmail.com
# 20                                Overall                                 -
#
#     information_gain  rank
# 0           0.954690  36.0
# 1           1.052000   7.0
# 2           0.289087  34.0
# 3           2.007149   2.0
# 4           2.091704   1.0
# 5           1.335695  19.0
# 6           1.588456   5.0
# 7           1.099141   8.0
# 8           2.069798  10.0
# 9           0.921129  35.0
# 10          0.421644  13.0
# 11          0.718929  19.0
# 12          1.484539  11.0
# 13          0.190630  29.0
# 14          0.401656   6.0
# 15          1.062550  31.0
# 16          0.851071   8.0
# 17          0.976515  36.0
# 18          0.000010  13.0
# 19          0.908261  35.0
# 20          1.021233  17.9

# %%
developers_relevance.to_csv('../../data/results/developers_importance.csv', index=False)

# %% [markdown]
# ## Language constructs relevance
# - What is the most important construct in each project?
# - What is the overall average information gain and rank for language constructs (using the top-1 for each project)?

# %%
import importlib
importlib.reload(classifier_utils)
constructs_relevance = classifier_utils.get_constructs_attribute_importance(projects, non_features_columns)

# %%
constructs_relevance
# Out:
#                                   project          construct  \
# 0                  Ramblurr__Anki-Android  Method invocation
# 1                apache__directory-server  Method invocation
# 2       android__platform_frameworks_base  Method invocation
# 3                           freenet__fred  Method invocation
# 4                            alexo__wro4j  Method invocation
# 5                     apache__lucene-solr  Method invocation
# 6                         getrailo__railo  Method invocation
# 7                         atlasapi__atlas  Method invocation
# 8                hibernate__hibernate-orm             Import
# 9   CloudStack-extras__CloudStack-archive  Method invocation
# 10                 TeamDev-Ltd__OpenFaces            Comment
# 11                 eucalyptus__eucalyptus  Method invocation
# 12                              zkoss__zk  Method invocation
# 13                  alkacon__opencms-core            Comment
# 14                   SINTEF-9012__ThingML  Method invocation
# 15                       apache__accumulo  Method invocation
# 16                       Unidata__thredds            Comment
# 17                       jgralab__jgralab  Method invocation
# 18                  sebastianbenz__Jnario       If statement
# 19                        CCI-MIT__XCoLab       If statement
# 20                                Overall                  -
#
#     information_gain   rank
# 0           1.309414  28.00
# 1           0.417061  34.00
# 2           0.820339  26.00
# 3           1.160266  27.00
# 4           1.061447  13.00
# 5           1.397565  18.00
# 6           0.953301  20.00
# 7           1.198229   6.00
# 8           1.260123  23.00
# 9           0.936753  34.00
# 10          0.301211  24.00
# 11          1.075006  12.00
# 12          0.778483  24.00
# 13          0.257804  22.00
# 14          0.272849  28.00
# 15          0.986388  33.00
# 16          0.400207  22.00
# 17          0.696160  42.00
# 18          0.009207   1.00
# 19          0.812860  38.00
# 20          0.805234  23.75

# %%
constructs_relevance.to_csv('../../data/results/constructs_importance_projects.csv', index=False)

# %% [markdown]
# What is the average information gain and rank for each language construct?

# %%
import importlib
importlib.reload(classifier_utils)
constructs_ig = classifier_utils.get_constructs_information_gain(projects, non_features_columns)

# %%
constructs_ig.sort_values('avg_information_gain', ascending=False)
# Out:
#                    construct  avg_information_gain  avg_rank
# 13         Method invocation              0.746177   26.6500
# 17                  Variable              0.424312   34.3500
# 12                   Comment              0.382789   33.6500
# 34              If statement              0.331180   38.1000
# 4                  Attribute              0.310743   38.8000
# 37                    Import              0.280483   40.4000
# 9           Method signature              0.251188   39.5000
# 39                   Overall              0.182639  148.5625
# 35        Method declaration              0.160039   43.9000
# 20                Annotation              0.132506   50.7000
# 1           Return statement              0.130927   46.1500
# 29             For statement              0.064499   55.5000
# 27             Try statement              0.059562   54.0000
# 3            Cast expression              0.049119   56.8000
# 14       Package declaration              0.047568   99.9500
# 19           Class signature              0.035731   64.1500
# 8                      Other              0.028182   69.5500
# 21          Method interface              0.026735   69.2000
# 26              Catch clause              0.025978   66.2000
# 0          Class declaration              0.024492   69.8500
# 38                     Blank              0.024107   84.1500
# 24           Throw statement              0.024104   68.4500
# 15           While statement              0.016265   77.8000
# 23    Synchronized statement              0.012931   84.0500
# 2               Array access              0.011146   80.4000
# 32          Assert statement              0.009804  114.0000
# 7             Case statement              0.007987   86.0500
# 10           Break statement              0.005974   82.9500
# 18                Enum value              0.005482   95.3000
# 25          Switch statement              0.005109   87.9500
# 22     Interface declaration              0.003407  105.1000
# 16       Interface signature              0.003007  108.7500
# 33        Static initializer              0.002654  100.6000
# 5          Array initializer              0.002183  103.2000
# 30          Enum declaration              0.002048  113.7500
# 36        Continue statement              0.001594  116.1000
# 31            Enum signature              0.001400  115.3000
# 6               Do statement              0.000759  110.1000
# 28    Annotation declaration              0.000525  124.1500
# 11  TypeDeclarationStatement              0.000085  115.7000

# %%
constructs_ig.to_csv('../../data/results/constructs_ig.csv', index=False)
