# %%
import numpy as np
import pandas as pd
from IPython.core.display import display

pd.set_option('display.max_columns', None)
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFECV
import warnings
import classifier_utils
warnings.filterwarnings("ignore")

# %%
non_features_columns = ["chunk_id", "line_start", "line_end", "line_separator", "kind_conflict", "url", "project"]
non_features_columns.extend(["project_user", "project_name", "path", "file_name", "sha", "leftsha", "rightsha", "basesha"])

# %%
selected_dataset = pd.read_csv("../../data/SELECTED_LABELLED_DATASET.csv")
projects = list(selected_dataset['project'].unique())

# %% [markdown]
# ## Attributes relevance

# %%
import importlib
importlib.reload(classifier_utils)
results = classifier_utils.get_attributes_importance(projects, non_features_columns)

# %% [markdown]
# - Which attributes are more relevant (according to the information gain) across all projects?

# %%
results = results.sort_values('average_information_gain', ascending=False).head(50)
results
# Out:
#                              attribute  average_information_gain  average_rank
# 1                   left_lines_removed                  0.348419         12.30
# 0                     left_lines_added                  0.344164         10.00
# 2                    right_lines_added                  0.324572         11.50
# 38                     Changed files 2                  0.324027         15.35
# 37                     Changed files 1                  0.317652         14.75
# 5                          keyword_fix                  0.314918         13.75
# 28                      Branching time                  0.311556         17.10
# 35                           Commits 1                  0.311012         11.30
# 3                  right_lines_removed                  0.307950         14.80
# 14                         keyword_use                  0.300825         15.45
# 12                         keyword_add                  0.297971         14.60
# 29                Merge isolation time                  0.288796         18.10
# 16                      keyword_change                  0.285733         18.65
# 6                          keyword_bug                  0.261187         20.05
# 36                           Commits 2                  0.256391         18.85
# 32                      Different devs                  0.245485         25.55
# 13                      keyword_remove                  0.244934         17.40
# 11                      keyword_update                  0.233802         19.80
# 8                      keyword_improve                  0.203374         20.25
# 30                              Devs 1                  0.196514         30.35
# 10                    keyword_refactor                  0.194214         25.55
# 15                      keyword_delete                  0.193934         25.35
# 31                              Devs 2                  0.191654         28.95
# 4                     conclusion_delay                  0.164567         31.80
# 33                           Same devs                  0.155884         27.95
# 9                     keyword_document                  0.154223         30.65
# 7                      keyword_feature                  0.149197         26.85
# 23                            fileSize                  0.126166         36.65
# 19                              fileCC                  0.112062         38.60
# 20                        chunkAbsSize                  0.090192         26.85
# 21                        chunkRelSize                  0.085437         36.35
# 40                  self_conflict_perc                  0.082890         40.65
# 34                   Devs intersection                  0.082446         45.20
# 42      has_multiple_devs_on_each_side                  0.067386         45.05
# 26                chunk_right_abs_size                  0.061088         36.65
# 27                chunk_right_rel_size                  0.059461         44.35
# 25                 chunk_left_rel_size                  0.059461         43.45
# 67                              Import                  0.057876         31.05
# 41  has_branch_merge_message_indicator                  0.053162         49.20
# 24                 chunk_left_abs_size                  0.048707         41.55
# 65                   Method invocation                  0.033857         35.30
# 48                            Variable                  0.026682         36.35
# 22                       chunkPosition                  0.026665         52.80
# 50                             Comment                  0.026347         38.65
# 63                               Blank                  0.022051         52.75
# 75                    Method signature                  0.021427         40.70
# 17                              leftCC                  0.021168         51.25
# 18                             rightCC                  0.019844         53.40
# 58                          Annotation                  0.017675         47.15
# 54                        If statement                  0.017594         40.75

# %%
results.to_csv('../../data/results/attributes_importance.csv', index=False)

# %% [markdown]
# - Are there any insightful association rules for the top-10 attributes?

# %%
import importlib
importlib.reload(classifier_utils)
top_10_attributes = results.iloc[:10]
top_10_attributes = list(top_10_attributes['attribute'])
target_class_name = 'developerdecision'
threshold = 0.5
min_occurences = 10
df_increase, df_decrease = classifier_utils.process_association_rules(top_10_attributes, projects, target_class_name, threshold, min_occurences)

# %%
print(f"Mined {len(df_increase)} rules with at least {threshold*100:.2f}% increased chance that occur more than {min_occurences} times:")
display(df_increase)
# Out:
# Mined 278 rules with at least 50.00% increased chance that occur more than 10 times:
#                                         Rule       Lift  Confidence  \
# 2            left_lines_removed=17 => Manual  10.607873    0.976023
# 0                      keyword_fix=0 => None   7.288073    0.014981
# 2   right_lines_added=9 => ConcatenationV2V1   7.236271    0.033730
# 0              keyword_use=12 => Combination   5.842355    0.375000
# 0            Changed files 2=13 => Version 2   5.575764    0.847826
# ..                                       ...        ...         ...
# 29        keyword_fix=8 => ConcatenationV2V1   1.510804    0.007042
# 43     right_lines_removed=14 => Combination   1.506373    0.096689
# 27             keyword_use=10 => Combination   1.503042    0.096475
# 34          Commits 1=9 => ConcatenationV2V1   1.500822    0.006996
# 51       right_lines_added=15 => Combination   1.500200    0.096292
#
#     Occurrences
# 2           692
# 0            12
# 2            17
# 0            15
# 0            39
# ..          ...
# 29           24
# 43          438
# 27           52
# 34           18
# 51          187
#
# [278 rows x 4 columns]

# %%
print(f"Mined {len(df_decrease)} rules with at least {threshold*100:.2f}% decreased chance that occur more than {min_occurences} times:")
display(df_decrease)
# Out:
# Mined 130 rules with at least 50.00% decreased chance that occur more than 10 times:
#                                     Rule      Lift  Confidence  Occurrences
# 1     left_lines_removed=17 => Version 1  0.025370    0.016925           12
# 3     left_lines_removed=-1 => Version 2  0.050272    0.007644           33
# 4   left_lines_removed=-1 => Combination  0.050525    0.003243           14
# 0                keyword_use=0 => Manual  0.094187    0.008666           74
# 6        left_lines_removed=-1 => Manual  0.100704    0.009266           40
# ..                                   ...       ...         ...          ...
# 24       left_lines_added=8 => Version 1  0.486497    0.324561          444
# 16    keyword_use=1 => ConcatenationV1V2  0.486705    0.008708           18
# 27      right_lines_removed=17 => Manual  0.492448    0.045310          185
# 19              Commits 1=2 => Version 1  0.493321    0.329114          104
# 17           keyword_fix=11 => Version 2  0.496894    0.075556           34
#
# [130 rows x 4 columns]

# %% [markdown]
# ## Developers attribute relevance
#
# Considers the information gain and attribute rank (according to the information gain) for the developer with the highest information gain in each project

# %%
import importlib
importlib.reload(classifier_utils)
developers_relevance = classifier_utils.get_developers_attribute_importance(projects, non_features_columns)

# %% [markdown]
# - Which author is the more relevant for each project?
# - What about overall? How important are the authors?

# %%
developers_relevance
# Out:
#                                   project  \
# 0                  Ramblurr__Anki-Android
# 1                apache__directory-server
# 2       android__platform_frameworks_base
# 3                           freenet__fred
# 4                            alexo__wro4j
# 5                     apache__lucene-solr
# 6                         getrailo__railo
# 7                         atlasapi__atlas
# 8                hibernate__hibernate-orm
# 9   CloudStack-extras__CloudStack-archive
# 10                 TeamDev-Ltd__OpenFaces
# 11                 eucalyptus__eucalyptus
# 12                              zkoss__zk
# 13                  alkacon__opencms-core
# 14                   SINTEF-9012__ThingML
# 15                       apache__accumulo
# 16                       Unidata__thredds
# 17                       jgralab__jgralab
# 18                  sebastianbenz__Jnario
# 19                        CCI-MIT__XCoLab
# 20                                Overall
#
#                                          author  information_gain  rank
# 0                        martin.andre@gmail.com          0.175819  29.0
# 1                          akarasulu@apache.org          0.215938  30.0
# 2                                jbq@google.com          0.050371  27.0
# 3                      saces@freenetproject.org          0.122353  29.0
# 4                              thilo@ginkel.com          0.010600  28.0
# 5                        markrmiller@apache.org          0.096490  23.0
# 6                          michael@getrailo.org          0.092394  31.0
# 7                        sergio.bossa@gmail.com          0.029947  24.0
# 8                           jverhaeg@redhat.com          0.086512  27.0
# 9                     deepakgarg.iitg@gmail.com          0.099051  34.0
# 10  Dallas@7826287f-d7cb-499f-91f0-9f45672cc948          0.049421  31.0
# 11                                    neil@pall          0.039244  32.0
# 12                             tomyeh@zkoss.org          0.083146  37.0
# 13                           r.kurz@alkacon.com          0.073650  22.0
# 14                       brice.morin1@gmail.com          0.066252  33.0
# 15                             vines@apache.org          0.107638  26.0
# 16                       caron@unidata.ucar.edu          0.076831  27.0
# 17                            devnull@localhost          0.074206  38.0
# 18                birgit.engelmann@bmw-carit.de          0.000010  13.0
# 19                         steverab93@gmail.com          0.546533  23.0
# 20                                            -          0.104820  28.2

# %%
developers_relevance.to_csv('../../data/results/developers_importance.csv', index=False)

# %% [markdown]
# ## Language constructs relevance
# - What is the most important construct in each project?
# - What is the overall average information gain and rank for language constructs (using the top-1 for each project)?

# %%
import importlib
importlib.reload(classifier_utils)
constructs_relevance = classifier_utils.get_constructs_attribute_importance(projects, non_features_columns)

# %%
constructs_relevance
# Out:
#                                   project           construct  \
# 0                  Ramblurr__Anki-Android              Import
# 1                apache__directory-server               Blank
# 2       android__platform_frameworks_base        If statement
# 3                           freenet__fred          Annotation
# 4                            alexo__wro4j              Import
# 5                     apache__lucene-solr              Import
# 6                         getrailo__railo              Import
# 7                         atlasapi__atlas              Import
# 8                hibernate__hibernate-orm              Import
# 9   CloudStack-extras__CloudStack-archive               Blank
# 10                 TeamDev-Ltd__OpenFaces             Comment
# 11                 eucalyptus__eucalyptus              Import
# 12                              zkoss__zk   Method invocation
# 13                  alkacon__opencms-core              Import
# 14                   SINTEF-9012__ThingML  Method declaration
# 15                       apache__accumulo              Import
# 16                       Unidata__thredds   Method invocation
# 17                       jgralab__jgralab   Method invocation
# 18                  sebastianbenz__Jnario            Variable
# 19                        CCI-MIT__XCoLab    Return statement
# 20                                Overall                   -
#
#     information_gain  rank
# 0           0.033104  46.0
# 1           0.216272  29.0
# 2           0.013492  39.0
# 3           0.144550  27.0
# 4           0.125109   1.0
# 5           0.066641  30.0
# 6           0.079876  35.0
# 7           0.069572  12.0
# 8           0.185363  18.0
# 9           0.092971  35.0
# 10          0.190066   9.0
# 11          0.093982  21.0
# 12          0.093248  34.0
# 13          0.040171  30.0
# 14          0.025776  41.0
# 15          0.110428  25.0
# 16          0.026156  43.0
# 17          0.032839  42.0
# 18          0.001863   1.0
# 19          0.027477  46.0
# 20          0.083448  28.2

# %%
constructs_relevance.to_csv('../../data/results/constructs_importance_projects.csv', index=False)

# %% [markdown]
# What is the average information gain and rank for each language construct?

# %%
import importlib
importlib.reload(classifier_utils)
constructs_ig = classifier_utils.get_constructs_information_gain(projects, non_features_columns)

# %%
constructs_ig.sort_values('avg_information_gain', ascending=False)
# Out:
#                    construct  avg_information_gain  avg_rank
# 37                    Import              0.057876   33.8500
# 13         Method invocation              0.033857   42.0000
# 17                  Variable              0.026682   40.2500
# 12                   Comment              0.026347   50.2500
# 38                     Blank              0.022051   65.8000
# 9           Method signature              0.021427   50.0000
# 39                   Overall              0.018471  154.7725
# 20                Annotation              0.017675   61.2000
# 34              If statement              0.017594   47.2500
# 4                  Attribute              0.014829   53.5500
# 14       Package declaration              0.013825   95.5000
# 35        Method declaration              0.013519   55.7500
# 1           Return statement              0.011955   52.9000
# 3            Cast expression              0.009157   64.1000
# 29             For statement              0.008827   64.0000
# 0          Class declaration              0.008267   67.8000
# 19           Class signature              0.007636   70.6000
# 27             Try statement              0.006280   60.6000
# 8                      Other              0.006276   79.3000
# 26              Catch clause              0.005418   75.1500
# 21          Method interface              0.004814   71.5000
# 24           Throw statement              0.004254   81.6500
# 15           While statement              0.004083   82.0500
# 23    Synchronized statement              0.003301   82.0000
# 22     Interface declaration              0.003168   98.4000
# 2               Array access              0.002802   84.7000
# 7             Case statement              0.002507   84.7000
# 25          Switch statement              0.002226   83.6000
# 10           Break statement              0.002209   85.4500
# 32          Assert statement              0.001828  113.7500
# 16       Interface signature              0.001594  107.3500
# 18                Enum value              0.001387   96.5000
# 5          Array initializer              0.001369   96.9500
# 33        Static initializer              0.001127  102.1500
# 30          Enum declaration              0.000941  113.8000
# 31            Enum signature              0.000874  114.8000
# 36        Continue statement              0.000715  116.3000
# 28    Annotation declaration              0.000332  124.3000
# 6               Do statement              0.000312  110.0000
# 11  TypeDeclarationStatement              0.000085  115.6500

# %%
constructs_ig.to_csv('../../data/results/constructs_ig.csv', index=False)
