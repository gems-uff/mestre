# %%
import pandas as pd
import re

# %%
df = pd.read_csv("../../data/merge_types_data.csv")
df = df.drop('branch_merge', 1)
df['merge_SHA'] = df["merge_SHA"].str[:10]

# %%
sample = df.sample(frac = 1.0, random_state=123).groupby('project').head(5).sample(n=20, random_state=123)
display(sample)
# Out:
#         chunk_id                                  project   merge_SHA  devs1  \
# 139384   1405151                    cismet/cismet-commons  02f552a7ad    1.0
# 92319    1162628  forcedotcom/SalesforceMobileSDK-Android  683b0f306a    3.0
# 51394    1026140                    BetterShop/BetterShop  ac4fcac8d4    1.0
# 43477     998523                        droolsjbpm/guvnor  76c10c2fa7    1.0
# 89449    1154752                     iron-io/iron_mq_java  f6b88e2b6c    3.0
# 98837    1226168               ladriangb/jSwitch-base-src  a238af2139    1.0
# 45380    1005133                    dropwizard/dropwizard  841f07cd8c   20.0
# 26976     941598                       aptana/studio3-php  bf7b549fd4    1.0
# 2116      781374                     bpellin/keepassdroid  9141ffc4fc    1.0
# 108889   1313350                Rajawali/RajawaliExamples  5de49a7c87    4.0
# 141476   1411822                     zanata/zanata-common  b7adf89e0c    2.0
# 141656   1412067                          amininger/abolt  3c998eab84    1.0
# 20626     922917                        geeksville/Gaggle  ce325082fb    2.0
# 100245   1254033               hylke94/Vossen-en-konijnen  223842550d    1.0
# 102113   1272753                            tomp2p/TomP2P  44f73a1bda    1.0
# 86063    1147581                             duongvc/apps  629b675191    1.0
# 104986   1293407               evandor/skysail-server-ext  ed36dd5998    1.0
# 46541    1008010                          jayway/JsonPath  131f2a1a45    7.0
# 53330    1041184                             cmader/qSKOS  2ad0c9cedd    2.0
# 146504   1465515                  frapontillo/ImageViewEx  6be8e5bf8a    1.0
#
#         devs2                                     commit_message
# 139384    1.0  Merge remote-tracking branch 'origin/pw-enc-op...
# 92319     2.0  Merge remote-tracking branch 'upstream/master'...
# 51394     1.0  Merge branch 'master' of https://github.com/lo...
# 43477     4.0  Merge remote branch 'remotes/upstream/master' ...
# 89449     1.0  Merge branch 'master' into v3\n\nConflicts:\n\...
# 98837     1.0                                          18-032012
# 45380     1.0  Merge branch 'dynamic-ports' of https://github...
# 26976     8.0           Merge branch 'development' into debugger
# 2116      3.0  Merge branch 'master' into save_kdbx\n\nConfli...
# 108889    1.0  Merge remote-tracking branch 'remotes/origin/a...
# 141476    1.0  Merge branch 'rhbz888090' into integration/mas...
# 141656    1.0  Merge remote-tracking branch 'lhinkle/master'\...
# 20626     2.0  Merge branch 'master' of git://github.com/rele...
# 100245    1.0  Merge branch 'master' of https://github.com/hy...
# 102113    2.0  Merge remote-tracking branch 'tomp2p/master'\n...
# 86063     1.0  Merge branch 'master' of https://github.com/du...
# 104986    1.0                                                wip
# 46541     1.0  Fixed merge conflict. Support for Functions in...
# 53330     1.0  Merge branch 'devel'\n\nConflicts:\n\tpom.xml\...
# 146504    1.0  Merge commit '2b5712335bcaea3157002c32db943566...

# %% [markdown]
# ### Option 1: devs1 >= 2 and devs2 >=2 and merge branch in commit_message

# %%
def is_branch_merge1(devs1, devs2, commit_message):
    return devs1 >=2 and devs2 >=2 and 'merge branch' in str(commit_message).strip().lower()

option1 = sample.copy()
option1['merge_branch'] = df.apply(lambda x: is_branch_merge1(x['devs1'], x['devs2'], x['commit_message']), axis=1)
display(option1)
# Out:
#         chunk_id                                  project   merge_SHA  devs1  \
# 139384   1405151                    cismet/cismet-commons  02f552a7ad    1.0
# 92319    1162628  forcedotcom/SalesforceMobileSDK-Android  683b0f306a    3.0
# 51394    1026140                    BetterShop/BetterShop  ac4fcac8d4    1.0
# 43477     998523                        droolsjbpm/guvnor  76c10c2fa7    1.0
# 89449    1154752                     iron-io/iron_mq_java  f6b88e2b6c    3.0
# 98837    1226168               ladriangb/jSwitch-base-src  a238af2139    1.0
# 45380    1005133                    dropwizard/dropwizard  841f07cd8c   20.0
# 26976     941598                       aptana/studio3-php  bf7b549fd4    1.0
# 2116      781374                     bpellin/keepassdroid  9141ffc4fc    1.0
# 108889   1313350                Rajawali/RajawaliExamples  5de49a7c87    4.0
# 141476   1411822                     zanata/zanata-common  b7adf89e0c    2.0
# 141656   1412067                          amininger/abolt  3c998eab84    1.0
# 20626     922917                        geeksville/Gaggle  ce325082fb    2.0
# 100245   1254033               hylke94/Vossen-en-konijnen  223842550d    1.0
# 102113   1272753                            tomp2p/TomP2P  44f73a1bda    1.0
# 86063    1147581                             duongvc/apps  629b675191    1.0
# 104986   1293407               evandor/skysail-server-ext  ed36dd5998    1.0
# 46541    1008010                          jayway/JsonPath  131f2a1a45    7.0
# 53330    1041184                             cmader/qSKOS  2ad0c9cedd    2.0
# 146504   1465515                  frapontillo/ImageViewEx  6be8e5bf8a    1.0
#
#         devs2                                     commit_message  merge_branch
# 139384    1.0  Merge remote-tracking branch 'origin/pw-enc-op...         False
# 92319     2.0  Merge remote-tracking branch 'upstream/master'...         False
# 51394     1.0  Merge branch 'master' of https://github.com/lo...         False
# 43477     4.0  Merge remote branch 'remotes/upstream/master' ...         False
# 89449     1.0  Merge branch 'master' into v3\n\nConflicts:\n\...         False
# 98837     1.0                                          18-032012         False
# 45380     1.0  Merge branch 'dynamic-ports' of https://github...         False
# 26976     8.0           Merge branch 'development' into debugger         False
# 2116      3.0  Merge branch 'master' into save_kdbx\n\nConfli...         False
# 108889    1.0  Merge remote-tracking branch 'remotes/origin/a...         False
# 141476    1.0  Merge branch 'rhbz888090' into integration/mas...         False
# 141656    1.0  Merge remote-tracking branch 'lhinkle/master'\...         False
# 20626     2.0  Merge branch 'master' of git://github.com/rele...          True
# 100245    1.0  Merge branch 'master' of https://github.com/hy...         False
# 102113    2.0  Merge remote-tracking branch 'tomp2p/master'\n...         False
# 86063     1.0  Merge branch 'master' of https://github.com/du...         False
# 104986    1.0                                                wip         False
# 46541     1.0  Fixed merge conflict. Support for Functions in...         False
# 53330     1.0  Merge branch 'devel'\n\nConflicts:\n\tpom.xml\...         False
# 146504    1.0  Merge commit '2b5712335bcaea3157002c32db943566...         False

# %% [markdown]
# ### Option 2: merge[d]  branch [] [i|o]nto in commit_message or (devs1 >= 2 and devs2 >=2)

# %%
pattern1 = re.compile(r"[m|M]erge[d]? [b|B]ranch (.*) [i|o]nto", re.IGNORECASE)

def is_branch_merge2(devs1, devs2, commit_message):
    commit_message = str(commit_message)
    has_message_evidence = pattern1.search(commit_message) != None 
    if has_message_evidence or (int(devs1) >= 2 and int(devs2) >=2):
        return True
    return False
    
option2 = sample.copy()
option2['merge_branch'] = df.apply(lambda x: is_branch_merge2(x['devs1'], x['devs2'], x['commit_message']), axis=1)
display(option2)
# Out:
#         chunk_id                                  project   merge_SHA  devs1  \
# 139384   1405151                    cismet/cismet-commons  02f552a7ad    1.0
# 92319    1162628  forcedotcom/SalesforceMobileSDK-Android  683b0f306a    3.0
# 51394    1026140                    BetterShop/BetterShop  ac4fcac8d4    1.0
# 43477     998523                        droolsjbpm/guvnor  76c10c2fa7    1.0
# 89449    1154752                     iron-io/iron_mq_java  f6b88e2b6c    3.0
# 98837    1226168               ladriangb/jSwitch-base-src  a238af2139    1.0
# 45380    1005133                    dropwizard/dropwizard  841f07cd8c   20.0
# 26976     941598                       aptana/studio3-php  bf7b549fd4    1.0
# 2116      781374                     bpellin/keepassdroid  9141ffc4fc    1.0
# 108889   1313350                Rajawali/RajawaliExamples  5de49a7c87    4.0
# 141476   1411822                     zanata/zanata-common  b7adf89e0c    2.0
# 141656   1412067                          amininger/abolt  3c998eab84    1.0
# 20626     922917                        geeksville/Gaggle  ce325082fb    2.0
# 100245   1254033               hylke94/Vossen-en-konijnen  223842550d    1.0
# 102113   1272753                            tomp2p/TomP2P  44f73a1bda    1.0
# 86063    1147581                             duongvc/apps  629b675191    1.0
# 104986   1293407               evandor/skysail-server-ext  ed36dd5998    1.0
# 46541    1008010                          jayway/JsonPath  131f2a1a45    7.0
# 53330    1041184                             cmader/qSKOS  2ad0c9cedd    2.0
# 146504   1465515                  frapontillo/ImageViewEx  6be8e5bf8a    1.0
#
#         devs2                                     commit_message  merge_branch
# 139384    1.0  Merge remote-tracking branch 'origin/pw-enc-op...         False
# 92319     2.0  Merge remote-tracking branch 'upstream/master'...          True
# 51394     1.0  Merge branch 'master' of https://github.com/lo...         False
# 43477     4.0  Merge remote branch 'remotes/upstream/master' ...         False
# 89449     1.0  Merge branch 'master' into v3\n\nConflicts:\n\...          True
# 98837     1.0                                          18-032012         False
# 45380     1.0  Merge branch 'dynamic-ports' of https://github...          True
# 26976     8.0           Merge branch 'development' into debugger          True
# 2116      3.0  Merge branch 'master' into save_kdbx\n\nConfli...          True
# 108889    1.0  Merge remote-tracking branch 'remotes/origin/a...         False
# 141476    1.0  Merge branch 'rhbz888090' into integration/mas...          True
# 141656    1.0  Merge remote-tracking branch 'lhinkle/master'\...         False
# 20626     2.0  Merge branch 'master' of git://github.com/rele...          True
# 100245    1.0  Merge branch 'master' of https://github.com/hy...         False
# 102113    2.0  Merge remote-tracking branch 'tomp2p/master'\n...         False
# 86063     1.0  Merge branch 'master' of https://github.com/du...         False
# 104986    1.0                                                wip         False
# 46541     1.0  Fixed merge conflict. Support for Functions in...         False
# 53330     1.0  Merge branch 'devel'\n\nConflicts:\n\tpom.xml\...         False
# 146504    1.0  Merge commit '2b5712335bcaea3157002c32db943566...         False
